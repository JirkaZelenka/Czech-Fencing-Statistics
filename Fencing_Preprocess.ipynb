# %% [markdown]
# ## Fencing Statistics - ČR and World
# #### 7.11.2022 After a competition in Písek (5.-6.11.2022)
# #### 8.12. still manually preparing Men data...
# #### 21.12. creating local repo and GITHub https://github.com/JirkaZelenka/Czech-Fencing-Statistics

# %% [markdown]
# * https://fie.org/athletes/                                      = Individual's Profile, D.o.B.
# * https://fie.org/competitions                                   = Event profile
#
# * https://www.czechfencing.cz/portal/teams/detail/14             = Club's profile
# * https://www.czechfencing.cz/portal/rankings/list               = Rankings + filters
# * https://www.czechfencing.cz/portal/members/detail/1175         = Individual's Profile
# * https://www.czechfencing.cz/portal/events/detail?eventId=3095  = Event profile with a File included
# * https://www.czechfencing.cz/user_files/propositions/63541c9150a35/Lazensky-pohar-2022.pdf = File with details
#
# * http://sermliga.eu/  = univerzitní liga, 3. kola, 2. teď v praze
#
# * http://www.fencing.cz/  = aktivní čeští veteráni - překrývá se s czechfencing, ale jiné turnaje -> zpracovat též

# %% [markdown]
# ### Ideas:
#
# ##### Hlavní metriky:
# * Poměr výher/proher
# * Index = zásahy dal minus dostal
# * Průměrné umístění (vždy přepočítat na percentily kvůli různým počtům účastníků?)
# * Počet medailí celkem
#
# #### 4 úrovně: Kluby, Závodníci obecně, Zápasy (vzájemné skore dvojic) a pak predikce (sázky, regrese,simulace ...)
#
# #### Kluby:
# * ~~celkový počet členů~~, **V2_Club.html**
# * ~~věkové statistiky~~ - **V1_Year-Club.html**
# * žebříčky po turnajích, ~~po medailích,~~
# * žebříčky podle typu turnaje (UŠL/ČR/Svět), podle zbraně (Jen kord)
# * statistiky států (měst) a klubů
# * průměrný věk a počet nasazených za klub
# * průměrné umístění za klub v daném turnaji
# * ~~který klub má kolik medailí.~~  **V4_Medals-Club.html**
# * pro každého človeka/klub mít průměrný počet zásahů na zápas, přičemž oddělovat poolové a eliminační (15b)
# * PŘIDAT KROM KLUBU JEŠTĚ MĚSTO, odkud klub pochází?
# * vyjet si interní statistiky klubu, vzájemné duely, "žebříček"
#
# #### Závodníci obecně:
# * ~~věkové statistiky~~ **V1_Year-Club.html**
# * ~~průměrný "aktivní" věk výherců, ale i ten reálný~~ **V3_Medals-Year.html**
# * ~~(věk - vyhrává stáří a xp vs mládí a energie?)~~
# * leváci vs praváci. jejich zastoupení u obou pohlaví, u klubů atd.
# * Do tabulek zápasů si doplnit skore, jaké dostali za ten turnaj -> abych mohl udělat jakoby pseudo žebříček jen na základě těchto bodů
# * muži vs ženy. věk , rozložení medailí, zbraně, ruka... histogramy
# * pro každého človeka/klub mít průměrný počet zásahů na zápas, přičemž oddělovat poolové a eliminační (15b)
# * Znamení zvěrokruhu xD
#
# #### Závodníci- profily jednotlivců + vzájemné info (když se vyberou dva lidi), společné zápasy
# * po zvolení člověka vidím jeho medailonek jako na webu (věk, klub, ??ruka??)
# * ale taky účast na všech turnajích, co si ještě můřu rozfiltrovat podle typu soutěže: přidat LVL závodu, tj UŠL < Klasický závod < MČR < Evropské < Světové
# * kalendář, kdy byl aktivní.
# * nejlepší umístění, průměrné umístění (zas podle typu soutěže)
# * počet odehraných zápasů, TS, TR ...
# * největí nemesis, nejlepší terč?
# * co by koho osobně ještě mohlo zajímat???
# ####
# * vzájemné soutěže, kde se potkali, i když spolu třeba nebojovali, nebo i jen ty kde spolu bojovali. - ty zvýraznit
# * vzájemné souboje, historie duelů pro danou dvojici (nebo klub), skore a počty výher pro každou dvojici. = vybrat si libovolnou dovjici lidí a ukázat celou jejich soubojovu historii, jednak přímé boje, ale i to na kterých turnajích se potkali a jak dopadli.
# * pořadí, ale i eliminace, kolikrát vypadnutí nazčátku atd., kolikrát ve finále.
# * počet zápasů. zlepšování se v čase. Sankey diagramy umístění (v rámci klubu?)
# * overall matice, každý s každým, aby se vidělo, kdo se s kým už potkal ve skupině nebo v eliminaci, ajak to dopadlo. V případě že už vícekrát,tak vytvořit jejich vzájemný skore, podle počtu výher? - příklad A v řádku porazí B ve sloupci ve 2 bojích ze 3, tak dostane skore +2? nebo prostě zelený čtvereček. naopak červený. nebo žlutý na remízu nebo šedivý pokud nic)
# * vyjet si duely sourozenců
#
# #### Predikce (bonusová část)
# * -> Předpovědět když se potká někdo z SC a někdo z VSK, jak to pravděpodobně dopadne
# * srovnávačka, jak moc první kolo předpoví i finální výsledek
# * nějaká regrese, jak se klub a věk podílí na pořadí, resp korelace věku a pořadí. asi bude kvadratický vztah?
# * regrese - jak se index podepíše na postupu, resp na pozici. protože některé s -16 prošli a čestmír s -6 neprošel
# * procentuální šance na výhru. Pak by se dalo sázet :O Odhadnout, že Vávra vyhrává 90 % zápasů a nejhůř dává 4 zásahy. Nebo že například Vávra vždy porazil kohokoliv z VUT a Olomouce.
# * Pokémon systém xD udělat modelové souboje
# * možnost nasimulovat celý zápas podle historických dat, znovu vytvořit pooly i žebříček
# * možnost vidět jak by dopadl tehdejší turnaj, kdyby se odehrál dnes -> tj záleží na pořadí a historii zápasů.
# * v případě simulace celého zápasu, vidět jak by se zpřesNoval kyž mu dodám postupně třeba poolová data.

# %% [markdown]
# ### Data format:
# * **Tři tabulky**
# * 1) **Závodníci** - ID / Jméno / Klub (potenciálně víc)  / Stát / Pohlaví / D.narození / Ruka / Zbraň / Skore v žebříčku k poslednímu update
# * // dopočítaný počet všech turnajů, počet poolových zápasů a počet eliminačních zápasů, a jejich koeficienty Výher. / Počet vítězství? nebo to až později...
#
# * 2) **Eventy** - ID / Datum / Event / Město / Pohlaví / Počet účastníků / Počet účastníků obou pohlaví
#
# * 3) **Výsledky Eventů** - ID / ID Event / ID závodníka / Rank ČR před / Rank po Poolu / Status po Poolu (Adv./Elim.)/ Rank Celkově
#
# * 4) **Zápasy** - ID / ID Eventu / ID závodníka 1 / ID závodníka 2 / Fight Lvl (Pool/Eliminace_32) / Výsledek (V/D) / Scored / Received
#
# #### Zatím:
# 1) **1_zavodnici.xlsx**
# 2) **2_ranky.xlsx** = **Výsledky Eventů**
# 3) **Zápasy**

# %% [markdown]
# ### Notes
# * https://www.czechfencing.cz/portal/rankings/list - po Exportu vyjede textak, kde sice nejsou body za jendotlivé soutěže, ale je tam zas celé datum narození !
#
# * v žebříčcích se dá sehnat 600 bodů za jediný event, i když standardní český turnaj je třeba za 80
#
# - ze závodu 09 - MCR USK - tak jsou tam i týmy. hromada dalších tabulek,ale to zatím neřeším beru základ.
#
# - zajímavé formátování outputu:
# | Default | Left-aligned | Center-aligned | Right-aligned |
# |---------|:-------------|:--------------:|--------------:|
# | Default | Left | Center | Right |
#
# 5.1. Souboje s opravami (polovina ženských zápasů):
# - zavádím tam v eliminaci značení: Eliminace_32, Eliminace_16_A, Eliminace_16_B,
# - Eliminace_8_A (výherci z 16_A)
# - Eliminace_16_AB, Eliminace_8_AB (spojení prohraných 16_A a vítězů 16_B, dvakrát po sobě -> 4 zbydou )
# - Eliminace_8_B (pohravší 8_A a vítězové Eliminace_8_AB)
# - Eliminace_8 = klasická Osmička, a dál ...
#
#
# - Vizualizace V1-V4 uděat přepínání mezi muži, ženami, a součtem
# - ještě řeším roky - šlo by místocheckboxů mít ty toggle tlačítka? pokdu každé může mít dva stavy, tak jich prostě mít víc? jen je dobře posčítat pak?
# - u V3 by bylo hekzé do pozadí dát počet lidí té dané věkovéískupiny, takovou tu populační křivku
# - step 1 dropdowny na 4 grafy - muží, ženy, součet.
# - Step 2 možná i dropdown na roky.
# - step 3) data ženy čistění a ukložení.
# - 4) spojení s muži
# - UPRAVIT názvy grafů, aby taky reflektovaly pohlaví? pokud teda budou oddělené.
#
#
# ~~--Index je vždycky rozdíl dal-dostal = TS-TR; TS = touche scored = ZD (zásahů dal); TR = touches received ~~--
#
# ~~-- v posledním turnaji v Písku, všem (mužům) posunuli den narození o den dřív :D včetně mě, Rubeše a všech co jsem si kontrolov.~~-
#
# ~~Rozbitá jména v písku - ADAM Sykora je Sýkora Adam Herbert~~
#
# ~~* zrovna VSK Humanita je nějaká divná, protože ve výsledcích turnaje se jmenuje **HF PRAHA**, teď jsem akorát našel **HUMANITA PHA** a taky **VSK HUMANITA**, potom ještě **VSKHPZ** přes Aničku~~

# %%
import pandas as pd
import numpy as np
import os

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go

def printbold(s):
    print("\033[1m" + s + "\033[0m")

# %% [markdown]
# # I. PREPROCESSING
# ### ((a zatím nepoužitý výsledek po Poolovém kole))

# %% [markdown]
# ## I.1 - LOADING připravených excelů

# %% [markdown]
# * Excel - velká manuální část - stáhnutí PDF tabulek do excelu, přepis Ranků na integer (jsou tam T), namnožení sloupečků s Datumem, Eventem, Pohlavím, sortování první tabulky podle příjmení, Kontrola useknutých jmen,
# * a hlavně: Vytvoření Poolových tabulek a záznamů z eliminace
# * Kontrola Birthdate oproti exportu z webu ve formě CSV, a oproti ostatním záznamům z minulých turnajů
# * chybí mi "ruka"

# %%
files = os.listdir('C:/Users/jzelenka/Documents/python_j/fencing/data/men/')
excels = [x for x in files if x.split(".")[1]== "xlsx"]
print(len(excels))
excels
# Out:
# 16
# ['M_2019_04_Jested.xlsx',
#  'M_2019_05_MCR.xlsx',
#  'M_2019_10_Lazensky_pohar.xlsx',
#  'M_2019_11_Pisek.xlsx',
#  'M_2019_12_Memorial.xlsx',
#  'M_2020_02_Dukla_Olomouc.xlsx',
#  'M_2021_09_MCR.xlsx',
#  'M_2021_10_Lazensky_pohar.xlsx',
#  'M_2021_11_Pisek.xlsx',
#  'M_2021_12_Memorial.xlsx',
#  'M_2022_03_Dukla_Olomouc.xlsx',
#  'M_2022_04_Jested.xlsx',
#  'M_2022_05_MCR_USK.xlsx',
#  'M_2022_10_Lazensky_pohar.xlsx',
#  'M_2022_11_Pisek.xlsx',
#  'M_2022_12_Memorial.xlsx']

# %%
men = ['M_2019_04_Jested.xlsx', 'M_2019_05_MCR.xlsx', 'M_2019_10_Lazensky_pohar.xlsx', 'M_2019_11_Pisek.xlsx',
 'M_2019_12_Memorial.xlsx',"M_2020_02_Dukla_Olomouc.xlsx", "M_2021_09_MCR.xlsx","M_2021_10_Lazensky_pohar.xlsx","M_2021_11_Pisek.xlsx", 
       "M_2021_12_Memorial.xlsx", "M_2022_03_Dukla_Olomouc.xlsx", "M_2022_04_Jested.xlsx","M_2022_05_MCR_USK.xlsx",
       "M_2022_10_Lazensky_pohar.xlsx", "M_2022_11_Pisek.xlsx", "M_2022_12_Memorial.xlsx"]
print(len(men))
women = ["W_2019_05_MCR.xlsx", "W_2019_10_Pohar_CEZ.xlsx", "W_2019_12_Cup_USK.xlsx", "W_2020_01_Letnany.xlsx", 
         "W_2020_02_Dukla_Olomouc.xlsx", "W_2020_09_MCR.xlsx", "W_2021_09_MCR.xlsx", "W_2021_11_Letnany.xlsx", "W_2021_11_Pisek.xlsx",
         "W_2022_03_Dukla_Olomouc.xlsx", "W_2022_04_Teplice.xlsx", "W_2022_05_MCR_USK.xlsx", "W_2022_10_Lazensky_pohar.xlsx",
         "W_2022_11_Pisek.xlsx" , "W_2022_12_Memorial.xlsx"]
print(len(women))
# Out:
# 16
# 15

# %%
SEX = "M"

# %%
def merge_all(list_of_events, sex):
    df_tot = pd.DataFrame(columns = ['Name', 'Club', 'Country', 'Sex', 'Birthdate',
                                 "Date", "Event", "Rank", "Init_rank", "First_rank", "Final_rank",
                                 "V",  "V/M",  "TS", "TR", "Ind", "Notes"])
    if sex == "M":
        s = "men"
    else:
        s = "women"
    for event in list_of_events:
        e = pd.ExcelFile(f"C:/Users/jzelenka/Documents/python_j/fencing/data/{s}/" + event)
        df0 = pd.read_excel(e, 'initiation')
        df1 = pd.read_excel(e, 'first_round')
        df2 = pd.read_excel(e, 'total_rank')
        
        if len(df0) == len(df1) == len(df2):
            if sorted(df0['Name'].unique()) == sorted(df1['Name'].unique()) == sorted(df2['Name'].unique()):
                print(f"Event {event} has {len(df0)} people per each list, {len(df0['Name'].unique())} unique Names")
            else:
                printbold(f"Event {event} has an inconsistency in the uniqueness of names !!!!!!!!")
                printbold(f"unique names: {len(df0['Name'].unique())}, {len(df1['Name'].unique())}, and {len(df2['Name'].unique())}")
                
        else:
            printbold(f"Event {event} has an inconsistency in the length of the lists !!!!!!!!")
            printbold(f"length initiation: {len(df0)}, first_round: {len(df1)}, and total_rank: {len(df2)}")
            
        
        df3 = pd.merge(df0, df1, on = ['Name',"Club", "Country"])
        df4 = pd.merge(df3, df2, on = ['Name',"Club", "Country"])
                                                                                                            
        if len(df0) == len(df4) and len(df0['Name'].unique()) == len(df4['Name'].unique()):                                               
            print(f"Correct after merging")
        else:
            printbold("Something is wrong, during merging or before !!!!!!!!!!!!!!!!!!!!")
        
        df_tot=df_tot.append(df4)
        print(f"new length of total = {len(df_tot)}")
        printbold("####################################")
        
    df_tot = df_tot[["Name", "Club", "Country","Birthdate_x", "Date_x", "Event_x", "Sex_x", "Rank", "First_rank", "Final_rank", "Notes"]]
    df_tot = df_tot.rename(columns={"Birthdate_x":'Birthdate', "Date_x": "Date", "Event_x": "Event", "Sex_x": "Sex" })
    df_tot.reset_index(inplace=True, drop = True)
    
    return df_tot

# %%
df_m = merge_all(men, "M")
print(len(df_m))
print(df_m.head(2))
print(df_m.tail(2))
# Out:
# Event M_2019_04_Jested.xlsx has 68 people per each list, 68 unique Names
# Correct after merging
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# new length of total = 68
# ####################################
# Event M_2019_05_MCR.xlsx has 65 people per each list, 65 unique Names
# Correct after merging
# new length of total = 133
# ####################################
# Event M_2019_10_Lazensky_pohar.xlsx has 82 people per each list, 82 unique Names
# Correct after merging
# new length of total = 215
# ####################################
# Event M_2019_11_Pisek.xlsx has 65 people per each list, 65 unique Names
# Correct after merging
# new length of total = 280
# ####################################
# Event M_2019_12_Memorial.xlsx has 80 people per each list, 80 unique Names
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# Correct after merging
# new length of total = 360
# ####################################
# Event M_2020_02_Dukla_Olomouc.xlsx has 61 people per each list, 61 unique Names
# Correct after merging
# new length of total = 421
# ####################################
# Event M_2021_09_MCR.xlsx has 82 people per each list, 82 unique Names
# Correct after merging
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# new length of total = 503
# ####################################
# Event M_2021_10_Lazensky_pohar.xlsx has 70 people per each list, 70 unique Names
# Correct after merging
# new length of total = 573
# ####################################
# Event M_2021_11_Pisek.xlsx has 81 people per each list, 81 unique Names
# Correct after merging
# new length of total = 654
# ####################################
# Event M_2021_12_Memorial.xlsx has 80 people per each list, 80 unique Names
# Correct after merging
# new length of total = 734
# ####################################
# Event M_2022_03_Dukla_Olomouc.xlsx has 61 people per each list, 61 unique Names
# Correct after merging
# new length of total = 795
# ####################################
# Event M_2022_04_Jested.xlsx has 73 people per each list, 73 unique Names
# Correct after merging
# new length of total = 868
# ####################################
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# Event M_2022_05_MCR_USK.xlsx has 75 people per each list, 75 unique Names
# Correct after merging
# new length of total = 943
# ####################################
# Event M_2022_10_Lazensky_pohar.xlsx has 82 people per each list, 82 unique Names
# Correct after merging
# new length of total = 1025
# ####################################
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# Event M_2022_11_Pisek.xlsx has 76 people per each list, 76 unique Names
# Correct after merging
# new length of total = 1101
# ####################################
# Event M_2022_12_Memorial.xlsx has 98 people per each list, 98 unique Names
# Correct after merging
# new length of total = 1199
# ####################################
# 1199
#            Name          Club Country  Birthdate       Date   Event Sex  Rank  \
# 0  ANDERLE Petr  RIEGEL PRAHA     CZE 1977-07-07 2019-04-14  Ještěd   M  40.0
# 1  BALCAR Josef  LOKO TEPLICE     CZE 1998-10-31 2019-04-14  Ještěd   M  17.0
#
#   First_rank Final_rank     Notes
# 0         36         41  Advanced
# 1         10         11  Advanced
#               Name      Club Country  Birthdate       Date     Event Sex Rank  \
# 1197  WALLER Jonáš  SC PRAHA     CZE 2008-10-10 2022-12-17  Memorial   M   25
# 1198  ZELENKA Jiří  HF PRAHA     CZE 1993-06-04 2022-12-17  Memorial   M  131
#
#      First_rank Final_rank       Notes
# 1197         35         29    Advanced
# 1198         95         95  Eliminated
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\3050692290.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)

# %%
df_m.tail()
# Out:
#                 Name          Club Country  Birthdate       Date     Event  \
# 1194  VÁVRA Miroslav      VSK ČVUT     CZE 1961-08-17 2022-12-17  Memorial
# 1195   VÁVRA Vojtěch  EKONOM PRAHA     CZE 1996-11-19 2022-12-17  Memorial
# 1196     WALLER Adam      SC PRAHA     CZE 2007-08-27 2022-12-17  Memorial
# 1197    WALLER Jonáš      SC PRAHA     CZE 2008-10-10 2022-12-17  Memorial
# 1198    ZELENKA Jiří      HF PRAHA     CZE 1993-06-04 2022-12-17  Memorial
#
#      Sex Rank First_rank Final_rank       Notes
# 1194   M  114         84         84  Eliminated
# 1195   M   43         30         38    Advanced
# 1196   M   65         54         32    Advanced
# 1197   M   25         35         29    Advanced
# 1198   M  131         95         95  Eliminated

# %%
display(df_m.describe())
#display(df_m.describe(datetime_is_numeric=True))
# Out:
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\701769035.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df_m.describe())
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_8772\701769035.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df_m.describe())
#                 Name      Club Country            Birthdate  \
# count           1199      1199    1199                 1190
# unique           298       122      12                  244
# top     BALCAR Josef  SC PRAHA     CZE  2001-07-29 00:00:00
# freq              16       217    1153                   24
# first            NaN       NaN     NaN  1949-04-02 00:00:00
# last             NaN       NaN     NaN  2011-11-07 00:00:00
#
#                        Date     Event   Sex   Rank  First_rank  Final_rank  \
# count                  1199      1199  1199  992.0      1199.0      1199.0
# unique                   16         7     1  118.0        98.0        98.0
# top     2022-12-17 00:00:00  Memorial     M  999.0        25.0         3.0
# freq                     98       258  1199   81.0        21.0        31.0
# first   2019-04-14 00:00:00       NaN   NaN    NaN         NaN         NaN
# last    2022-12-17 00:00:00       NaN   NaN    NaN         NaN         NaN
#
#            Notes
# count       1199
# unique         4
# top     Advanced
# freq         959
# first        NaN
# last         NaN

# %%
for col in df_m.columns:
    printbold(f"# {col}")
    display(df_m[col].value_counts())
    printbold("######################################")
# Out:
# # Name
# BALCAR Josef       16
# PRYL Dobromil      15
# TŮMA Marek         15
# STEHLÍK Jan        15
# DOLEJŠÍ Marek      15
#                    ..
# CHLEBÍK Michal      1
# PÁTEK Ondřej        1
# POKORNÝ Jan         1
# ŠTULÍŘ Pavel        1
# ŠILHAN Jindřich     1
# Name: Name, Length: 298, dtype: int64
# ######################################
# # Club
# SC PRAHA       217
# USK PRAHA       88
# LOKO K.VARY     67
# D.OLOMOUC       67
# D.PRAHA         50
#               ...
# TJSBI            1
# ORELJHK          1
# BSKM             1
# AKADSB           1
# POL              1
# Name: Club, Length: 122, dtype: int64
# ######################################
# # Country
# CZE    1153
# SVK      19
# VEN       8
# POL       7
# PL        2
# RUS       2
# GEO       2
# UKR       2
# GER       1
# SWE       1
# GRE       1
# AUT       1
# Name: Country, dtype: int64
# ######################################
# # Birthdate
# 2001-07-29    24
# 1993-03-30    16
# 1993-12-12    16
# 1991-12-23    16
# 1962-08-27    15
#               ..
# 1999-04-24     1
# 1961-01-01     1
# 1967-01-01     1
# 1994-05-25     1
# 2001-01-05     1
# Name: Birthdate, Length: 244, dtype: int64
# ######################################
# # Date
# 2022-12-17    98
# 2019-10-26    82
# 2021-09-26    82
# 2022-10-22    82
# 2021-11-06    81
# 2019-12-14    80
# 2021-12-18    80
# 2022-11-05    76
# 2022-05-21    75
# 2022-04-24    73
# 2021-10-23    70
# 2019-04-14    68
# 2019-05-25    65
# 2019-11-09    65
# 2020-02-22    61
# 2022-03-12    61
# Name: Date, dtype: int64
# ######################################
# # Event
# Memorial                  258
# Lázeňský pohár            234
# Zlatý kord města Písku    222
# MCR                       147
# Ještěd                    141
# Dukla Olomouc             122
# MČR USK                    75
# Name: Event, dtype: int64
# ######################################
# # Sex
# M    1199
# Name: Sex, dtype: int64
# ######################################
# # Rank
# 999.0    81
# 52.0     20
# 34.0     19
# 59.0     17
# 51.0     16
#          ..
# 121.0     1
# 92.0      1
# 100.0     1
# 133.0     1
# 107.0     1
# Name: Rank, Length: 118, dtype: int64
# ######################################
# # First_rank
# 25    21
# 47    20
# 1     20
# 41    19
# 57    18
#       ..
# 87     1
# 89     1
# 85     1
# 90     1
# 95     1
# Name: First_rank, Length: 98, dtype: int64
# ######################################
# # Final_rank
# 3     31
# 52    18
# 47    18
# 48    18
# 17    17
#       ..
# 89     1
# 85     1
# 94     1
# 4      1
# 95     1
# Name: Final_rank, Length: 98, dtype: int64
# ######################################
# # Notes
# Advanced      959
# Eliminated    235
# Withdrew        3
# DNF             2
# Name: Notes, dtype: int64
# ######################################

# %%
df_m[df_m["Notes"]=="Withdrew"]
# Out:
#                       Name         Club Country  Birthdate       Date  \
# 994        ŘEZANKA_ST. Ota  LOKO K.VARY     CZE 1970-07-24 2022-10-22
# 1078  PUSTEJOVSKY Vladimír     SC PRAHA     CZE 2003-12-14 2022-11-05
# 1165        OMELKA Antonín     HF PRAHA     CZE 1993-03-12 2022-12-17
#
#                        Event Sex  Rank First_rank Final_rank     Notes
# 994           Lázeňský pohár   M  62.0        DNF        DNF  Withdrew
# 1078  Zlatý kord města Písku   M    30        DNF        DNF  Withdrew
# 1165                Memorial   M   114        DNF        DNF  Withdrew

# %% [markdown]
# ## I.2 - Duplicity ve jménech
# * Export vs. Soutěže (sjednoceno):
# * 'SVOBODA Tomáš Kristián' = SVOBODA Tomáš_st.
# * SVOBODA Tomáš = 'SVOBODA Tomáš_ml.',

# %%
# 189 jmen -> 15 orpav -> 142 unikátních jmen

to_replace_woman = {"ADAMCOVA Anita": "ADAMCOVÁ Anita",
                    "AIGERMANOVA Gabriela": "AIGERMANOVÁ Gabriela",
                    "BARTOSKOVA Adéla": "BARTOŠKOVÁ Adéla",
                    "BIELESZOVA Veronika": "BIELESZOVÁ Veronika",
                    "CEJNAROVA Barbora": "CEJNAROVÁ Barbora",
                    'CHALUPNÍKOVÁ Arana': 'CHALUPNÍKOVÁ Aranka',
                    'CHEVALIER Vira': 'CHEVALLIER Vira',          # novější a častější, + FB check
                    "COUFALOVA Anna": "COUFALOVÁ Anna",
                    'DE_VINCENZO Francesca': 'DE VINCENZO Francesca',
                    "DIVISOVA Klára": "DIVIŠOVÁ Klára",
                    'DIVIŠOVÁ, ROZ. JÍLKOVÁ Klára': "DIVIŠOVÁ Klára",   #tohle je otázka...
                    "FRDLIKOVA Markéta": "FRDLÍKOVÁ Markéta",
                    "HAVLINOVA Tereza": "HAVLÍNOVÁ Tereza",
                    'HONOVÁ Markéte': 'HONOVÁ Markéta',
                    "HONOVA Marketa": "HONOVÁ Markéta",
                    "HUNCAROVA Katarína": "HUNČÁROVÁ Katarína",
                    'HUNČÁROVÁ Katarina': 'HUNČÁROVÁ Katarína',
                    "CHALUPNIKOVA Aranka": "CHALUPNÍKOVÁ Aranka",
                    'JANKOVÁ Karolina': 'JANKOVÁ Karolína',
                    "KAHABKOVA Eliska": "KAHABKOVÁ Eliška",
                    'KINCLOVÁ Ema': 'KINCLOVÁ Emma',
                    "KOCOURKOVA Marie": "KOCOURKOVÁ Marie",
                    'KOCOUROVÁ Marie': 'KOCOURKOVÁ Marie',     # ověřeno přes datum narození
                    'KOŘÍNKOVÁ Magdalena': 'KOŘÍNKOVÁ Magdaléna',
                    'KRAUSE Rebeka': 'KRAUSE Rebekka',        # podle FB
                    'KŘEČKOVÁ Kamila_Marie': 'KŘEČKOVÁ Kamila',  # naší Kamče jsem zkrátil jméno)
                    "KUHNOVA Korolína": "KÜHNOVÁ Karolína",   # pravděpodobně OK
                    "LASTOVKOVA Tereza": "LAŠTOVKOVÁ Tereza",
                    "MATEJCKOVA Lucie": "MATĚJČKOVÁ Lucie",
                    "MYSKOVA Petra": "MYŠKOVÁ Petra",
                    "NOVAKOVA Petra": "NOVÁKOVÁ Petra",
                    "PECHOVOVA Michala": "PĚCHOVOVÁ Michala",
                    "POKORNA Anna": "POKORNÁ Anna",
                    "POTOCKOVA Katerina": "POTOČKOVÁ Kateřina",
                    "PROKSIKOVA Patricie": "PROKŠÍKOVÁ Patricie",
                    'ROSKOVÁ Sonja_Maria': 'ROŠKOVÁ Sonja',        # zkrátil jsem jméno...
                    "SALIGEROVA Katerina": "SALIGEROVÁ Kateřina",
                    "SLUSNA Karolína": "SLUŠNÁ Karolína",
                    "SMIDOVA Daniela": "ŠMÍDOVÁ Daniela",
                    "SYROVATKOVA Iva": "SYROVÁTKOVÁ Iva",
                    'TODORYSHYNA Virkoriia': 'TODORYSHYNA Viktoriia',
                    "TUMOVA Šárka": "TŮMOVÁ Šárka",
                    'TYRPEKLOVÁ Amálie': 'TYRPEKLOVÁ Amélie',
                    "VACHOVA Tereza": "VÁCHOVÁ Tereza",
                    "VINCENCOVA Ester": "VINCENCOVÁ Ester",
                    "WEISOVA Katerrina": "WEISOVÁ Kateřina",
                    "ZIEGLEROVA Adéla Anna": "ZIEGLEROVÁ Adéla Anna"
            }

print(len(to_replace_woman))
df_m["Name"] = df_m["Name"].replace(to_replace_woman)
# Out:
# 47

# %% [markdown]
# ## I.3 - Ženy & změny příjmení
# * Dvě zbývají k ověření

# %%
df2 = df_m.groupby(['Name','Birthdate']).size().reset_index().rename(columns={0:'count'})

#vytáhne z groupby, který má 142 unikátních dvojic člověk-datum, počet výskytů datumů narození
df2["Birthdate"].value_counts().head(8) 

# troublemakers:
# 2000-03-05   2 -> OK, dvojčata Jasné
# 1989-10-11   2 -> VACÍNOVÁ Gabriela -> KORYCH Gabriela, klub sedí, nepřekrývají se, je mezi účastmi pauza...
# 1999-01-01   2 -> OK, nesouvisí
# 1997-10-04   2 -> ŠEDIVÁ Michaela -> SVOBODA Michaela, klub sedí, nepřekrývají se, je mezi účastmi pauza...
# 1995-07-31   2 -> ŠÁMALOVÁ Anna -> POKORNÁ Anna

df_m.loc[df_m.Name == "VACÍNOVÁ Gabriela", "Name"] = "KORYCH (VACÍNOVÁ) Gabriela" 
df_m.loc[df_m.Name == "KORYCH Gabriela", "Name"]   = "KORYCH (VACÍNOVÁ) Gabriela" 

df_m.loc[df_m.Name == "ŠEDIVÁ Michaela", "Name"]  = "SVOBODA (ŠEDIVÁ) Michaela" 
df_m.loc[df_m.Name == "SVOBODA Michaela", "Name"] = "SVOBODA (ŠEDIVÁ) Michaela" 

df_m.loc[df_m.Name == "ŠÁMALOVÁ Anna", "Name"] = "POKORNÁ (ŠÁMALOVÁ) Anna" 
df_m.loc[df_m.Name == "POKORNÁ Anna", "Name"]  = "POKORNÁ (ŠÁMALOVÁ) Anna"

# %%
# OPRAVA JMEN:
# Svoboda Tomáš st. = Tomáš Kristián
# Svoboda Tomáš ml. = Svoboda Tomáš


to_replace_man = {"ADAM Sykora" : "SÝKORA Adam Herbert",
             "ADDO DJAN Theodor": "ADDO DJAN Theodor Ezekiel",
             "ARTAZOV Maxmilian": "ARTAZOV Maxmilián",
             "BOSAK Stepan": "BOSÁK Štěpán",
             "BEDNAR Kryštof":"BEDNÁR Kryštof",  ##?##
             "BRADAC Petr": "BRADÁČ Petr",
             "CAPEK Martin": "ČAPEK Martin",
             "CUPR Michal": "ČUPR Michal",
             "D´AMICO Kristian": "D'AMICO Kristian",
             "DOLEJSI Marek": "DOLEJŠÍ Marek",
             "DUDUC Alex": "DUDUC Alex Vladimír", ##?##
             "DUDUC Alex Vladimir": "DUDUC Alex Vladimír",
             "DUDUC Alex_Vladimír": "DUDUC Alex Vladimír",
             "ERNEÉ Jan":"ERNÉE Jan",
             "FOLDES Tomáš": "FÖLDES Tomáš",
             "HLAVAC Jakub": "HLAVÁČ Jakub",
             "HOBAUS Max": "HÖBAUS Max",
             "HORBACHUCK Yuriy": "HORBACHUK Yuriy",
             "HORBACHUCK Jurij": "HORBACHUK Yuriy",
             "IVANCO Alexander": "IVANČO Alexandr",  ## Alexander -> Alexandr
             "IVANCO Robin": "IVANČO Robin",
             "IVANCO Mikuláš": "IVANČO Mikuláš",
             "JANU Gael": "JANŮ Gael",
             "JILEK Jaroslav": "JÍLEK Jaroslav",
             "KOURIL Jan": "KOUŘIL Jan",
             "KRUZECKY Tomáš": "KROUŽECKÝ Tomáš",  ##?##
             "KUCHAR Matěj": "KUCHAŘ Matěj",
             "LANIK Jan": "LÁNÍK Jan",
             "LOKAJ Vaclav": "LOKAJ Václav",
             "LUSTICKY Josef": "LUŠTICKÝ Josef",
             "MOTALIK Libor": "MOTALÍK Libor",
             "NOVAK Martin": "NOVÁK Martin",
             "PAVLIK Matyáš": "PAVLÍK Matyáš",
             "PROCHAZKA Ondřej": "PROCHÁZKA Ondřej",
             "PUSTEJOVSKY Vladimír": "PUSTĚJOVSKÝ Vladimír",
             "RUBES Martin": "RUBEŠ Martin",
             "ŘEZANKA_ST. Ota": "ŘEZANKA Ota",
             'SADSKY Jaroslav': 'SADSKÝ Jaroslav',
             "SKROVNY Petr": "SKROVNÝ Petr",
             "SMITKA Jan": "SMÍTKA Jan",
             "SMRCEK Šimon": "SMRČEK Šimon",
             "STIRBER Sebastian": "STIRBER Sebastián",
             "SVOBODA Tomáš_St.": "SVOBODA Tomáš Kristián",
             "SVOBODA Tomáš_st.": "SVOBODA Tomáš Kristián",
             "SVOBODA Tomáš_ml.": "SVOBODA Tomáš",
             "SVOBODA Tomáš_Ml.": "SVOBODA Tomáš",
             "ŠILHAN Jindřich": "ŠILHÁN Jindřich",
             "ŠTVERAK Martin": "ŠTVERÁK Martin",
             "TABORSKY Lukas": "TÁBORSKÝ Lukáš",
             "TKAČENKO Danil": "TKACHENKO Danil",
             "TUMA Marek": "TŮMA Marek",
             "VACHOVEC Matej": "VACHOVEC Matěj",
             "VALKOVIC Martin": "VALKOVIČ Martin",
             "VONDRA Matous":"VONDRA Matouš"
                }
                  
print(len(to_replace_man))

df_m["Name"] = df_m["Name"].replace(to_replace_man)
# Out:
# 54

# %%
pd.options.display.max_rows = 999
printbold(str(len(df_m["Name"].unique())))
# Out:
# 250

# %%
print(sorted(df_m["Name"].unique()))
# Out:
# ['ADAM Ondřej', 'ADDO DJAN Theodor Ezekiel', 'AIGERMAN František', 'AIGERMAN Oliver', 'ALMER Vojtěch', 'ANDERLE Petr', 'ARTAZOV Maxmilián', 'BALCAR Josef', 'BAUER Jiří', 'BEDNÁR Kryštof', 'BELL Tristen', 'BERAN Jiří', 'BERKA Adam', 'BILKO Martin', 'BINICHAKIS Emannouil', 'BODÓ Jiří', 'BOSÁK Štěpán', 'BRADÁČ Petr', 'BRYKNER Matyáš', 'BURDA Miroslav', 'BUREŠ Lukáš', 'BÉREŠ Daniel', 'BÓR Karel', 'BĚLOHOUBEK Matouš', 'CAICEDO Fabia', 'CHLEBÍK Michal', 'CHOUN Karím', 'CIBULKA Martin', 'CIMLER Čestmír', 'CIMPA Miroslav', 'COUFAL František', 'CVIEK Wojciech', "D'AMICO Kristian", 'DITRICH Jan', 'DOLEJŠÍ Marek', 'DOŠEK Jiří', 'DUDUC Alex Vladimír', 'DUDUC Alex_Vladimír', 'DUNAYTCEV Vladimír', 'DURYCH Martin', 'DÁŇA Vojtěch', 'ERNÉE Jan', 'FIEDOR Michal', 'FRANK Kilián', 'FÖLDES Tomáš', 'GAISLER Jakub', 'GASCON Willian', 'GENZER Jiří', 'GERŽA Jakub', 'GIL Matyáš', 'GRUMMICH Petr', 'HABARTA Ondřej', 'HAVRÁNEK Michal', 'HERDA Jan', 'HEREY Anatoliy', 'HLAVA Marek', 'HLAVÁČ Jakub', 'HORBACHUCK Jurij', 'HORBACHUK Yuriy', 'HOUŠKA Filip', 'HOYER Martin', 'HRADEČNÝ Vojtěch', 'HRONEK Ondřej', 'HÖBAUS Max', 'IVANČO Alexandr', 'IVANČO Mikuláš', 'IVANČO Robin', 'JAMBOR Stanislav', 'JANŮ Gael', 'JAVAKHISHVILI Georgii', 'JEŘÁBEK Petr', 'JINDRA Jakub', 'JINDRA Jan', 'JIRAN Jan', 'JURKA Jakub', 'JURKA Tomáš', 'JURÁŇ Jiri', 'JURÁŇ Jiří', 'JÍLEK Jaroslav', 'JŮN Tadeáš', 'KAIL Daniel', 'KALINA Jiří', 'KALUS Jonáš', 'KAPRAL Martin', 'KAPRÁČ Martin', 'KARDASZEWICZ Jan', 'KAREL Petr', 'KARÁSEK Libor', 'KAŠE Štěpán', 'KAŠPAR Daniel', 'KEDER Michal', 'KLAUS Robert', 'KLSÁK Adam', 'KNAP Ladislav', 'KNOP Tadeáš', 'KOLBE Stanislav', 'KONEČNÝ Antonín', 'KORBA Matyáš', 'KOTALA Jan', 'KOUŘIL Jan', 'KOVACKI Milos', 'KOVAŘÍK Tomáš', 'KRACMAN Tomáš', 'KRAJSA Tomáš', 'KROUŽECKÝ Tomáš', 'KRÁL Jiří', 'KUCERA Kristian', 'KUCHAŘ Matěj', 'KUF Jan', 'KULT Pavel', 'KULÍK Milan', 'KURÁŇ Martin', 'KUČERA Jan', 'KŘÍŽ Petr', 'LEVI Josef', 'LEVY Josef', 'LIBICH Vladimír', 'LIMARDO Francisco', 'LIMARDO Jesus', 'LIMARDO Ruben', 'LOKAJ Václav', 'LORENC Adam', 'LUCOVIČ Matěj', 'LUGO Grabiel', 'LUKEŠ Matěj', 'LUŠTICKÝ Josef', 'LÁNÍK Jan', 'MAJGIER Sebastian', 'MALEČEK Jakub', 'MALÝ Vojtěch', 'MATOUŠEK David', 'MAZANEC Matěj', 'MAZANEC Vojtěch', 'MAŇÁK Jiří', 'MAŠATA Vojtěch', 'METZNER Andreas', 'MICHALAK Damian', 'MIGAS Piotr', 'MIROVSKÝ Vojtěch', 'MIČINEC Adam', 'MONCADA Alejandro', 'MOTALÍK Libor', 'MRÁZ Pavel', 'MUSIL Tomáš', 'MÜNZBERGER Vladimír', 'NAVRÁTIL Jindřich', 'NECHAY Pavel', 'NOVOTNÝ Šimon', 'NOVÁK Martin', 'NÁROVEC Václav', 'OCHEC Prokop', 'OMELKA Antonín', 'OMELKA Jakub', 'OSIČKA Adam', 'PATOČKA Marek', 'PAVLÍK Matyáš', 'PIKOUS Matouš', 'PITRA Pavel', 'PLÁTEK Daniel', 'POHNAN Kryštof', 'POKORNÝ Jan', 'POKORNÝ Richard', 'POŠTA Marek', 'PROCHÁZKA Ondřej', 'PRYL Dobromil', 'PULIDO Diego', 'PUR Lukáš', 'PUSTĚJOVSKÝ Vladimír', 'PÁTEK Ondřej', 'RANDÁK Richard', 'ROGUSKI Tomasz', 'RUBEŠ Martin', 'RUSIN Illia', 'SADSKÝ Jaroslav', 'SALAČ Vojtěch', 'SALZER Jiří', 'SALZER Matěj', 'SCHÖPPEL Karel', 'SEDLÁK Petr', 'SEDLÁČEK Ondřej', 'SEJKORA Adam', 'SKROVNÝ Petr', 'SMRČEK Šimon', 'SMUTNÝ Richard', 'SMÍTKA Jan', 'SNOPEK Miroslav', 'SOCHOR František', 'SOKOL Vratislav', 'SOKOLOV Sevastyan', 'STASZULONEK Bartosz', 'STEHLÍK Jan', 'STEHLÍK Vojtěch', 'STEIS Matúš', 'STEMPEL Jan', 'STIRBER Sebastián', 'STOLAR Samuel', 'STRAKA Tomáš', 'STUDENÝ Václav', 'STYMNE Jakob', 'SURMA Štěpán', 'SVOBODA 67 Tomas', 'SVOBODA Bohumil Jiří', 'SVOBODA Ivo', 'SVOBODA Jakub', 'SVOBODA ST Tomáš', 'SVOBODA Tomáš', 'SVOBODA Tomáš Kristián', 'SVOBODA_ML Tomáš', 'SVOBODA_ST Tomáš', 'SZALAY Jan', 'SÝKORA Adam Herbert', 'TKACHENKO Danil', 'TOMAN Jan', 'TOMAN Štěpán', 'TOMÁŠEK Vlastimil', 'TREFILÍK Jakub', 'TÁBORSKÝ Lukáš', 'TŮMA Jan', 'TŮMA Marek', 'VACH Daniel', 'VACHOVEC Matěj', 'VALENTA Jiří', 'VALKOVIČ Martin', 'VASIC Filip', 'VAVRA Miroslav', 'VAŠÍČEK Martin', 'VIKOV Atrtěm', 'VLACH Šimon', 'VOKÁČ František', 'VOLÁK Samuel', 'VONDRA Matouš', 'VÁVRA Antonín', 'VÁVRA Miroslav', 'VÁVRA Vojtěch', 'VÍTEK Daniel', 'WA ...

# %% [markdown]
# ## I.4 - Duplicity v Klubech
# * Vždy je diskutabilní, který název klubu je ten správný..beru nejdelší
# * vyřešit kluby: "UKRAJINA", "SVK", "GEO", ...
# * jeden sporný: ASBVA = Akademie šermu Bratislava??
#
# ## I.4.1 -  Lidé, co změnili Klub:
# * **BRADÁČ Petr**: TJ LOKO PLZEN  ->  USK PRAHA
# * **CIMLER**: Bohemka -> RIEGEL PRAHA
# * **DUDUC Alex_Vladimír**: BA MPC BRATISLAV -> BSK MARTINENGO
# * **HABARTA Ondřej**: SS UH.HRADISTE -> SC PRAHA
# * **KRAJSA**: SLAVOJ LITOMERICE -> TJ LOKO K.VARY
# * **TKACHENKO**: RUS -> SPORTOVNÍ ŠERM ZLÍN
#
# * **HUNČÁROVÁ**: KS SNINA
# * **CHEVALLIER**: BOHEMIANS -> VSK HUMANITA
# * **DOŠKOVÁ**: SLAVOJ LITOMERICE -> USK PRAHA
# * **FRDLÍKOVÁ**: BOHEMIANS -> VSK HUMANITA
# * **HUNČÁROVÁ**: KŠ SNINA -> SC PRAHA
# * **KOŘÍNKOVÁ Magdaléna**: SS UH.HRADISTE -> Dukla Olomouc
# * **LINDEROVÁ**: AŠ BR -> ASBVA   # možná to není změna..ale nevadí
# * **MIROVSKÁ**: USK PRAHA -> SC PRAHA
# * **ŠÁMALOVÁ** USK PRAHA -> VSK HUMANITA

# %%
df_m.loc[df_m.Name == "BRADÁČ Petr", "Club"] = "USK PRAHA"
df_m.loc[df_m.Name == "CIMLER Čestmír", "Club"] = "RIEGEL PRAHA"
df_m.loc[df_m.Name == "DUDUC Alex Vladimír", "Club"] = "BSK MARTINENGO"
df_m.loc[df_m.Name == "HABARTA Ondřej", "Club"] = "SC PRAHA"
df_m.loc[df_m.Name == "KRAJSA Tomáš", "Club"] = "TJ LOKO K.VARY"
df_m.loc[df_m.Name == "TKACHENKO Danil", "Club"] = "SPORTOVNÍ ŠERM ZLÍN"

df_m.loc[df_m.Name == "CHEVALLIER Vira", "Club"] = "VSK HUMANITA"
df_m.loc[df_m.Name == "DOŠKOVÁ Kateřina", "Club"] = "USK PRAHA"
df_m.loc[df_m.Name == "FRDLÍKOVÁ Markéta", "Club"] = "VSK HUMANITA"
df_m.loc[df_m.Name == "HUNČÁROVÁ Katarína", "Club"] = "SC PRAHA"
df_m.loc[df_m.Name == "KOŘÍNKOVÁ Magdaléna", "Club"] = "DUKLA OLOMOUC" 
df_m.loc[df_m.Name == "LINDEROVÁ Nina", "Club"] = "ASBVA" 
df_m.loc[df_m.Name == "MIROVSKÁ Eliška", "Club"] = "SC PRAHA" 
df_m.loc[df_m.Name == "POKORNÁ (ŠÁMALOVÁ) Anna", "Club"] = "VSK HUMANITA"

# %%
to_replace_club = {
    "LOKO K.VARY": "TJ LOKO K.VARY",    ####
    "LOKO KV": "TJ LOKO K.VARY",    
    "TJLKV-ŠZ": "TJ LOKO K.VARY",  
    "LOKOK": "TJ LOKO K.VARY",
    
    "LOKO TEPLICE": "TJ LOKO TEPLICE",   ####
    "LOKO TP": "TJ LOKO TEPLICE",
    "TJLTZ": "TJ LOKO TEPLICE",
    "LOKOT": "TJ LOKO TEPLICE",
    
    "SCPŠS": "SC PRAHA",    ####
    "SCP": "SC PRAHA",
    
    "D.PRAHA": "TJ DUKLA PRAHA",  ####
    "DUKLA PRAHA": "TJ DUKLA PRAHA", 
    "TJDP": "TJ DUKLA PRAHA",
    "TJDPZ": "TJ DUKLA PRAHA",
    "D.PR": "TJ DUKLA PRAHA",
    
    "1.1.FC BĚLÁ": "1.FC BELA POD BEZ", ####
    "1.FC BĚLÁ": "1.FC BELA POD BEZ",
    "1.FC BELA": "1.FC BELA POD BEZ",
    "1.FCB": "1.FC BELA POD BEZ",
    "1.FCBPBZ": "1.FC BELA POD BEZ",
    
    "LOKO PLZ": "TJ LOKO PLZEN", ####
    "LOKO PLZEŇ": "TJ LOKO PLZEN",
    "TJLPZ": "TJ LOKO PLZEN",
    
    "S.PÍSEK": "TJ SOKOL PÍSEK", ###
    "TJ SOKOL PISEK": "TJ SOKOL PÍSEK" ,
    "SOKOL PÍSEK": "TJ SOKOL PÍSEK",
    
    "HF PRAHA": "VSK HUMANITA", ####
    "HUMANITA PHA": "VSK HUMANITA",
    "VSKHPZ": "VSK HUMANITA",
    "HUM": "VSK HUMANITA",
    
    "ČŠKRP": "RIEGEL PRAHA",  ####
    "ČESKŠKRZ": "RIEGEL PRAHA",
    "ČŠK RIEGEL": "RIEGEL PRAHA",
    "RIEGP": "RIEGEL PRAHA",
    
    "DUKLA OL": "DUKLA OLOMOUC",  ####
    "TĚLOJDOZ": "DUKLA OLOMOUC",
    "D.OL": "DUKLA OLOMOUC",
    "TJ DUKLA OLOMOU": "DUKLA OLOMOUC",
    "D.OLOMOUC": "DUKLA OLOMOUC",
    "Dukla Olomouc": "DUKLA OLOMOUC",
    
    "SL.LITOMĚŘICE": "SLAVOJ LITOMĚŘICE", ####
    "SLAVOJ LIT": "SLAVOJ LITOMĚŘICE",
    "SLAVOJ LITOMERIC": "SLAVOJ LITOMĚŘICE",
    "SL.L": "SLAVOJ LITOMĚŘICE",
    "SL. LITOMĚŘICE": "SLAVOJ LITOMĚŘICE",
    "SLAVOJ LITOMERICE": "SLAVOJ LITOMĚŘICE",
    "SLAVOJ LITOMĚŘIC": "SLAVOJ LITOMĚŘICE",
    "SLAVOJ LITOMERICE": "SLAVOJ LITOMĚŘICE",
    "SLAVLZ": "SLAVOJ LITOMĚŘICE",
    
    "S.S.UH.HRAD.": "SS UH.HRADISTE", ####
     "S.S.": "SS UH.HRADISTE",
    "TJSSUHZ": "SS UH.HRADISTE",
    
    "UNIVSKPS": "USK PRAHA", ####
    "USK PHA": "USK PRAHA",
    "USKP": "USK PRAHA",
    
    "J.H.BROD": "JISKRA H.BROD",  ####
    "HAV BROD": "JISKRA H.BROD",
    
    "SP.Š.ÚSTÍ/L.": "SČ USTI NAD LABEM", ####
    "SPŠ ÚSTÍ": "SČ USTI NAD LABEM",
    "SPORŠÚNLZ": "SČ USTI NAD LABEM",
    "SŠ USTI N. LABEM": "SČ USTI NAD LABEM",
    "SČ USTI NAD LABE": "SČ USTI NAD LABEM",
    "SP.Š": "SČ USTI NAD LABEM",
    
    "S.DEJVICE": "SOKOL DEJVICE", ####
    "S.DE": "SOKOL DEJVICE",
    "TJSPDI": "SOKOL DEJVICE", 
    
    "EKONOM": "EKONOM PRAHA", ####
    "VYSOTJEPZ": "EKONOM PRAHA",
    "EKONP": "EKONOM PRAHA",
    
    "BSKM": "BSK MARTINENGO", ####
    "BŠKMARTINENGO": "BSK MARTINENGO",
    
    "ŠERMLZ": "ŠERM LIBEREC", ####
    "SERM LIBEREC": "ŠERM LIBEREC",
    
    "SLOV HORKY": "TJ SLOVAN HORKY", ####
    "SLOVAN HORKY": "TJ SLOVAN HORKY", 
    "TĚLOJSHZ": "TJ SLOVAN HORKY",
    
    "TJSBI": "S.BRNO I",  ####
    "S.BRNO I": "SOKOL BRNO I",
    "S.BRNO I": "SOKOL BRNO I",
    
    "AKADSB": "AKADÉMIA ŠERMU BRATISLAVA",  ####
    
    "SLAV ČTĚŠ": "SLAVOJ Č.TĚŠÍN", ####
    "SLAVOJ TESIN": "SLAVOJ Č.TĚŠÍN",
    "SL.Č.TĚŠÍN": "SLAVOJ Č.TĚŠÍN",
    "TJSČTZ": "SLAVOJ Č.TĚŠÍN",
    
    "OREL HK": "OREL HR.KR.", ####
    "ORELJHK": "OREL HR.KR.",
    
    "SP.Š. TÁBOR": "SPORTOVNÍ ŠERM TÁBOR", ####
    "SP Š TÁBOR": "SPORTOVNÍ ŠERM TÁBOR",
    "SP.Š.TÁBOR": "SPORTOVNÍ ŠERM TÁBOR",
    "ŠERM TÁBOR": "SPORTOVNÍ ŠERM TÁBOR",
    "TABOR": "SPORTOVNÍ ŠERM TÁBOR",
    ###   
    "LOKOP": "TJ LOKO PLZEN",
    "OREL H.K." : "OREL HR.KR.",
    "SPORT. ŠERM ZLÍN": "SPORTOVNÍ ŠERM ZLÍN",
    "SPORŠZZ": "SPORTOVNÍ ŠERM ZLÍN",
    "SP PLZEŇ": "SOKOL PLZEŇ",
    "SOKOL PLZEN": "SOKOL PLZEŇ",
    "BOHEP": "BOHEMIANS",
    "KS SNINA": "KŠ SNINA",  # Klub šermu snina
    "AŠ BR": "AŠ BRATISLAVA"
            }

# %%
df_m["Club"] = df_m["Club"].replace(to_replace_club)

# %%
men_clubs = df_m.groupby(['Name','Club']).size().reset_index().rename(columns={0:'count'})
# .size() vs .count(), zajímavé

printbold(str(len(men_clubs)))
#men_clubs
# Out:
# 267

# %% [markdown]
# ## I.5 -  Duplicity v Datumech narození - NEJASNE
# * předpoklad - kdo má 1.1., tak datum nejdřív nevěděli, později doplnili
# * toto aplikuji sem: BALCAR Josef, BEDNÁR Kryštof, GRUMMICH Petr, HEREY Anatoliy,JAVAKHISHVILI Georgii, MIČINEC Adam, NOVOTNÝ Šimon, STEHLÍK Jan, STOLAR Samuel, VÁVRA Vojtěch,
# * DUDUC Alex Vladimir (má 3 různé - zatím volím 1.6.97)
# * GAISLER Jakub (jiný měsíc - zatím volím 29.4., byl víckrát, shodně s exportem Mužů)
# * KURÁŇ Martin (stále o den - zatím volím 24.8., shodně s exportem Mužů)
# * Stehlík Vojtěch - na webu 2001, ale v Lázenském poháru 2011 = to musí být error
# * SVOBODA Bohumil Jiří - dva různé datumy, volím ten častější 2003-03-17
#
# #### ženy
# * 1.1. vs. Jiné datum: CHEVALLIER Vira, COUFALOVÁ Anna, JASNÁ Adéla, JASNÁ Tereza, JELÍNKOVÁ Martina, KRAUSE Rebekka, KŘEČKOVÁ Kamila,
# * PROKŠÍKOVÁ Patricie, ROŠKOVÁ Sonja, SALIGEROVÁ Kateřina, SYROVÁTKOVÁ Iva, VACKOVÁ Tereza, VOLÁKOVÁ Hana, VRŠNÍKOVÁ Karolína, ŠPATENKOVÁ Anna
# * DOŠKOVÁ Kateřina - Dvě různé, volím to častější (1999-12-22)
# * NOVOTNÁ Veronika - dvě různé, to častější a dávající smysl (2000-11-11)
# * URBÁNKOVÁ Klára - dvě různé, to častější (2005-05-04)

# %%
men_birthdates = df_m.groupby(['Name','Birthdate']).size().reset_index().rename(columns={0:'count'})
printbold(str(len(men_birthdates)))
print(len(men_birthdates))
# Out:
# 270
# 270

# %%
## Problémisti:

df2 = df_m.groupby(['Name','Birthdate']).size().reset_index().rename(columns={0:'count'})
df2 = df2[["Name", "Birthdate"]]
#display(df2)
v = df2.Name.value_counts()   # kolikrát se jméno objevuje v našem Name-Birthdate groupáči, kde jsou unikátní dvojice
df2[df2.Name.isin(v.index[v.gt(1)])]  # nevím co je to v.gt(1), ale 1 v tuto chvíli říká 2 a více výskytů :D
# Out:
#                       Name  Birthdate
# 7             BALCAR Josef 1998-01-01
# 8             BALCAR Josef 1998-10-31
# 10          BEDNÁR Kryštof 1997-01-01
# 11          BEDNÁR Kryštof 1997-04-02
# 37     DUDUC Alex Vladimír 1997-01-01
# 38     DUDUC Alex Vladimír 1997-04-12
# 39     DUDUC Alex Vladimír 1997-06-01
# 40     DUDUC Alex Vladimír 1997-08-25
# 49           GAISLER Jakub 2005-04-29
# 50           GAISLER Jakub 2005-05-29
# 54           GRUMMICH Petr 1991-01-01
# 55           GRUMMICH Petr 1991-11-20
# 59          HEREY Anatoliy 1989-01-01
# 60          HEREY Anatoliy 1989-03-31
# 72            IVANČO Robin 1999-01-01
# 73            IVANČO Robin 1999-10-08
# 76   JAVAKHISHVILI Georgii 1999-01-01
# 77   JAVAKHISHVILI Georgii 1999-05-05
# 81               JIRAN Jan 1996-01-01
# 82               JIRAN Jan 1996-07-31
# 83             JURKA Jakub 1999-01-01
# 84             JURKA Jakub 1999-06-13
# 85             JURKA Tomáš 1997-01-01
# 86             JURKA Tomáš 1997-01-20
# 121           KURÁŇ Martin 2005-08-23
# 122           KURÁŇ Martin 2005-08-24
# 138          MAZANEC Matěj 1998-01-01
# 139          MAZANEC Matěj 1998-03-02
# 147           MIČINEC Adam 1991-01-01
# 148           MIČINEC Adam 1991-07-01
# 155          NOVOTNÝ Šimon 2006-01-01
# 156          NOVOTNÝ Šimon 2006-05-17
# 162            OSIČKA Adam 2000-01-01
# 163            OSIČKA Adam 2000-10-22
# 174          PRYL Dobromil 1975-01-01
# 175          PRYL Dobromil 1975-05-06
# 200            STEHLÍK Jan 1999-01-01
# 201            STEHLÍK Jan 1999-02-28
# 206          STOLAR Samuel 1998-01-01
# 207          STOLAR Samuel 1998-06-16
# 213   SVOBODA Bohumil Jiří 2003-01-20
# 214   SVOBODA Bohumil Jiří 2003-03-17
# 222             SZALAY Jan 1992-01-01
# 223             SZALAY Jan 1992-06-29
# 225        TKACHENKO Danil 2000-01-01
# 226        TKACHENKO Danil 2000-10-31
# 231         TÁBORSKÝ Lukáš 2004-01-01
# 232         TÁBORSKÝ Lukáš 2004-06-03
# 235            VACH Daniel 2005-01-01
# 236            VACH Daniel 2005-07-23
# 250          VÁVRA Vojtěch 1996-01-01
# 251          VÁVRA Vojtěch 1996-11-19

# %%
## MANUÁLNÍ OPRAVA Muži

df_m.loc[df_m.Name == "BALCAR Josef", "Birthdate"] = "1998-10-31"
df_m.loc[df_m.Name == "BEDNÁR Kryštof", "Birthdate"] = "1997-04-02"
df_m.loc[df_m.Name == "DUDUC Alex Vladimír", "Birthdate"] = "1997-06-01"
df_m.loc[df_m.Name == "GAISLER Jakub", "Birthdate"] = "2005-04-29"
df_m.loc[df_m.Name == "GRUMMICH Petr", "Birthdate"] = "1991-11-20"
df_m.loc[df_m.Name == "HEREY Anatoliy", "Birthdate"] = "1989-03-31"
df_m.loc[df_m.Name == "JAVAKHISHVILI Georgii", "Birthdate"] = "1999-05-05"
df_m.loc[df_m.Name == "KURÁŇ Martin", "Birthdate"] = "2005-08-24"
df_m.loc[df_m.Name == "MIČINEC Adam", "Birthdate"] = "1991-07-01"
df_m.loc[df_m.Name == "NOVOTNÝ Šimon", "Birthdate"] = "2006-05-17"
df_m.loc[df_m.Name == "STEHLÍK Jan", "Birthdate"] = "1999-02-28"
df_m.loc[df_m.Name == "STOLAR Samuel", "Birthdate"] = "1998-06-16"
df_m.loc[df_m.Name == "VÁVRA Vojtěch", "Birthdate"] = "1996-11-19"
df_m.loc[df_m.Name == "STEHLÍK Vojtěch", "Birthdate"] = "2001-11-07"
df_m.loc[df_m.Name == "SVOBODA Bohumil Jiří", "Birthdate"] = "2003-03-17"

# ??
df_m.loc[df_m.Name == "IVANČO Robin", "Birthdate"] = "1999-10-08"
df_m.loc[df_m.Name == "JIRAN Jan", "Birthdate"] = "1996-07-31"
df_m.loc[df_m.Name == "JURKA Jakub", "Birthdate"] = "1999-06-13"
df_m.loc[df_m.Name == "JURKA Tomáš", "Birthdate"] = "1997-01-20"
df_m.loc[df_m.Name == "MAZANEC Matěj", "Birthdate"] = "1998-03-02"
df_m.loc[df_m.Name == "OSIČKA Adam", "Birthdate"] = "2000-10-22"
df_m.loc[df_m.Name == "PRYL Dobromil", "Birthdate"] = "1975-05-06"
df_m.loc[df_m.Name == "TKACHENKO Danil", "Birthdate"] = "2000-10-31"

# %%
## MANUÁLNÍ OPRAVA Ženy

df_m.loc[df_m.Name == "CHEVALLIER Vira", "Birthdate"] = "1992-12-18"
df_m.loc[df_m.Name == "COUFALOVÁ Anna", "Birthdate"] = "2000-04-01"
df_m.loc[df_m.Name == "DOŠKOVÁ Kateřina", "Birthdate"] = "1999-12-22"
df_m.loc[df_m.Name == "JASNÁ Adéla", "Birthdate"] = "2000-03-05"
df_m.loc[df_m.Name == "JASNÁ Tereza", "Birthdate"] = "2000-03-05"
df_m.loc[df_m.Name == "JELÍNKOVÁ Martina", "Birthdate"] = "1998-03-09"
df_m.loc[df_m.Name == "KRAUSE Rebekka", "Birthdate"] = "2000-12-27"
df_m.loc[df_m.Name == "KŘEČKOVÁ Kamila", "Birthdate"] = "1997-09-08"
df_m.loc[df_m.Name == "NOVOTNÁ Veronika", "Birthdate"] = "2000-11-11"
df_m.loc[df_m.Name == "PROKŠÍKOVÁ Patricie", "Birthdate"] = "2002-07-07"
df_m.loc[df_m.Name == "ROŠKOVÁ Sonja", "Birthdate"] = "2000-02-10"
df_m.loc[df_m.Name == "SALIGEROVÁ Kateřina", "Birthdate"] = "1999-06-14"
df_m.loc[df_m.Name == "SYROVÁTKOVÁ Iva", "Birthdate"] = "1998-11-02"
df_m.loc[df_m.Name == "URBÁNKOVÁ Klára", "Birthdate"] = "2005-05-04"
df_m.loc[df_m.Name == "VACKOVÁ Tereza", "Birthdate"] = "1991-12-04"
df_m.loc[df_m.Name == "VOLÁKOVÁ Hana", "Birthdate"] = "2002-07-04"
df_m.loc[df_m.Name == "VRŠNÍKOVÁ Karolína", "Birthdate"] = "1991-04-02"
df_m.loc[df_m.Name == "ŠPATENKOVÁ Anna", "Birthdate"] = "1999-09-26"

# %% [markdown]
# ## I.6 - Kontrola zemí
#
# * DUDUC Alex Vladimir & STEIS Matúš - oba víckrát SVK než CZE -> SVK
# * CHEVALLIER Vira = CZE podle většiny
# * HUNČÁROVÁ Katarína - má to tak půl napůl -> novější =  SVK
# * TODORYSHYNA Viktoriia - půl napůl -> novější = UKR
# * YOUSEF Mira - půl napůl -> novější = UKR

# %%
men_countries = df_m.groupby(['Name','Club', "Country", "Sex", "Birthdate"]).size().reset_index().rename(columns={0:'count'})
printbold(str(len(men_countries)))
#men_countries
# Out:
# 264

# %%
df_m.loc[df_m.Name == "DUDUC Alex Vladimír", "Country"] = "SVK"
df_m.loc[df_m.Name == "STEIS Matúš", "Country"] = "SVK"
df_m.loc[df_m.Name == "BÉREŠ Daniel", "Country"] = "CZE"

df_m.loc[df_m.Name == "CHEVALLIER Vira", "Country"] = "CZE"
df_m.loc[df_m.Name == "HUNČÁROVÁ Katarína", "Country"] = "SVK"
df_m.loc[df_m.Name == "TODORYSHYNA Viktoriia", "Country"] = "UKR"
df_m.loc[df_m.Name == "YOUSEF Mira", "Country"] = "UKR"

# %% [markdown]
# ## I.7 - Kontrola Final Ranků
# * otázka: čím nahradit DNF? 99 ? 999? Pomlčkou, a pak vynechávat?

# %%
df_m["Final_rank"].value_counts()

df_m["Final_rank"] = df_m["Final_rank"].replace({"DNF": 999})

# %%
df_m[df_m.Name == "JURKA Jakub"]  # opravdu, má dvě čisté výhry turnajů
# Out:
#             Name           Club Country  Birthdate       Date  \
# 92   JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2019-05-25
# 162  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2019-10-26
# 244  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2019-11-09
# 313  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2019-12-14
# 385  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2020-02-22
# 452  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2021-09-26
# 523  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2021-10-23
# 600  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2021-11-06
# 894  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2022-05-21
# 972  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2022-10-22
#
#                       Event Sex Rank First_rank  Final_rank     Notes
# 92                      MCR   M    1          1           1  Advanced
# 162          Lázeňský pohár   M  1.0          2           2  Advanced
# 244  Zlatý kord města Písku   M  NaN          1           5  Advanced
# 313                Memorial   M  NaN          6           1  Advanced
# 385           Dukla Olomouc   M    1          7          10  Advanced
# 452                     MCR   M    1          2           1  Advanced
# 523          Lázeňský pohár   M  1.0          1           1  Advanced
# 600  Zlatý kord města Písku   M    1          4           1  Advanced
# 894                 MČR USK   M    2          5           1  Advanced
# 972          Lázeňský pohár   M  1.0          1           1  Advanced

# %%
# seřazeno podle průměrného Final_ranku přes všechyn jejich závody
# samozřemě DNF = 999 mi to pokazí

df_m.groupby('Name')['Final_rank'].mean().round().sort_values()
# Out:
# Name
# LIMARDO Francisco              1.0
# JURKA Jakub                    2.0
# MICHALAK Damian                3.0
# RUBEŠ Martin                   5.0
# BERAN Jiří                     5.0
# ČUPR Michal                    6.0
# HEREY Anatoliy                 6.0
# LIMARDO Ruben                  7.0
# ČAPEK Martin                   8.0
# POKORNÝ Richard                9.0
# PITRA Pavel                    9.0
# PAVLÍK Matyáš                  9.0
# BALCAR Josef                   9.0
# STYMNE Jakob                   9.0
# JAVAKHISHVILI Georgii         10.0
# BRYKNER Matyáš                10.0
# D'AMICO Kristian              10.0
# DUDUC Alex Vladimír           11.0
# KUF Jan                       12.0
# HABARTA Ondřej                12.0
# SALZER Matěj                  13.0
# COUFAL František              13.0
# LIMARDO Jesus                 13.0
# KLAUS Robert                  14.0
# VACHOVEC Matěj                15.0
# MAJGIER Sebastian             17.0
# SZALAY Jan                    17.0
# KOVACKI Milos                 18.0
# OSIČKA Adam                   18.0
# LUGO Grabiel                  19.0
# DOLEJŠÍ Marek                 19.0
# SOCHOR František              20.0
# STEHLÍK Jan                   20.0
# BILKO Martin                  20.0
# PLÁTEK Daniel                 23.0
# TOMAN Jan                     24.0
# KAPRAL Martin                 24.0
# PULIDO Diego                  24.0
# POHNAN Kryštof                25.0
# KAŠE Štěpán                   25.0
# CAICEDO Fabia                 25.0
# ŠVANDA Pavel                  26.0
# VOLÁK Samuel                  26.0
# DÁŇA Vojtěch                  26.0
# ERNÉE Jan                     26.0
# JINDRA Jakub                  26.0
# STOLAR Samuel                 26.0
# SVOBODA Bohumil Jiří          28.0
# JANŮ Gael                     28.0
# KULT Pavel                    28.0
# GASCON Willian                28.0
# STIRBER Sebastián             28.0
# KAŠPAR Daniel                 28.0
# HOUŠKA Filip                  28.0
# STASZULONEK Bartosz           29.0
# IVANČO Alexandr               29.0
# CHLEBÍK Michal                29.0
# PROCHÁZKA Ondřej              29.0
# HORBACHUK Yuriy               30.0
# HLAVA Marek                   30.0
# JURKA Tomáš                   30.0
# KAPRÁČ Martin                 30.0
# ZHÁŇAL Petr                   30.0
# HLAVÁČ Jakub                  30.0
# MOTALÍK Libor                 30.0
# STRAKA Tomáš                  30.0
# ANDERLE Petr                  30.0
# MATOUŠEK David                31.0
# LOKAJ Václav                  31.0
# MUSIL Tomáš                   31.0
# ROGUSKI Tomasz                32.0
# KOUŘIL Jan                    32.0
# WALLER Jonáš                  32.0
# BERKA Adam                    32.0
# METZNER Andreas               32.0
# FIEDOR Michal                 33.0
# KALUS Jonáš                   34.0
# DITRICH Jan                   34.0
# DUDUC Alex_Vladimír           34.0
# SEDLÁČEK Ondřej               35.0
# SALZER Jiří                   35.0
# CHOUN Karím                   36.0
# VAŠÍČEK Martin                36.0
# KŘÍŽ Petr                     36.0
# DURYCH Martin                 36.0
# LÁNÍK Jan                     37.0
# NOVÁK Martin                  37.0
# STEIS Matúš                   37.0
# CVIEK Wojciech                38.0
# KLSÁK Adam                    38.0
# ŠPATENKA Martin               38.0
# IVANČO Robin                  39.0
# MIGAS Piotr                   39.0
# HOYER Martin                  39.0
# TŮMA Jan                      39.0
# VONDRA Matouš                 39.0
# BRADÁČ Petr                   39.0
# MAŠATA Vojtěch                40.0
# KOTALA Jan                    40.0
# KURÁŇ Martin                  41.0
# FÖLDES Tomáš                  42.0
# JAMBOR Stanislav              42.0
# BOSÁK Štěpán                  42.0
# KROUŽECKÝ Tomáš               43.0
# CIBULKA Martin                43.0
# MALEČEK Jakub                 43.0
# SVOBODA 67 Tomas              43.0
# SKROVNÝ Petr                  43.0
# KUČERA Jan                    43.0
# FRANK Kilián                  44.0
# KARÁSEK Libor                 44.0
# CIMLER Čestmír                44.0
# KNAP Ladislav                 44.0
# ADDO DJAN Theodor Ezekiel     44.0
# TKACHENKO Danil               45.0
# JŮN Tadeáš                    45.0
# KRAJSA Tomáš                  45.0
# WALLER Adam                   46.0
# BODÓ Jiří                     46.0
# BEDNÁR Kryštof                46.0
# LORENC Adam                   46.0
# VLACH Šimon                   47.0
# VÁVRA Vojtěch                 47.0
# BURDA Miroslav                47.0
# BUREŠ Lukáš                   47.0
# LUCOVIČ Matěj                 48.0
# SOKOL Vratislav               48.0
# JURÁŇ Jiri                    48.0
# TÁBORSKÝ Lukáš                48.0
# SEJKORA Adam                  49.0
# KUCHAŘ Matěj                  49.0
# SOKOLOV Sevastyan             49.0
# HORBACHUCK Jurij              49.0
# SALAČ Vojtěch                 49.0
# KEDER Michal                  50.0
# BELL Tristen                  50.0
# HRONEK Ondřej                 50.0
# KULÍK Milan                   50.0
# LEVY Josef                    50.0
# MIČINEC Adam                  50.0
# PRYL Dobromil                 51.0
# IVANČO Mikuláš                51.0
# VÁVRA Antonín                 51.0
# SMRČEK Šimon                  51.0
# GAISLER Jakub                 51.0
# KRÁL Jiří                     51.0
# SVOBODA ST Tomáš              52.0
# DOŠEK Jiří                    52.0
# SURMA Štěpán                  52.0
# SVOBODA Tomáš                 52.0
# SNOPEK Miroslav               52.0
# JEŘÁBEK Petr                  52.0
# TOMÁŠEK Vlastimil             53.0
# ŠILHÁN František              53.0
# NOVOTNÝ Šimon                 53.0
# GERŽA Jakub                   53.0
# VÍTEK Daniel                  53.0
# HERDA Jan                     53.0
# KARDASZEWICZ Jan              54.0
# ŠTVERÁK Martin                54.0
# JÍLEK Jaroslav                55.0
# TŮMA Marek                    55.0
# POKORNÝ Jan                   55.0
# SMÍTKA Jan                    56.0
# MONCADA Alejandro             57.0
# MALÝ Vojtěch                  57.0
# BINICHAKIS Emannouil          57.0
# KAREL Petr                    57.0
# MIROVSKÝ Vojtěch              58.0
# TREFILÍK Jakub                58.0
# MAŇÁK Jiří                    58.0
# SMUTNÝ Richard                58.0
# SVOBODA_ML Tomáš              59.0
# JINDRA Jan                    59.0
# RUSIN Illia                   59.0
# STEMPEL Jan                   60.0
# OMELKA Jakub                  60.0
# ŠTULÍŘ Pavel                  60.0
# HAVRÁNEK Michal               60.0
# KAIL Daniel                   60.0
# LEVI Josef                    60.0
# GENZER Jiří                   61.0
# STUDENÝ Václav                61.0
# VIKOV Atrtěm                  61.0
# PIKOUS Matouš                 61.0
# MÜNZBERGER Vladimír           62.0
# DUNAYTCEV Vladimír            62.0
# SVOBODA Tomáš Kristián        62.0
# JURÁŇ Jiří                    62.0
# VAVRA Miroslav                63.0
# VALKOVIČ Martin               63.0
# ŽIŽKA David                   63.0
# MAZANEC Matěj                 63.0
# BĚLOHOUBEK Matouš             63.0
# CIMPA Miroslav                63.0
# STEHLÍK Vojtěch               63.0
# ALMER Vojtěch                 64.0
# NÁROVEC Václav                64.0
# ZEMAN Jakub                   64.0
# KUCERA Kristian               65.0
# KORBA Matyáš                  65.0
# SADSKÝ Jaroslav               66.0
# PUR Lukáš                     66.0
# ŠŤASTNÝ Kristián              66.0
# ŠILHÁN Jindřich               66.0
# NECHAY Pavel                  67.0
# ARTAZOV Maxmilián             68.0
# SÝKORA Adam Herbert           68.0
# VACH Daniel                   68.0
# KNOP Tadeáš                   68.0
# LUKEŠ Matěj                   68.0
# NAVRÁTIL Jindřich             68.0
# JIRAN Jan                     68.0
# AIGERMAN Oliver               69.0
# KONEČNÝ Antonín               69.0
# GRUMMICH Petr                 70.0
# GIL Matyáš                    70.0
# BÓR Karel                     70.0
# VOKÁČ František               70.0
# VASIC Filip                   71.0
# LUŠTICKÝ Josef                71.0
# POŠTA Marek                   71.0
# SVOBODA Ivo                   72.0
# HÖBAUS Max                    74.0
# LIBICH Vladimír               74.0
# BÉREŠ Daniel                  75.0
# KALINA Jiří                   75.0
# ADAM Ondřej                   76.0
# SVOBODA_ST Tomáš              76.0
# BAUER Jiří                    76.0
# VÁVRA Miroslav                76.0
# WESELOWSKI Michal             76.0
# TOMAN Štěpán                  76.0
# SEDLÁK Petr                   78.0
# AIGERMAN František            79.0
# MRÁZ Pavel                    79.0
# VALENTA Jiří                  80.0
# SCHÖPPEL Karel                80.0
# RANDÁK Richard                81.0
# ZELENKA Jiří                  85.0
# KOLBE Stanislav               87.0
# OCHEC Prokop                  91.0
# KRACMAN Tomáš                 92.0
# PATOČKA Marek                 93.0
# HRADEČNÝ Vojtěch              94.0
# MAZANEC Vojtěch               96.0
# SVOBODA Jakub                 97.0
# PUSTĚJOVSKÝ Vladimír         141.0
# ŘEZANKA Ota                  188.0
# KOVAŘÍK Tomáš                219.0
# OMELKA Antonín               528.0
# PÁTEK Ondřej                 999.0
# Name: Final_rank, dtype: float64

# %% [markdown]
# ## I.8 - Finální Kontrola, na počet unikátních jedinců, pro porovnání se stávajícími excely:

# %%
df_m[df_m["Name"]== "BRADÁČ Petr"]
# Out:
#              Name           Club Country  Birthdate       Date  \
# 6     BRADÁČ Petr  TJ LOKO PLZEN     CZE 1996-04-30 2019-04-14
# 71    BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2019-05-25
# 137   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2019-10-26
# 218   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2019-11-09
# 285   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2019-12-14
# 364   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2020-02-22
# 426   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2021-09-26
# 508   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2021-10-23
# 578   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2021-11-06
# 658   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2021-12-18
# 873   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2022-05-21
# 953   BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2022-10-22
# 1032  BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2022-11-05
# 1111  BRADÁČ Petr      USK PRAHA     CZE 1996-04-30 2022-12-17
#
#                        Event Sex  Rank First_rank  Final_rank       Notes
# 6                     Ještěd   M  34.0         12          33    Advanced
# 71                       MCR   M    28         53          53  Eliminated
# 137           Lázeňský pohár   M  28.0         52          52    Advanced
# 218   Zlatý kord města Písku   M   NaN         27          25    Advanced
# 285                 Memorial   M   NaN         39          44    Advanced
# 364            Dukla Olomouc   M    38         27          24    Advanced
# 426                      MCR   M    33         21          34    Advanced
# 508           Lázeňský pohár   M  30.0         20          35    Advanced
# 578   Zlatý kord města Písku   M    30         43          47    Advanced
# 658                 Memorial   M  26.0         46          47    Advanced
# 873                  MČR USK   M    40         38          41    Advanced
# 953           Lázeňský pohár   M  41.0         46          46    Advanced
# 1032  Zlatý kord města Písku   M    43         31          37    Advanced
# 1111                Memorial   M    39         28          26    Advanced

# %%
df_fin = df_m.groupby(['Name','Birthdate', "Club", "Country"]).size().reset_index().rename(columns={0:'count'})
printbold(str(len(df_fin)))
df_fin
# Out:
# 253
#                           Name  Birthdate                       Club Country  \
# 0                  ADAM Ondřej 1993-08-26                   VUT BRNO     CZE
# 1    ADDO DJAN Theodor Ezekiel 2006-11-06              SOKOL DEJVICE     CZE
# 2           AIGERMAN František 1972-08-31            TJ LOKO TEPLICE     CZE
# 3              AIGERMAN Oliver 2006-12-03            TJ LOKO TEPLICE     CZE
# 4                ALMER Vojtěch 1997-12-24               EKONOM PRAHA     CZE
# 5                 ANDERLE Petr 1977-07-07               RIEGEL PRAHA     CZE
# 6            ARTAZOV Maxmilián 2002-03-09          SČ USTI NAD LABEM     CZE
# 7                 BALCAR Josef 1998-10-31            TJ LOKO TEPLICE     CZE
# 8                   BAUER Jiří 2002-12-13             TJ DUKLA PRAHA     CZE
# 9               BEDNÁR Kryštof 1997-04-02              SOKOL DEJVICE     CZE
# 10                BELL Tristen 2001-08-06             TJ DUKLA PRAHA     CZE
# 11                  BERAN Jiří 1982-01-18                   SC PRAHA     CZE
# 12                  BERKA Adam 1982-03-11             BSK MARTINENGO     CZE
# 13                BILKO Martin 1993-03-12             TJ DUKLA PRAHA     CZE
# 14        BINICHAKIS Emannouil 2001-03-20               ŠERM LIBEREC     GRE
# 15                   BODÓ Jiří 1953-04-01          SLAVOJ LITOMĚŘICE     CZE
# 16                BOSÁK Štěpán 1998-02-16                  USK PRAHA     CZE
# 17                 BRADÁČ Petr 1996-04-30                  USK PRAHA     CZE
# 18              BRYKNER Matyáš 2001-05-20                   SC PRAHA     CZE
# 19              BURDA Miroslav 1977-04-08             TJ SOKOL PÍSEK     CZE
# 20                 BUREŠ Lukáš 2005-05-01              DUKLA OLOMOUC     CZE
# 21                BÉREŠ Daniel 1993-12-01               EKONOM PRAHA     CZE
# 22                   BÓR Karel 2007-02-16               ŠERM LIBEREC     CZE
# 23           BĚLOHOUBEK Matouš 2003-05-12               RIEGEL PRAHA     CZE
# 24              CHLEBÍK Michal 1987-01-01             BŠK MARTINENGO     SVK
# 25                 CHOUN Karím 2005-09-05                   SC PRAHA     CZE
# 26              CIBULKA Martin 1972-04-30                   SC PRAHA     CZE
# 27              CIMLER Čestmír 1990-06-14               RIEGEL PRAHA     CZE
# 28              CIMPA Miroslav 1982-06-15       SPORTOVNÍ ŠERM TÁBOR     CZE
# 29            COUFAL František 2003-02-10          1.FC BELA POD BEZ     CZE
# 30              CVIEK Wojciech 1999-04-24               WARSZAWIANKA      PL
# 31            D'AMICO Kristian 1997-04-22                   SC PRAHA     CZE
# 32                 DITRICH Jan 1989-05-26             SS UH.HRADISTE     CZE
# 33               DOLEJŠÍ Marek 1993-12-12                   SC PRAHA     CZE
# 34                  DOŠEK Jiří 2004-06-23                  USK PRAHA     CZE
# 35         DUDUC Alex Vladimír 1997-06-01             BSK MARTINENGO     SVK
# 36          DUNAYTCEV Vladimír 1995-02-27              SOKOL DEJVICE     CZE
# 37               DURYCH Martin 1994-01-15             TJ DUKLA PRAHA     CZE
# 38                DÁŇA Vojtěch 2002-12-24             TJ DUKLA PRAHA     CZE
# 39                   ERNÉE Jan 1998-09-08                   SC PRAHA     CZE
# 40               FIEDOR Michal 2004-02-02                   SC PRAHA     CZE
# 41                FRANK Kilián 2003-03-14             TJ DUKLA PRAHA     CZE
# 42                FÖLDES Tomáš 1986-01-01              DUKLA OLOMOUC     CZE
# 43               GAISLER Jakub 2005-04-29            TJ LOKO TEPLICE     CZE
# 44                 GENZER Jiří 1978-05-05               EKONOM PRAHA     CZE
# 45                 GERŽA Jakub 1992-07-06        SPORTOVNÍ ŠERM ZLÍN     CZE
# 46                  GIL Matyáš 1999-09-06               VSK HUMANITA     CZE
# 47               GRUMMICH Petr 1991-11-20          SČ USTI NAD LABEM     CZE
# 48              HABARTA Ondřej 1992-03-10                   SC PRAHA     CZE
# 49             HAVRÁNEK Michal 1985-02-26               SOKOL BRNO I     CZE
# 50                   HERDA Jan 1957-07-26                  USK PRAHA     CZE
# 51              HEREY Anatoliy 1989-03-31             DYNAMO UŽHOROD     UKR
# 52                 HLAVA Marek 1997-04-29                  USK PRAHA     CZE
# 53                HLAVÁČ Jakub 1983-07-06              DUKLA OLOMOUC     CZE
# 54             HORBACHUK Yuriy 1972-05-07               ŠERM LIBEREC     CZE
# 55                HOUŠKA Filip 2001-12-07             TJ DUKLA PRAHA     CZE
# 56                HOYER Martin 1967-11-25                   SC PRAHA     CZE
# 57                HOYER Martin 1967-11-25                   SL HORKY     CZE
# 58                HOYER Martin 1967-11-25            TJ SLOVAN HORKY     CZE
# 59            HRADEČNÝ Vojtěch 1994-07-03               ŠERM MASTERS     CZE
# 60               HRONEK Ondřej 2007-12-16             TJ SOKOL PÍSEK     CZE
# 61                  HÖBAUS Max 2000-12-30               VSK HUMANITA     CZE
# 62             IVANČO Alexandr 1973-11-28          SČ USTI NAD LABEM     CZE
# 63              IVANČO Mikuláš 2001-06-08          SČ USTI NAD LABEM     CZE
# 64                IVANČO Robin 1999-10-08          SČ USTI NAD LABEM     CZE
# 65            JAMBOR Stanislav 1981-01-14             TJ LOKO K.VARY     CZE
# 66                   JANŮ Gael 2003-01-06              DUKLA OLOMOUC     CZE
# 67       JAVAKHISHVILI Georgii 1999-05-05                    TBILISI     GEO
# 68                JEŘÁBEK Petr 1984-06-10             SS UH.HRADISTE     CZE
# 69                JINDRA Jakub 2002-09-24              TJ LOKO PLZEN     CZE
# 70                  JINDRA Jan 1956-09-20                   SC PRAHA     CZE
# 71                  JINDRA Jan 1956-09-20             TJ DUKLA PRAHA     CZE
# 72                   JIRAN Jan 1996-07-31               EKONOM PRAHA     CZE
# 73                 JURKA Jakub 1999-06-13              DUKLA OLOMOUC     CZE
# 74                 JURKA Tomáš 1997-01-20              DUKLA OLOMOUC     CZE
# 75                  JURÁŇ Jiri 2003-01-01            TJ LOKO TEPLICE     CZE
# 76                  JURÁŇ Jiří 2003-09-14            TJ LOKO TEPLICE     CZE
# 77              JÍLEK Jaroslav 1968-07-03              TJ LOKO PLZEN     CZE
# 78                  JŮN Tadeáš 2002-05-12               RIEGEL PRAHA     CZE
# 79                 KAIL Daniel 2003-07-20                   SC PRAHA     CZE
# 80                 KALINA Jiří 1963-04-12                SOKOL PLZEŇ     CZE
# 81                 KALUS Jonáš 2002-11-23                   SC PRAHA     CZE
# 82               KAPRÁČ Martin 1993-01-01                   KŠ SNINA     CZE
# 83            KARDASZEWICZ Jan 2001-10-26              PIAST GLIWICZ     POL
# 84                  KAREL Petr 1974-09-22               ŠERM LIBEREC     CZE
# 85               KARÁSEK Libor 1984-04-12             SS UH.HRADISTE     CZE
# 86                 KAŠE Štěpán 1984-01-14              TJ LOKO PLZEN     CZE
# 87               KAŠPAR Daniel 1980-07-17             TJ DUKLA PRAHA     CZE
# 88                KEDER Michal 1991-12-24               EKONOM PRAHA     CZE
# 89                KLAUS Robert 2003-03-03                   SC PRAHA     CZE
# 90                  KLSÁK Adam 1991-06-25             TJ LOKO K.VARY     CZE
# 91               KNAP Ladislav 1978-10-21               ŠERM LIBEREC     CZE
# 92                 KNOP Tadeáš 2004-03-10               ŠERM LIBEREC     CZE
# 93             KOLBE Stanislav 1978-07-30               EKONOM PRAHA     CZE
# 94             KONEČNÝ Antonín 1996-12-24                   VUT BRNO     CZE
# 95                KORBA Matyáš 1999-08-31                SOKOL PLZEŇ     CZE
# 96                  KOTALA Jan 2004-11-08            TJ LOKO TEPLICE     CZE
# 97                  KOUŘIL Jan 1988-03-25             SS UH.HRADISTE     CZE
# 98               KOVACKI Milos 1996-01-01                        AUT     AUT
# 99               KOVAŘÍK Tomáš 1985-04-21             SS UH.HRADISTE     CZE
# 100              KRACMAN Tomáš 2006-07-19          1.FC BELA POD BEZ     CZE
# 101               KRAJSA Tomáš 1982-04-12             TJ LOKO K.VARY     CZE
# 102            KROUŽECKÝ Tomáš 2001-08-12              TJ LOKO PLZEN     CZE
# 103            KROUŽECKÝ Tomáš 2001-08-12                  USK PRAHA     CZE
# 104                  KRÁL Jiří 2004-06-30              DUKLA OLOMOUC     CZE
# 105            KUCERA Kristian 2005-01-01                SOKOL PLZEŇ     CZE
# 106               KUCHAŘ Matěj 2006-02-04                   SC PRAHA     CZE
# 107                    KUF Jan 1991-05-11             TJ DUKLA PRAHA     CZE
# 108                 KULT Pavel 1995-03-31                   SC PRAHA     CZE
# 109                KULÍK Milan 1984-12-06               ŠERM LIBEREC     CZE
# 110               KURÁŇ Martin 2005-08-24              DUKLA OLOMOUC     CZE
# 111                 KUČERA Jan 1949-04-02             TJ LOKO K.VARY     CZE
# 112                  KŘÍŽ Petr 1990-04-19               SOKOL BRNO I     CZE
# 113                 LEVI Josef 2000-05-31             TJ DUKLA PRAHA     CZE
# 114                 LEVY Josef 2000-05-31             TJ DUKLA PRAHA     CZE
# 115            LIBICH Vladimír 1950-04-19              SOKOL DEJVICE     CZE
# 116               LOKAJ Václav 1998-09-09                  USK PRAHA     CZE
# 117               LOKAJ Václav 1998-09-09               VSK HUMANITA     CZE
# 118                LORENC Adam 1984-07-18               EKONOM PRAHA     CZE
# 119              LUCOVIČ Matěj 2001-02-28             TJ LOKO K.VARY     CZE
# 120                LUKEŠ Matěj 2002-04-12             TJ DUKLA PRAHA     CZE
# 121             LUŠTICKÝ Josef 2004-11-17                OREL HR.KR.     CZE
# 122                  LÁNÍK Jan 1973-05-24          SČ USTI NAD LABEM     CZE
# 123          MAJGIER Sebastian 1995-10-26              PIAST GLIWICZ     POL
# 124              MALEČEK Jakub 2001-04-24             TJ DUKLA PRAHA     CZE
# 125               MALÝ Vojtěch 2006-04-07          1.FC BELA POD BEZ     CZE
# 126             MATOUŠEK David 2004-09-01              TJ LOKO PLZEN     CZE
# 127              MAZANEC Matěj 1998-03-02       SPORTOVNÍ ŠERM TÁBOR     CZE
# 128            MAZANEC Vojtěch 2003-11-16       SPORTOVNÍ ŠERM TÁBOR     CZE
# 129                 MAŇÁK Jiří 1994-05-25             TJ SOKOL PÍSEK     CZE
# 130             MAŠATA Vojtěch 2002-09-07             TJ LOKO K.VARY     CZE
# 131            METZNER Andreas 1962-12-27                USV DRESDEN     GER
# 132            MICHALAK Damian 1999-10-26              PIAST GLIWICZ     POL
# 133                MIGAS Piotr 2002-10-26              PIAST GLIWICZ     POL
# 134           MIROVSKÝ Vojtěch 1995-08-28                  USK PRAHA     CZE
# 135               MIČINEC Adam 1991-07-01             TJ DUKLA PRAHA     CZE
# 136              MOTALÍK Libor 1971-03-28              DUKLA OLOMOUC     CZE
# 137                 MRÁZ Pavel 1988-07-02              SOKOL DEJVICE     CZE
# 138                MUSIL Tomáš 2006-06-14              SOKOL DEJVICE     CZE
# 139        MÜNZBERGER Vladimír 1971-02-25             TJ DUKLA PRAHA     CZE
# 140          NAVRÁTIL Jindřich 1993-04-09                SOKOL PLZEŇ     CZE
# 141               NECHAY Pavel 2007-04-16                SOKOL PLZEŇ     CZE
# 142              NOVOTNÝ Šimon 2006-05-17               ŠERM LIBEREC     CZE
# 143               NOVÁK Martin 2004-05-04          1.FC BELA POD BEZ     CZE
# 144             NÁROVEC Václav 1989-03-07              DUKLA OLOMOUC     CZE
# 145             NÁROVEC Václav 1989-03-07                OREL HR.KR.     CZE
# 146               OCHEC Prokop 2003-06-06               ŠERM MASTERS     CZE
# 147             OMELKA Antonín 1993-03-12               VSK HUMANITA     CZE
# 148               OMELKA Jakub 1994-07-22                  SP.Š.ZLÍN     CZE
# 149               OMELKA Jakub 1994-07-22        SPORTOVNÍ ŠERM ZLÍN     CZE
# 150                OSIČKA Adam 2000-10-22              DUKLA OLOMOUC     CZE
# 151              PATOČKA Marek 1999-08-09                   VUT BRNO     CZE
# 152              PAVLÍK Matyáš 2000-09-13                   SC PRAHA     CZE
# 153              PIKOUS Matouš 1994-04-16          SČ USTI NAD LABEM     CZE
# 154                PITRA Pavel 1988-06-25                   SC PRAHA     CZE
# 155              PLÁTEK Daniel 1999-07-08             TJ DUKLA PRAHA     CZE
# 156             POHNAN Kryštof 2004-03-08                   SC PRAHA     CZE
# 157                POKORNÝ Jan 2005-01-01              DUKLA OLOMOUC     CZE
# 158            POKORNÝ Richard 1991-07-11                   SC PRAHA     CZE
# 159                POŠTA Marek 1987-04-27              SOKOL DEJVICE     CZE
# 160           PROCHÁZKA Ondřej 2005-04-10          1.FC BELA POD BEZ     CZE
# 161              PRYL Dobromil 1975-05-06               RIEGEL PRAHA     CZE
# 162                  PUR Lukáš 2001-05-07               ŠERM LIBEREC     CZE
# 163       PUSTĚJOVSKÝ Vladimír 2003-12-14                   SC PRAHA     CZE
# 164               PÁTEK Ondřej 1999-01-01                      S.BRI     CZE
# 165             RANDÁK Richard 2002-01-17             TJ LOKO K.VARY     CZE
# 166             ROGUSKI Tomasz 1985-04-18               WARSZAWIANKA      PL
# 167               RUBEŠ Martin 1996-09-16             TJ LOKO K.VARY     CZE
# 168                RUSIN Illia 2005-01-01                        POL     POL
# 169            SADSKÝ Jaroslav 1982-12-03              TJ LOKO PLZEN     CZE
# 170              SALAČ Vojtěch 1998-09-23          SLAVOJ LITOMĚŘICE     CZE
# 171                SALZER Jiří 2001-07-29                   SC PRAHA     CZE
# 172               SALZER Matěj 2001-07-29                   SC PRAHA     CZE
# 173             SCHÖPPEL Karel 2005-02-03                   VSK ČVUT     CZE
# 174                SEDLÁK Petr 2006-04-30            TJ LOKO TEPLICE     CZE
# 175            SEDLÁČEK Ondřej 1999-12-14              DUKLA OLOMOUC     CZE
# 176               SEJKORA Adam 2007-08-28                   SC PRAHA     CZE
# 177               SKROVNÝ Petr 1984-05-10              TJ LOKO PLZEN     CZE
# 178               SMRČEK Šimon 2001-05-17              TJ LOKO PLZEN     CZE
# 179               SMRČEK Šimon 2001-05-17                  USK PRAHA     CZE
# 180             SMUTNÝ Richard 2005-07-07                  USK PRAHA     CZE
# 181                 SMÍTKA Jan 2001-05-24                SOKOL PLZEŇ     CZE
# 182            SNOPEK Miroslav 1989-04-05             SS UH.HRADISTE     CZE
# 183           SOCHOR František 1981-05-27                  USK PRAHA     CZE
# 184            SOKOL Vratislav 1976-07-08             SLAVOJ Č.TĚŠÍN     CZE
# 185          SOKOLOV Sevastyan 2006-08-07                   SC PRAHA     CZE
# 186        STASZULONEK Bartosz 1997-10-26              PIAST GLIWICZ     POL
# 187                STEHLÍK Jan 1999-02-28              DUKLA OLOMOUC     CZE
# 188            STEHLÍK Vojtěch 2001-11-07          SLAVOJ LITOMĚŘICE     CZE
# 189                STEIS Matúš 1993-04-03                   SC PRAHA     SVK
# 190                STEMPEL Jan 2003-11-03              SOKOL DEJVICE     CZE
# 191          STIRBER Sebastián 2004-08-12                   SC PRAHA     CZE
# 192              STOLAR Samuel 1998-06-16  AKADÉMIA ŠERMU BRATISLAVA     SVK
# 193               STRAKA Tomáš 1975-03-14                   SC PRAHA     CZE
# 194             STUDENÝ Václav 1966-11-07               SOKOL BRNO I     CZE
# 195               STYMNE Jakob 1996-01-01              DIF STOCKHOLM     SWE
# 196               SURMA Štěpán 2004-12-17                   LAŠSSKFZ     CZE
# 197           SVOBODA 67 Tomas 1967-01-01                  USK PRAHA     CZE
# 198       SVOBODA Bohumil Jiří 2003-03-17             TJ DUKLA PRAHA     CZE
# 199                SVOBODA Ivo 1957-11-22               ŠERM MASTERS     CZE
# 200              SVOBODA Jakub 2001-01-05                   VUT BRNO     CZE
# 201           SVOBODA ST Tomáš 1967-09-09                  USK PRAHA     CZE
# 202              SVOBODA Tomáš 1998-11-29                  USK PRAHA     CZE
# 203     SVOBODA Tomáš Kristián 1967-09-09                  USK PRAHA     CZE
# 204           SVOBODA_ML Tomáš 1998-11-29                  USK PRAHA     CZE
# 205           SVOBODA_ST Tomáš 1967-09-09                  USK PRAHA     CZE
# 206                 SZALAY Jan 1992-01-01                     BA MPC     SVK
# 207                 SZALAY Jan 1992-06-29           BA MPC BRATISLAV     CZE
# 208        SÝKORA Adam Herbert 2001-09-17             TJ SOKOL PÍSEK     CZE
# 209            TKACHENKO Danil 2000-10-31        SPORTOVNÍ ŠERM ZLÍN     RUS
# 210                  TOMAN Jan 2002-08-16             TJ DUKLA PRAHA     CZE
# 211               TOMAN Štěpán 1978-06-10              SOKOL DEJVICE     CZE
# 212          TOMÁŠEK Vlastimil 1978-05-18             TJ LOKO K.VARY     CZE
# 213             TREFILÍK Jakub 1990-07-02                      S.BRI     CZE
# 214             TÁBORSKÝ Lukáš 2004-01-01                  USK PRAHA     CZE
# 215             TÁBORSKÝ Lukáš 2004-06-03                  USK PRAHA     CZE
# 216                   TŮMA Jan 1978-01-01                   SC PRAHA     CZE
# 217                 TŮMA Marek 1993-03-30              SOKOL DEJVICE     CZE
# 218                VACH Daniel 2005-01-01            TJ LOKO TEPLICE     CZE
# 219                VACH Daniel 2005-07-23            TJ LOKO TEPLICE     CZE
# 220             VACHOVEC Matěj 2005-11-30              TJ LOKO PLZEN     CZE
# 221               VALENTA Jiří 1983-07-04                   SC PRAHA     CZE
# 222            VALKOVIČ Martin 1962-08-27                   SC PRAHA     CZE
# 223                VASIC Filip 1973-07-19              SILNI BEOGRAD     CZE
# 224             VAVRA Miroslav 1961-01-01                   VSK ČVUT     CZE
# 225             VAŠÍČEK Martin 2002-09-21              DUKLA OLOMOUC     CZE
# 226               VIKOV Atrtěm 2002-01-29                  USK PRAHA     CZE
# 227                VLACH Šimon 2005-06-10              TJ LOKO PLZEN     CZE
# 228            VOKÁČ František 2002-09-03             TJ LOKO K.VARY     CZE
# 229               VOLÁK Samuel 2000-12-15              DUKLA OLOMOUC     CZE
# 230              VONDRA Matouš 2003-11-23             TJ DUKLA PRAHA     CZE
# 231              VÁVRA Antonín 2000-11-23               RIEGEL PRAHA     CZE
# 232             VÁVRA Miroslav 1961-08-17                   VSK ČVUT     CZE
# 233              VÁVRA Vojtěch 1996-11-19               EKONOM PRAHA     CZE
# 234               VÍTEK Daniel 1974-05-18             TJ LOKO K.VARY     CZE
# 235                WALLER Adam 2007-08-27                   SC PRAHA     CZE
# 236               WALLER Jonáš 2008-10-10                   SC PRAHA     CZE
# 237          WESELOWSKI Michal 2001-10-26              PIAST GLIWICZ     POL
# 238               ZELENKA Jiří 1993-06-04               VSK HUMANITA     CZE
# 239                ZEMAN Jakub 2001-08-24             TJ DUKLA PRAHA     CZE
# 240                ZHÁŇAL Petr 2002-05-17                   SC PRAHA     CZE
# 241                ZHÁŇAL Petr 2002-05-17             TJ DUKLA PRAHA     CZE
# 242               ČAPEK Martin 1983-09-14                   SC PRAHA     CZE
# 243                ČUPR Michal 1991-12-23          SLAVOJ LITOMĚŘICE     CZE
# 244                ŘEZANKA Ota 1970-07-24             TJ LOKO K.VARY     CZE
# 245           ŠILHÁN František 2000-01-21               ŠERM LIBEREC     CZE
# 246            ŠILHÁN Jindřich 1996-12-20               ŠERM LIBEREC     CZE
# 247            ŠPATENKA Martin 1971-10-13              DUKLA OLOMOUC     CZE
# 248               ŠTULÍŘ Pavel 1987-01-01                  BOHEMIANS     CZE
# 249             ŠTVERÁK Martin 1993-07-13             TJ SOKOL PÍSEK     CZE
# 250               ŠVANDA Pavel 1975-02-02                  USK PRAHA     CZE
# 251           ŠŤASTNÝ Kristián 2002-10-21             TJ LOKO K.VARY     CZE
# 252                ŽIŽKA David 1999-06-25          SČ USTI NAD LABEM     CZE
#
#      count
# 0        1
# 1        5
# 2        1
# 3        1
# 4        3
# 5       14
# 6        3
# 7       16
# 8        1
# 9       10
# 10       1
# 11       9
# 12       1
# 13       2
# 14       1
# 15       1
# 16       3
# 17      14
# 18       4
# 19       1
# 20       1
# 21       3
# 22       1
# 23       9
# 24       1
# 25       9
# 26       1
# 27       6
# 28       8
# 29       9
# 30       1
# 31      15
# 32       5
# 33      16
# 34       3
# 35       8
# 36       2
# 37       6
# 38       2
# 39      10
# 40       9
# 41      12
# 42      12
# 43       5
# 44       4
# 45       1
# 46       1
# 47      12
# 48      10
# 49       3
# 50      13
# 51       2
# 52       1
# 53       6
# 54       6
# 55       1
# 56       2
# 57       1
# 58       9
# 59       1
# 60       1
# 61       1
# 62      13
# 63      14
# 64      15
# 65      12
# 66       1
# 67       2
# 68       5
# 69       6
# 70       2
# 71       1
# 72       8
# 73      10
# 74       8
# 75       1
# 76       2
# 77      11
# 78       4
# 79       8
# 80       1
# 81       7
# 82       1
# 83       1
# 84       4
# 85       7
# 86       1
# 87      10
# 88       5
# 89      12
# 90      12
# 91      11
# 92       4
# 93       1
# 94       1
# 95       1
# 96       8
# 97       3
# 98       1
# 99       5
# 100      1
# 101     13
# 102      1
# 103     12
# 104      3
# 105      1
# 106      5
# 107      4
# 108     13
# 109      1
# 110      3
# 111      2
# 112      4
# 113      3
# 114      2
# 115      3
# 116      2
# 117      9
# 118      4
# 119     10
# 120      2
# 121      5
# 122     13
# 123      1
# 124      2
# 125      1
# 126      8
# 127      2
# 128      1
# 129      1
# 130      5
# 131      1
# 132      1
# 133      1
# 134      1
# 135     14
# 136     10
# 137      3
# 138      1
# 139      2
# 140      1
# 141      1
# 142      3
# 143      7
# 144      1
# 145      1
# 146      1
# 147      2
# 148      3
# 149      3
# 150      3
# 151      1
# 152     12
# 153      1
# 154     12
# 155      1
# 156      5
# 157      1
# 158      9
# 159      1
# 160      8
# 161     15
# 162      1
# 163      9
# 164      1
# 165      1
# 166      1
# 167     15
# 168      1
# 169      3
# 170      5
# 171     10
# 172     14
# 173      1
# 174      1
# 175      1
# 176      1
# 177      9
# 178      1
# 179     12
# 180      1
# 181      4
# 182      2
# 183      2
# 184      9
# 185      1
# 186      1
# 187     15
# 188      1
# 189      7
# 190      1
# 191     10
# 192      4
# 193      7
# 194      1
# 195      1
# 196      2
# 197      1
# 198      2
# 199      1
# 200      1
# 201      2
# 202     10
# 203      9
# 204      1
# 205      1
# 206      2
# 207      1
# 208      1
# 209      2
# 210      6
# 211      1
# 212      2
# 213      1
# 214      1
# 215     11
# 216      1
# 217     16
# 218      1
# 219      1
# 220      3
# 221      1
# 222     15
# 223      1
# 224      1
# 225      6
# 226      1
# 227      1
# 228      2
# 229      7
# 230      1
# 231      5
# 232      4
# 233      8
# 234      6
# 235      6
# 236      7
# 237      1
# 238      2
# 239      1
# 240      1
# 241      4
# 242     15
# 243     16
# 244      6
# 245      1
# 246      2
# 247     13
# 248      1
# 249      3
# 250     12
# 251      2
# 252      1

# %% [markdown]
# ## I.9 - Vytvoření tabulky závodníků a tabulky Ranků. Ještě bude tabulka zápasů
# * vyřešit sortování jmen dle české abecedy
# * Případně příjmení psát bez diakritiky...
#
# * ID / Jméno /Klub (potenciálně víc) / Stát / Pohlaví / D.narození / Ruka / Zbraň / Skore v žebříčku k poslednímu update
# * // dopočítaný počet všech turnajů, počet poolových zápasů a počet eliminačních zápasů, a jejich koeficienty Výher. / Počet vítězství? nebo to až později...

# %%
df_m["Year"]  = pd.DatetimeIndex(df_m['Birthdate']).year
printbold(str(len(df_m)))
# Out:
# 624

# %%
df_m_people = df_m.groupby(['Name','Club', "Country", "Sex", "Birthdate", "Year"]).size().reset_index().rename(columns={0:'count'})
df_m_people = df_m_people[["Name", "Club", "Country", "Sex", "Birthdate", "Year"]]

df_m_people.to_excel(f"C:/Users/jzelenka/Documents/python_j/fencing/1_zavodnici_{SEX}_NEW.xlsx", index=False)
df_m.to_excel(f"C:/Users/jzelenka/Documents/python_j/fencing/2_ranky_{SEX}_NEW.xlsx", index=False)

printbold(str(len(df_m_people)))
df_m_people.head(2)
df_m_people.tail(2)
# Out:
# 139
#                   Name           Club Country Sex  Birthdate  Year
# 134     ŠEBESTOVÁ Nela  SOKOL DEJVICE     CZE   W 2004-08-09  2004
# 135    ŠMÍDOVÁ Daniela  DUKLA OLOMOUC     CZE   W 2005-04-16  2005
# 136    ŠPATENKOVÁ Anna  DUKLA OLOMOUC     CZE   W 1999-09-26  1999
# 137   ŽOLNOVÁ Karolína  DUKLA OLOMOUC     CZE   W 1995-10-23  1995
# 138  ŽÁDNÍKOVÁ Daniela  DUKLA OLOMOUC     CZE   W 1984-07-31  1984

# %% [markdown]
# ## The End
#
# ## --> Fencing_Visualizations
