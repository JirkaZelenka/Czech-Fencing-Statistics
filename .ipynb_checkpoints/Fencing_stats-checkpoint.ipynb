# %% [markdown]
# ## Fencing Statistics - ČR and World
# #### 7.11.2022 After a competition in Písek (5.-6.11.2022)
# #### 8.12. still manually preparing Men data...
# #### 21.12. creating local repo and GITHub https://github.com/JirkaZelenka/Czech-Fencing-Statistics

# %% [markdown]
# * https://fie.org/athletes/                                      = Individual's Profile, D.o.B.
# * https://fie.org/competitions                                   = Event profile
#
# * https://www.czechfencing.cz/portal/teams/detail/14             = Club's profile
# * https://www.czechfencing.cz/portal/rankings/list               = Rankings + filters
# * https://www.czechfencing.cz/portal/members/detail/1175         = Individual's Profile
# * https://www.czechfencing.cz/portal/events/detail?eventId=3095  = Event profile with a File included
# * https://www.czechfencing.cz/user_files/propositions/63541c9150a35/Lazensky-pohar-2022.pdf = File with details
#
# * http://sermliga.eu/  = univerzitní liga, 3. kola, 2. teď v praze

# %% [markdown]
# ### Ideas:
#
# ##### Hlavní metriky:
# * Poměr výher/proher
# * Index = zásahy dal minus dostal
# * Průměrné umístění (vždy přepočítat na percentily kvůli různým počtům účastníků?)
# * Počet medailí celkem
#
# #### 4 úrovně: Kluby, Závodníci obecně, Zápasy (vzájemné skore dvojic) a pak predikce (sázky, rerese,simulace ...)
#
# #### Kluby:
# * ~~celkový počet členů~~, průměrné nasazení na zápas
# * věkové statistiky
# * žebříčky po turnajích, po medailích, podle typu turnaje (UŠL/ČR/Svět), podle zbraně (Jen kord)
# * statistiky států (měst) a klubů
# * průměrné umístění za klub v daném turnaji, který klub má kolik medailí..
# * pro každého človeka/klub mít průměrný počet zásahů na zápas, přičemž oddělovat poolové a eliminační (15b)
#
#
# #### Závodníci obecně:
# * ~~věkové statistiky~~
# * průměrný "aktivní" věk výherců, ale i ten reálný
# * věk - vyhrává stáří a xp vs mládí a energie?
# * leváci vs praváci. jejich zastoupení u obou pohlaví, u klubů atd.
# * muži vs ženy. věk ,skore, zbraně, ruka... histogramy
# * pro každého človeka/klub mít průměrný počet zásahů na zápas, přičemž oddělovat poolové a eliminační (15b)
# * Znamení zvěrokruhu xD
#
# #### Závodníci - zápasy (vzájemné skore dvojic)
# * vzájemné souboje, historie duelů pro danou dvojici (nebo klub), skore a počty výher pro každou dvojici. = vybrat si libovolnou dovjici lidí a ukázat celou jejich soubojovu historii, jednak přímé boje, ale i to na kterých turnajích se potkali a jak dopadli.
# * pořadí, ale i eliminace, kolikrát vypadnutí nazčátku atd., kolikrát ve finále.
# * počet zápasů. zlepšování se v čase. Sankey diagramy umístění (v rámci klubu?)
# * overall matice, každý s každým, aby se vidělo, kdo se s kým už potkal ve skupině nebo v eliminaci, ajak to dopadlo. V případě že už vícekrát,tak vytvořit jejich vzájemný skore, podle počtu výher? - příklad A v řádku porazí B ve sloupci ve 2 bojích ze 3, tak dostane skore +2? nebo prostě zelený čtvereček. naopak červený. nebo žlutý na remízu nebo šedivý pokud nic)
#
# #### Predikce (bonusová část)
# * -> Předpovědět když se potká někdo z SC a někdo z VSK, jak to pravděpodobně dopadne
# * srovnávačka, jak moc první kolo předpoví i finální výsledek
# * nějaká regrese, jak se klub a věk podílí na pořadí, resp korelace věku a pořadí. asi bude kvadratický vztah?
# * regrese - jak se index podepíše na postupu, resp na pozici. protože některé s -16 prošli a čestmír s -6 neprošel
# * procentuální šance na výhru. Pak by se dalo sázet :O Odhadnout, že Vávra vyhrává 90 % zápasů a nejhůř dává 4 zásahy. Nebo že například Vávra vždy porazil kohokoliv z VUT a Olomouce.
# * Pokémon systém xD udělat modelové souboje
# * možnost nasimulovat celý zápas podle historických dat, znovu vytvořit pooly i žebříček
# * možnost vidět jak by dopadl tehdejší turnaj, kdyby se odehrál dnes -> tj záleží na pořadí a historii zápasů.
# * v případě simulace celého zápasu, vidět jak by se zpřesNoval kyž mu dodám postupně třeba poolová data.
#
#
# #### Dohledávání
# * najít lidi co možná změnili klub, podle věku
# * FIE žebříčky ukazují skore jen pokud jsi závodil v aktuálním ročníku.
# * u českých turnajů jsou i statistiky o cizincích co se zúčastili

# %% [markdown]
# ### Data format:
# * **Tři tabulky**
# * 1) **Závodníci** - ID / Jméno / Klub (potenciálně víc)  / Stát / Pohlaví / D.narození / Ruka / Zbraň / Skore v žebříčku k poslednímu update
# * // dopočítaný počet všech turnajů, počet poolových zápasů a počet eliminačních zápasů, a jejich koeficienty Výher. / Počet vítězství? nebo to až později...
#
# * 2) **Eventy** - ID / Datum / Event / Město / Pohlaví / Počet účastníků / Počet účastníků obou pohlaví
#
# * 3) **Výsledky Eventů** - ID / ID Event / ID závodníka / Rank ČR před / Rank po Poolu / Status po Poolu (Adv./Elim.)/ Rank Celkově
#
# * 4) **Zápasy** - ID / ID Eventu / ID závodníka 1 / ID závodníka 2 / Fight Lvl (Pool/Eliminace_32) / Výsledek (V/D) / Scored / Received

# %% [markdown]
# ### Notes
# * https://www.czechfencing.cz/portal/rankings/list - po Exportu vyjede textak, kde sice nejsou body za jendotlivé soutěže, ale je tam zas celé datum narození !
#
# * jaktože Beran má 600/1000 bodů za jediný event ! a jaktože 10.člověk v žebčířku má pohých 86 bodů?
#
# * zrovna VSK Humanita je nějaká divná, protože ve výsledcích turnaje se jmenuje **HF PRAHA**, teď jsem akorát našel **HUMANITA PHA** a taky **VSK HUMANITA**, potom ještě **VSKHPZ** přes Aničku
#
# - ze závodu 09 - MCR USK - tak jsou tam i týmy. hromada dalších tabulek ale na to asi zatím píchám, beru základ.
#
# - 11.11. první mergování dat,kontrola kvality muži i ženy, drobné úpravy. Nalezeny 3-4 tvary pro psaní Humanity
#
# - 18.11. v letadle, dotaženo UŠL_2, jakože ženy velký Pool i celá eliminace. Začal jsem Memoriál Muži, 3/12 skupin. (80 lidí...)
# - 27.11. dokončuju třetí velký turnaj Mužů (pool a eliminace)
# - 8.12. still manually preparing Men data...
#
# | Default | Left-aligned | Center-aligned | Right-aligned |
# |---------|:-------------|:--------------:|--------------:|
# | Default | Left | Center | Right |
#
# ~~- na druhou stranu, dat není tolik 2x13 turnajů za rok, tak přemýšlím zda data nesebírat ručně a pak si hrát až s analýzami. beztak budu muset ta data ukládat ako pdf nebo jako obrázky nebo něco.~~
#
# ~~- 8.11. zjištěno, že nejvkalitnější je do excelu nahrád tabulku PDF pomocí excleového Get Data. Funguje na Ranky 1 i 2,~~
# ~~-- ale už ne na skupinky (jen levý sloupec) a musel bych je manuálně dopisovat vnitřky~~-
# ~~-- AHA, záleží na zpracování. TOto platilo o Karloých varech. Písek to má naopak, nemá tak hezké tabulky ranků, ale má strojově čitelné (importovatelné) tabulky skupin ! Ale v té prnví tabulce nemá čitelný poměr výher a taky má Q místo Advanced.~~-
# ~~--Index je vždycky rozdíl dal-dostal = TS-TR; TS = touche scored = ZD (zásahů dal); TR = touches received ~~--
#
# ~~-- v posledním turnaji v Písku, všem (mužům) posunuli den narození o den dřív :D včetně mě, Rubeše a všech co jsem si kontrolov.~~-
#
# ~~11.11. - do Písku jsem doplnil chybějící Club postupujících, abych mohl snadněji mergovat a nevznikal mi Club_X a Club_y~~
# ~~stejně tak tam doplněno PODLE MÝCH FOTEK skore a indexy těch, kdo jsme nepostoupili.~~
#
# ~~Rozjeaná jména v písku - ADAM Sykora je Sýkora Adam Herbert~~

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
## Novinka: Splitlines() !! v kombinaci se splitem() solidní výsledek
# akorát mi to zporzparsuje po slověch všechno, jména i kluby atd.

#t = [x.split() for x in text.splitlines()]
#t[2:4]

# %% [markdown]
# # I. KLUBY A ZÁVODNÍCI
# ### a zatím nepoužitý výsledek po prvním kole, a závěrečné skore

# %% [markdown]
# ## I.1 - PŘÍPRAVA A ČIŠTĚNÍ DAT

# %%
men = ["M_2022_02_Memorial.xlsx", "M_2022_04_Dukla_Olomouc.xlsx", "M_2022_06_Jested.xlsx",
      "M_2022_09_MCR_USK.xlsx", "M_2022_12_Lazensky_pohar.xlsx", "M_2022_13_Pisek.xlsx" ]

women = ["W_2022_04_Dukla_Olomouc.xlsx", "W_2022_05_Teplice.xlsx",
         "W_2022_07_MCR_USK.xlsx", "W_2022_12_Lazensky_pohar.xlsx", "W_2022_13_Pisek.xlsx" ]

# %% [markdown]
# ## Transformace:
# * už v excelu přidám pohlaví, datum a jméno turnaje, převádím rank ze stringu (3T) na int (3)
# * chybí mi "ruka"
# * v pythonu pak zmerguju dohromady, mám sloupečky na first_round_score a na final_score
# * kdykoliv můžu zvalidovat že user mi sedí do tohoto seznamu
# * Najít ženy, co změnily příjmení (asi podle data narození a to že se najednou "vystřídaly")
# * nesedí mi ranky: proč by měl být 3T 10x, 31 5x, a 19 jen 1x ?,
# * buď blbý formát čísla, nebo něco. Btw 4 by nikdy ve finále být neměl, pokud je tam 3T
# * ale aspon jsem si ověřil, že tu mám durhého, co odstoupil, a je jinak vyplněný, tak ho upravím

# %%
def printbold(s):
    print("\033[1m" + s + "\033[0m")

# %%
def merge_all(list_of_events, sex):
    df_tot = pd.DataFrame(columns = ['Name', 'Club', 'Country', 'Sex', 'Birthdate',
                                 "Date", "Event", "Rank", "Init_rank", "First_rank", "Final_rank",
                                 "V",  "V/M",  "TS", "TR", "Ind", "Notes"])
    if sex == "M":
        s = "men"
    else:
        s = "women"
    for event in list_of_events:
        e = pd.ExcelFile(f"C:/Users/jzelenka/Documents/python_j/fencing/data/{s}/" + event)
        df0 = pd.read_excel(e, 'initiation')
        df1 = pd.read_excel(e, 'first_round')
        df2 = pd.read_excel(e, 'total_rank')
        
        if len(df0) == len(df1) == len(df2) and len(df0['Name'].unique()) == len(df1['Name'].unique()) == len(df2['Name'].unique()):
            print(f"Event {event} has {len(df0)} people per each list, {len(df0['Name'].unique())} unique Names")
        else:
            printbold("There is an inconsistency in the length of the lists !!!!!!!!")
        
        df3 = pd.merge(df0, df1, on = ['Name',"Club", "Country"])
        df4 = pd.merge(df3, df2, on = ['Name',"Club", "Country"])
                                                                                                            
        if len(df0) == len(df4) and len(df0['Name'].unique()) == len(df4['Name'].unique()):                                               
            print(f"Correct after merging")
        else:
            printbold("Something is wrong, during merging or before !!!!!!!!!!!!!!!!!!!!")
        
        df_tot=df_tot.append(df4)
        print(f"new length of total = {len(df_tot)}")
        printbold("####################################")
        
    df_tot = df_tot[["Name", "Club", "Country","Birthdate_x", "Date_x", "Event_x", "Sex_x", "Rank", "First_rank", "Final_rank", "Notes"]]
    df_tot = df_tot.rename(columns={"Birthdate_x":'Birthdate', "Date_x": "Date", "Event_x": "Event", "Sex_x": "Sex" })
    df_tot.reset_index(inplace=True, drop = True)
    
    return df_tot

# %%
df_m = merge_all(men, "M")
print(len(df_m))
print(df_m.head(2))
print(df_m.tail(2))
# Out:
# Event M_2022_02_Memorial.xlsx has 80 people per each list, 80 unique Names
# Correct after merging
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# new length of total = 80
# ####################################
# Event M_2022_04_Dukla_Olomouc.xlsx has 61 people per each list, 61 unique Names
# Correct after merging
# new length of total = 141
# ####################################
# Event M_2022_06_Jested.xlsx has 73 people per each list, 73 unique Names
# Correct after merging
# new length of total = 214
# ####################################
# Event M_2022_09_MCR_USK.xlsx has 75 people per each list, 75 unique Names
# Correct after merging
# new length of total = 289
# ####################################
# Event M_2022_12_Lazensky_pohar.xlsx has 82 people per each list, 82 unique Names
# Correct after merging
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\1505106683.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tot=df_tot.append(df4)
# new length of total = 371
# ####################################
# Event M_2022_13_Pisek.xlsx has 76 people per each list, 76 unique Names
# Correct after merging
# new length of total = 447
# ####################################
# 447
#                 Name      Club Country  Birthdate       Date     Event Sex  \
# 0  ADDO DJAN Theodor    TJSPDI     CZE 2006-11-06 2021-12-18  Memorial   M
# 1       ANDERLE Petr  ČESKŠKRZ     CZE 1977-07-07 2021-12-18  Memorial   M
#
#     Rank First_rank Final_rank     Notes
# 0  999.0         56         56  Advanced
# 1   24.0         45         16  Advanced
#              Name          Club Country  Birthdate       Date  \
# 445  WALLER Jonáš      SC PRAHA     CZE 2008-10-10 2022-11-05
# 446  ZELENKA Jiří  VSK HUMANITA     CZE 1993-06-04 2022-11-05
#
#                       Event Sex Rank First_rank Final_rank       Notes
# 445  Zlatý kord města Písku   M   27         25         34    Advanced
# 446  Zlatý kord města Písku   M  999         75         75  Eliminated

# %%
df_m.tail()
# Out:
#               Name           Club Country  Birthdate       Date  \
# 442    VASIC Filip  SILNI BEOGRAD     CZE 1973-07-19 2022-11-05
# 443  VONDRA Matous    DUKLA PRAHA     CZE 2003-11-23 2022-11-05
# 444    WALLER Adam       SC PRAHA     CZE 2007-08-27 2022-11-05
# 445   WALLER Jonáš       SC PRAHA     CZE 2008-10-10 2022-11-05
# 446   ZELENKA Jiří   VSK HUMANITA     CZE 1993-06-04 2022-11-05
#
#                       Event Sex Rank First_rank Final_rank       Notes
# 442  Zlatý kord města Písku   M   60         71         71  Eliminated
# 443  Zlatý kord města Písku   M  999         35         39    Advanced
# 444  Zlatý kord města Písku   M   77         43         32    Advanced
# 445  Zlatý kord města Písku   M   27         25         34    Advanced
# 446  Zlatý kord města Písku   M  999         75         75  Eliminated

# %%
display(df_m.describe())
#display(df_m.describe(datetime_is_numeric=True))
# Out:
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\701769035.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df_m.describe())
# C:\Users\jzelenka\AppData\Local\Temp\ipykernel_23880\701769035.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df_m.describe())
#                 Name      Club Country            Birthdate  \
# count            447       447     447                  447
# unique           189        75       6                  159
# top     KLAUS Robert  SC PRAHA     CZE  2001-07-29 00:00:00
# freq               6        70     435                    8
# first            NaN       NaN     NaN  1956-09-20 00:00:00
# last             NaN       NaN     NaN  2011-11-07 00:00:00
#
#                        Date           Event  Sex   Rank  First_rank  \
# count                   447             447  447  425.0       447.0
# unique                    6               6    1  105.0        82.0
# top     2022-10-22 00:00:00  Lázeňský pohár    M  999.0        21.0
# freq                     82              82  447   29.0         8.0
# first   2021-12-18 00:00:00             NaN  NaN    NaN         NaN
# last    2022-11-05 00:00:00             NaN  NaN    NaN         NaN
#
#         Final_rank     Notes
# count        447.0       447
# unique        81.0         3
# top            3.0  Advanced
# freq          12.0       357
# first          NaN       NaN
# last           NaN       NaN

# %%
for col in df_m.columns:
    printbold(f"# {col}")
    display(df_m[col].value_counts())
    printbold("######################################")
# Out:
# # Name
# KLAUS Robert            6
# ŠPATENKA Martin         6
# FRANK Kilián            6
# SALZER Matěj            6
# FIEDOR Michal           6
#                        ..
# LUKEŠ Matěj             1
# ERNÉE Jan               1
# BINICHAKIS Emannouil    1
# DURYCH Martin           1
# ZELENKA Jiří            1
# Name: Name, Length: 189, dtype: int64
# ######################################
# # Club
# SC PRAHA         70
# SCPŠS            44
# USK PRAHA        25
# D.OLOMOUC        19
# UNIVSKPS         16
#                  ..
# OREL HR.KR.       1
# SLOVAN HORKY      1
# TJSBI             1
# ORELJHK           1
# SILNI BEOGRAD     1
# Name: Club, Length: 75, dtype: int64
# ######################################
# # Country
# CZE    435
# SVK      8
# RUS      1
# GRE      1
# GEO      1
# UKR      1
# Name: Country, dtype: int64
# ######################################
# # Birthdate
# 2001-07-29    8
# 1962-08-27    6
# 2004-02-02    6
# 2008-10-10    6
# 2005-04-10    6
#              ..
# 2002-04-12    1
# 2001-04-24    1
# 2004-06-30    1
# 1991-07-11    1
# 1993-06-04    1
# Name: Birthdate, Length: 159, dtype: int64
# ######################################
# # Date
# 2022-10-22    82
# 2021-12-18    80
# 2022-11-05    76
# 2022-05-21    75
# 2022-04-24    73
# 2022-03-12    61
# Name: Date, dtype: int64
# ######################################
# # Event
# Lázeňský pohár            82
# Memorial                  80
# Zlatý kord města Písku    76
# MČR USK                   75
# Ještěd                    73
# Dukla Olomouc             61
# Name: Event, dtype: int64
# ######################################
# # Sex
# M    447
# Name: Sex, dtype: int64
# ######################################
# # Rank
# 999.0    29
# 52.0     11
# 54.0      9
# 37.0      8
# 59.0      7
#          ..
# 92.0      1
# 100.0     1
# 133.0     1
# 57.0      1
# 66.0      1
# Name: Rank, Length: 105, dtype: int64
# ######################################
# # First_rank
# 21     8
# 25     8
# 45     7
# 41     7
# 60     7
#       ..
# 78     2
# 79     2
# DNF    2
# 77     1
# 81     1
# Name: First_rank, Length: 82, dtype: int64
# ######################################
# # Final_rank
# 3      12
# 22      7
# 44      7
# 58      7
# 5       7
#        ..
# 79      2
# 78      2
# DNF     2
# 77      1
# 81      1
# Name: Final_rank, Length: 81, dtype: int64
# ######################################
# # Notes
# Advanced      357
# Eliminated     88
# Withdrew        2
# Name: Notes, dtype: int64
# ######################################

# %%
df_m[df_m["Notes"]=="Withdrew"]
# Out:
#                      Name         Club Country  Birthdate       Date  \
# 340       ŘEZANKA_ST. Ota  LOKO K.VARY     CZE 1970-07-24 2022-10-22
# 424  PUSTEJOVSKY Vladimír     SC PRAHA     CZE 2003-12-14 2022-11-05
#
#                       Event Sex  Rank First_rank Final_rank     Notes
# 340          Lázeňský pohár   M  62.0        DNF        DNF  Withdrew
# 424  Zlatý kord města Písku   M    30        DNF        DNF  Withdrew

# %% [markdown]
# ## Duplicity ve jménech
# #### Export vs. Soutěže (sjednoceno):
# #### 'SVOBODA Tomáš Kristián' = SVOBODA Tomáš_st.
# #### SVOBODA Tomáš = 'SVOBODA Tomáš_ml.',

# %%
# 32 jmen opravuju získávám: 106-> 77 (některé vlastně jen updatuju samy sebe)

to_replace_woman = {"AIGERMANOVA Gabriela": "AIGERMANOVÁ Gabriela",
             "SALIGEROVA Katerina": "SALIGEROVÁ Kateřina",
             "HAVLINOVA Tereza": "HAVLÍNOVÁ Tereza",
             "PROKSIKOVA Patricie": "PROKŠÍKOVÁ Patricie",
             "COUFALOVA Anna": "COUFALOVÁ Anna",
             "BIELESZOVA Veronika": "BIELESZOVÁ Veronika",
             "PECHOVOVA Michala": "PĚCHOVOVÁ Michala",
             "MYSKOVA Petra": "MYŠKOVÁ Petra",
             "VINCENCOVA Ester": "VINCENCOVÁ Ester",
             "NOVAKOVA Petra": "NOVÁKOVÁ Petra",
             "HUNCAROVA Katarína": "HUNČÁROVÁ Katarína",
             "ADAMCOVA Anita": "ADAMCOVÁ Anita",
             "SLUSNA Karolína": "SLUŠNÁ Karolína",
             "POKORNA Anna": "POKORNÁ Anna",
             "CHALUPNIKOVA Aranka": "CHALUPNÍKOVÁ Aranka",
             "CEJNAROVA Barbora": "CEJNAROVÁ Barbora",
             "KAHABKOVA Eliska": "KAHABKOVÁ Eliška",
             "POTOCKOVA Katerina": "POTOČKOVÁ Kateřina",
             "BARTOSKOVA Adéla": "BARTOŠKOVÁ Adéla",
             "WEISOVA Katerrina": "WEISOVÁ Kateřina",   ##?##
             "SMIDOVA Daniela": "ŠMÍDOVÁ Daniela",
             "LASTOVKOVA Tereza": "LAŠTOVKOVÁ Tereza",
             "TUMOVA Šárka": "TŮMOVÁ Šárka",
             "HONOVA Marketa": "HONOVÁ Markéta",
             "VACHOVA Tereza": "VÁCHOVÁ Tereza",
             "DIVISOVA Klára": "DIVIŠOVÁ Klára",
             "KUHNOVA Korolína": "KÜHNOVÁ Karolína",  ##?##
             "KOCOURKOVA Marie": "KOCOURKOVÁ Marie",
             "MATEJCKOVA Lucie": "MATĚJČKOVÁ Lucie",
             "FRDLIKOVA Markéta": "FRDLÍKOVÁ Markéta",
             "SYROVATKOVA Iva": "SYROVÁTKOVÁ Iva",
             "ZIEGLEROVA Adéla Anna": "ZIEGLEROVÁ Adéla Anna"
            }

print(len(to_replace_woman))
# Out:
# 32

# %%
# 35 jmen opravuju získávám: 189-> 155   -> 154 -> 153 (Svoboda Tomáš st. = Tomáš Kristián)

to_replace_man = {"ADAM Sykora" : "SÝKORA Adam Herbert",
             "BOSAK Stepan": "BOSÁK Štěpán",
             "BEDNAR Kryštof":"BEDNÁR Kryštof",  ##?##
             "BRADAC Petr": "BRADÁČ Petr",
             "CAPEK Martin": "ČAPEK Martin",
             "CUPR Michal": "ČUPR Michal",
             "D´AMICO Kristian": "D'AMICO Kristian",
             "DOLEJSI Marek": "DOLEJŠÍ Marek",
             "DUDUC Alex": "DUDUC Alex Vladimír", ##?##
             "DUDUC Alex Vladimir": "DUDUC Alex Vladimír",
             "ERNEÉ Jan":"ERNÉE Jan",
             "FOLDES Tomáš": "FÖLDES Tomáš",
             "HLAVAC Jakub": "HLAVÁČ Jakub",
             "HOBAUS Max": "HÖBAUS Max",
             "HORBACHUCK Yuriy": "HORBACHUK Yuriy",
             "IVANCO Alexander": "IVANČO Alexandr",  ## Alexander -> Alexandr
             "IVANCO Robin": "IVANČO Robin",
             "IVANCO Mikuláš": "IVANČO Mikuláš",
             "JANU Gael": "JANŮ Gael",
             "JILEK Jaroslav": "JÍLEK Jaroslav",
             "KOURIL Jan": "KOUŘIL Jan",
             "KRUZECKY Tomáš": "KROUŽECKÝ Tomáš",  ##?##
             "KUCHAR Matěj": "KUCHAŘ Matěj",
             "LANIK Jan": "LÁNÍK Jan",
             "LOKAJ Vaclav": "LOKAJ Václav",
             "LUSTICKY Josef": "LUŠTICKÝ Josef",
             "MOTALIK Libor": "MOTALÍK Libor",
             "NOVAK Martin": "NOVÁK Martin",
             "PAVLIK Matyáš": "PAVLÍK Matyáš",
             "PROCHAZKA Ondřej": "PROCHÁZKA Ondřej",
             "PUSTEJOVSKY Vladimír": "PUSTĚJOVSKÝ Vladimír",
             "RUBES Martin": "RUBEŠ Martin",
             'SADSKY Jaroslav': 'SADSKÝ Jaroslav',
             "SKROVNY Petr": "SKROVNÝ Petr",
             "SMITKA Jan": "SMÍTKA Jan",
             "SMRCEK Šimon": "SMRČEK Šimon",
             "STIRBER Sebastian": "STIRBER Sebastián",
             "SVOBODA Tomáš_st.": "SVOBODA Tomáš Kristián",
             "SVOBODA Tomáš_ml.": "SVOBODA Tomáš",
             "ŠTVERAK Martin": "ŠTVERÁK Martin",
             "TABORSKY Lukas": "TÁBORSKÝ Lukáš",
             "TUMA Marek": "TŮMA Marek",
             "VACHOVEC Matej": "VACHOVEC Matěj",
             "VALKOVIC Martin": "VALKOVIČ Martin",
             "VONDRA Matous":"VONDRA Matouš"
                }
                  
print(len(to_replace_man))

df_m["Name"] = df_m["Name"].replace(to_replace_man)
# Out:
# 45

# %%
pd.options.display.max_rows = 999
printbold(str(len(df_m["Name"].unique())))
print(sorted(df_m["Name"].unique()))
# Out:
# 153
# ['ADDO DJAN Theodor', 'AIGERMAN František', 'AIGERMAN Oliver', 'ALMER Vojtěch', 'ANDERLE Petr', 'ARTAZOV Maxmilián', 'BALCAR Josef', 'BEDNÁR Kryštof', 'BERAN Jiří', 'BERKA Adam', 'BILKO Martin', 'BINICHAKIS Emannouil', 'BOSÁK Štěpán', 'BRADÁČ Petr', 'BUREŠ Lukáš', 'BÉREŠ Daniel', 'BÓR Karel', 'BĚLOHOUBEK Matouš', 'CHOUN Karím', 'CIMLER Čestmír', 'CIMPA Miroslav', 'COUFAL František', "D'AMICO Kristian", 'DOLEJŠÍ Marek', 'DOŠEK Jiří', 'DUDUC Alex Vladimír', 'DURYCH Martin', 'ERNÉE Jan', 'FIEDOR Michal', 'FRANK Kilián', 'FÖLDES Tomáš', 'GAISLER Jakub', 'GENZER Jiří', 'GERŽA Jakub', 'GIL Matyáš', 'GRUMMICH Petr', 'HABARTA Ondřej', 'HERDA Jan', 'HEREY Anatoliy', 'HLAVÁČ Jakub', 'HORBACHUK Yuriy', 'HOYER Martin', 'HRONEK Ondřej', 'HÖBAUS Max', 'IVANČO Alexandr', 'IVANČO Mikuláš', 'IVANČO Robin', 'JAMBOR Stanislav', 'JANŮ Gael', 'JAVAKHISHVILI Georgii', 'JEŘÁBEK Petr', 'JINDRA Jakub', 'JINDRA Jan', 'JIRAN Jan', 'JURKA Jakub', 'JURKA Tomáš', 'JÍLEK Jaroslav', 'KAIL Daniel', 'KALUS Jonáš', 'KAREL Petr', 'KARÁSEK Libor', 'KAŠPAR Daniel', 'KEDER Michal', 'KLAUS Robert', 'KLSÁK Adam', 'KNAP Ladislav', 'KNOP Tadeáš', 'KOTALA Jan', 'KOUŘIL Jan', 'KRAJSA Tomáš', 'KROUŽECKÝ Tomáš', 'KRÁL Jiří', 'KUCHAŘ Matěj', 'KUF Jan', 'KULT Pavel', 'KURÁŇ Martin', 'KŘÍŽ Petr', 'LOKAJ Václav', 'LUCOVIČ Matěj', 'LUKEŠ Matěj', 'LUŠTICKÝ Josef', 'LÁNÍK Jan', 'MALEČEK Jakub', 'MATOUŠEK David', 'MAŠATA Vojtěch', 'MIČINEC Adam', 'MOTALÍK Libor', 'MRÁZ Pavel', 'MÜNZBERGER Vladimír', 'NECHAY Pavel', 'NOVOTNÝ Šimon', 'NOVÁK Martin', 'OMELKA Antonín', 'OMELKA Jakub', 'OSIČKA Adam', 'PAVLÍK Matyáš', 'PITRA Pavel', 'POHNAN Kryštof', 'POKORNÝ Richard', 'PROCHÁZKA Ondřej', 'PRYL Dobromil', 'PUSTĚJOVSKÝ Vladimír', 'RUBEŠ Martin', 'SADSKÝ Jaroslav', 'SALAČ Vojtěch', 'SALZER Jiří', 'SALZER Matěj', 'SCHÖPPEL Karel', 'SEDLÁK Petr', 'SEJKORA Adam', 'SKROVNÝ Petr', 'SMRČEK Šimon', 'SMÍTKA Jan', 'SOKOL Vratislav', 'STEHLÍK Jan', 'STEHLÍK Vojtěch', 'STEIS Matúš', 'STIRBER Sebastián', 'STOLAR Samuel', 'STRAKA Tomáš', 'STUDENÝ Václav', 'SURMA Štěpán', 'SVOBODA Bohumil Jiří', 'SVOBODA Tomáš', 'SVOBODA Tomáš Kristián', 'SZALAY Jan', 'SÝKORA Adam Herbert', 'TKACHENKO Danil', 'TOMAN Jan', 'TOMAN Štěpán', 'TÁBORSKÝ Lukáš', 'TŮMA Marek', 'VACHOVEC Matěj', 'VALENTA Jiří', 'VALKOVIČ Martin', 'VASIC Filip', 'VAŠÍČEK Martin', 'VLACH Šimon', 'VOLÁK Samuel', 'VONDRA Matouš', 'VÁVRA Miroslav', 'VÁVRA Vojtěch', 'VÍTEK Daniel', 'WALLER Adam', 'WALLER Jonáš', 'ZELENKA Jiří', 'ČAPEK Martin', 'ČUPR Michal', 'ŘEZANKA_ST. Ota', 'ŠILHÁN Jindřich', 'ŠPATENKA Martin', 'ŠTVERÁK Martin', 'ŠVANDA Pavel']

# %% [markdown]
# ## Duplicity v Klubech
# #### Vždy je diskutabilní, který je ten správný..beru nejdelší
# #### "UKRAJINA" == co za klub?
# #### pořešit: HUNČÁROVÁ Katarína - KS SNINA = jediná, která změnila klub v průběhu

# %%
#df_w[df_w["Club"]=="VSK HUMANITA"]

# HF Praha= Markéta 1x - Dukla Olomouc
# HUMANITA PHA = Markéta 1x - Karlovy vary
# VSK HUMANITA = Holky 5x Písek
# VSKHPZ = 2X Anička

# %%
to_replace_club = {
    "LOKO K.VARY": "TJ LOKO K.VARY",    ####
    "LOKO KV": "TJ LOKO K.VARY",    
    "TJLKV-ŠZ": "TJ LOKO K.VARY",   
    "LOKO TEPLICE": "TJ LOKO TEPLICE",   ####
    "LOKO TP": "TJ LOKO TEPLICE",
    "TJLTZ": "TJ LOKO TEPLICE",
    "SCPŠS": "SC PRAHA",    ####
    "D.PRAHA": "TJ DUKLA PRAHA",  ####
    "DUKLA PRAHA": "TJ DUKLA PRAHA", 
    "TJDP": "TJ DUKLA PRAHA",
    "TJDPZ": "TJ DUKLA PRAHA",
    "1.1.FC BĚLÁ": "1.FC BELA POD BEZ", ####
    "1.FC BĚLÁ": "1.FC BELA POD BEZ",
    "1.FC BELA": "1.FC BELA POD BEZ",
    "1.FCB": "1.FC BELA POD BEZ",
    "1.FCBPBZ": "1.FC BELA POD BEZ",
    "LOKO PLZ": "TJ LOKO PLZEN", ####
    "LOKO PLZEŇ": "TJ LOKO PLZEN",
    "TJLPZ": "TJ LOKO PLZEN",
    "HF PRAHA": "VSK HUMANITA", ####
    "HUMANITA PHA": "VSK HUMANITA",
    "VSKHPZ": "VSK HUMANITA",
    "ČŠKRP": "RIEGEL PRAHA",  ####
    "ČESKŠKRZ": "RIEGEL PRAHA",
    "ČŠK RIEGEL": "RIEGEL PRAHA",
    "DUKLA OL": "DUKLA OLOMOUC",  ####
    "TĚLOJDOZ": "DUKLA OLOMOUC",
    "TJ DUKLA OLOMOU": "DUKLA OLOMOUC",
    "D.OLOMOUC": "DUKLA OLOMOUC",
    "SL.LITOMĚŘICE": "SLAVOJ LITOMERICE", ####
    "SLAVOJ LIT": "SLAVOJ LITOMERICE",
    "SLAVOJ LITOMERIC": "SLAVOJ LITOMERICE",
    "S.S.UH.HRAD.": "SS UH.HRADISTE", ####
    "TJSSUHZ": "SS UH.HRADISTE",
    "UNIVSKPS": "USK PRAHA", ####
    "USK PHA": "USK PRAHA",
    "J.H.BROD": "HAV BROD",  ####
    "SP.Š.ÚSTÍ/L.": "SČ USTI NAD LABEM", ####
    "SPŠ ÚSTÍ": "SČ USTI NAD LABEM",
    "SPORŠÚNLZ": "SČ USTI NAD LABEM",
    "SŠ USTI N. LABEM": "SČ USTI NAD LABEM",
    ###############################
    "S.DEJVICE": "SOKOL DEJVICE", ####
    "TJSPDI": "SOKOL DEJVICE", 
    "EKONOM": "EKONOM PRAHA", ####
    "VYSOTJEPZ": "EKONOM PRAHA",
    "BSKM": "BSK MARTINENGO", ####
    "BŠKMARTINENGO": "BSK MARTINENGO",
    "ŠERMLZ": "ŠERM LIBEREC", ####
    "SERM LIBEREC": "ŠERM LIBEREC",
    "SLOV HORKY": "TJ SLOVAN HORKY", ####
    "SLOVAN HORKY": "TJ SLOVAN HORKY", 
    "TĚLOJSHZ": "TJ SLOVAN HORKY",
    "TJSBI": "S.BRNO I",  ####
    "SLAVLZ": "SLAVOJ LITOMERICE", ####
    "AKADSB": "AKADÉMIA ŠERMU BRATISLAVA",  ####
    "SLAV ČTĚŠ": "SLAVOJ Č.TĚŠÍN", ####
    "SLAVOJ TESIN": "SLAVOJ Č.TĚŠÍN",
    "TJSČTZ": "SLAVOJ Č.TĚŠÍN",
    "OREL HK": "OREL HR.KR.", ####
    "ORELJHK": "OREL HR.KR."
            }

# %%
# pro 77 žen mám původně 153 klubo-kombinací -> 78
## hapruje mi: HUNČÁROVÁ Katarína

# pro 154 mužů původně 285 name-klub kombinací 
# -> nyní 154, což odpovídá počtu mužů -> každý má unikátní klub

# .size() vs .count(), zajímavé

df_m["Club"] = df_m["Club"].replace(to_replace_club)

# %%
men_clubs = df_m.groupby(['Name','Club']).size().reset_index().rename(columns={0:'count'})
printbold(str(len(men_clubs)))
men_clubs
# Out:
# 153
#                        Name                       Club  count
# 0         ADDO DJAN Theodor              SOKOL DEJVICE      4
# 1        AIGERMAN František            TJ LOKO TEPLICE      1
# 2           AIGERMAN Oliver            TJ LOKO TEPLICE      1
# 3             ALMER Vojtěch               EKONOM PRAHA      2
# 4              ANDERLE Petr               RIEGEL PRAHA      4
# 5         ARTAZOV Maxmilián          SČ USTI NAD LABEM      1
# 6              BALCAR Josef            TJ LOKO TEPLICE      6
# 7            BEDNÁR Kryštof              SOKOL DEJVICE      6
# 8                BERAN Jiří                   SC PRAHA      2
# 9                BERKA Adam             BSK MARTINENGO      1
# 10             BILKO Martin             TJ DUKLA PRAHA      1
# 11     BINICHAKIS Emannouil               ŠERM LIBEREC      1
# 12             BOSÁK Štěpán                  USK PRAHA      2
# 13              BRADÁČ Petr                  USK PRAHA      4
# 14              BUREŠ Lukáš              DUKLA OLOMOUC      1
# 15             BÉREŠ Daniel               EKONOM PRAHA      1
# 16                BÓR Karel               ŠERM LIBEREC      1
# 17        BĚLOHOUBEK Matouš               RIEGEL PRAHA      2
# 18              CHOUN Karím                   SC PRAHA      6
# 19           CIMLER Čestmír               RIEGEL PRAHA      1
# 20           CIMPA Miroslav                 SP Š TÁBOR      1
# 21         COUFAL František          1.FC BELA POD BEZ      4
# 22         D'AMICO Kristian                   SC PRAHA      5
# 23            DOLEJŠÍ Marek                   SC PRAHA      6
# 24               DOŠEK Jiří                  USK PRAHA      2
# 25      DUDUC Alex Vladimír             BSK MARTINENGO      3
# 26            DURYCH Martin             TJ DUKLA PRAHA      1
# 27                ERNÉE Jan                   SC PRAHA      2
# 28            FIEDOR Michal                   SC PRAHA      6
# 29             FRANK Kilián             TJ DUKLA PRAHA      6
# 30             FÖLDES Tomáš              DUKLA OLOMOUC      5
# 31            GAISLER Jakub            TJ LOKO TEPLICE      4
# 32              GENZER Jiří               EKONOM PRAHA      3
# 33              GERŽA Jakub                    SPORŠZZ      1
# 34               GIL Matyáš               VSK HUMANITA      1
# 35            GRUMMICH Petr          SČ USTI NAD LABEM      5
# 36           HABARTA Ondřej                   SC PRAHA      3
# 37                HERDA Jan                  USK PRAHA      6
# 38           HEREY Anatoliy             DYNAMO UŽHOROD      1
# 39             HLAVÁČ Jakub              DUKLA OLOMOUC      2
# 40          HORBACHUK Yuriy               ŠERM LIBEREC      2
# 41             HOYER Martin            TJ SLOVAN HORKY      5
# 42            HRONEK Ondřej             TJ SOKOL PISEK      1
# 43               HÖBAUS Max               VSK HUMANITA      1
# 44          IVANČO Alexandr          SČ USTI NAD LABEM      5
# 45           IVANČO Mikuláš          SČ USTI NAD LABEM      5
# 46             IVANČO Robin          SČ USTI NAD LABEM      5
# 47         JAMBOR Stanislav             TJ LOKO K.VARY      5
# 48                JANŮ Gael              DUKLA OLOMOUC      1
# 49    JAVAKHISHVILI Georgii                    TBILISI      1
# 50             JEŘÁBEK Petr             SS UH.HRADISTE      1
# 51             JINDRA Jakub              TJ LOKO PLZEN      1
# 52               JINDRA Jan                   SC PRAHA      1
# 53                JIRAN Jan               EKONOM PRAHA      4
# 54              JURKA Jakub              DUKLA OLOMOUC      2
# 55              JURKA Tomáš              DUKLA OLOMOUC      1
# 56           JÍLEK Jaroslav              TJ LOKO PLZEN      4
# 57              KAIL Daniel                   SC PRAHA      4
# 58              KALUS Jonáš                   SC PRAHA      2
# 59               KAREL Petr               ŠERM LIBEREC      2
# 60            KARÁSEK Libor             SS UH.HRADISTE      3
# 61            KAŠPAR Daniel             TJ DUKLA PRAHA      4
# 62             KEDER Michal               EKONOM PRAHA      3
# 63             KLAUS Robert                   SC PRAHA      6
# 64               KLSÁK Adam             TJ LOKO K.VARY      3
# 65            KNAP Ladislav               ŠERM LIBEREC      3
# 66              KNOP Tadeáš               ŠERM LIBEREC      2
# 67               KOTALA Jan            TJ LOKO TEPLICE      5
# 68               KOUŘIL Jan             SS UH.HRADISTE      2
# 69             KRAJSA Tomáš             TJ LOKO K.VARY      5
# 70          KROUŽECKÝ Tomáš                  USK PRAHA      5
# 71                KRÁL Jiří              DUKLA OLOMOUC      1
# 72             KUCHAŘ Matěj                   SC PRAHA      3
# 73                  KUF Jan             TJ DUKLA PRAHA      2
# 74               KULT Pavel                   SC PRAHA      4
# 75             KURÁŇ Martin              DUKLA OLOMOUC      2
# 76                KŘÍŽ Petr                   S.BRNO I      2
# 77             LOKAJ Václav               VSK HUMANITA      4
# 78            LUCOVIČ Matěj             TJ LOKO K.VARY      2
# 79              LUKEŠ Matěj             TJ DUKLA PRAHA      1
# 80           LUŠTICKÝ Josef                OREL HR.KR.      3
# 81                LÁNÍK Jan          SČ USTI NAD LABEM      5
# 82            MALEČEK Jakub             TJ DUKLA PRAHA      1
# 83           MATOUŠEK David              TJ LOKO PLZEN      5
# 84           MAŠATA Vojtěch             TJ LOKO K.VARY      2
# 85             MIČINEC Adam             TJ DUKLA PRAHA      4
# 86            MOTALÍK Libor              DUKLA OLOMOUC      5
# 87               MRÁZ Pavel              SOKOL DEJVICE      1
# 88      MÜNZBERGER Vladimír             TJ DUKLA PRAHA      1
# 89             NECHAY Pavel                SOKOL PLZEN      1
# 90            NOVOTNÝ Šimon               ŠERM LIBEREC      2
# 91             NOVÁK Martin          1.FC BELA POD BEZ      5
# 92           OMELKA Antonín               VSK HUMANITA      1
# 93             OMELKA Jakub                    SPORŠZZ      1
# 94              OSIČKA Adam              DUKLA OLOMOUC      1
# 95            PAVLÍK Matyáš                   SC PRAHA      4
# 96              PITRA Pavel                   SC PRAHA      5
# 97           POHNAN Kryštof                   SC PRAHA      2
# 98          POKORNÝ Richard                   SC PRAHA      1
# 99         PROCHÁZKA Ondřej          1.FC BELA POD BEZ      6
# 100           PRYL Dobromil               RIEGEL PRAHA      5
# 101    PUSTĚJOVSKÝ Vladimír                   SC PRAHA      6
# 102            RUBEŠ Martin             TJ LOKO K.VARY      6
# 103         SADSKÝ Jaroslav              TJ LOKO PLZEN      2
# 104           SALAČ Vojtěch          SLAVOJ LITOMERICE      1
# 105             SALZER Jiří                   SC PRAHA      2
# 106            SALZER Matěj                   SC PRAHA      6
# 107          SCHÖPPEL Karel                   VSK ČVUT      1
# 108             SEDLÁK Petr            TJ LOKO TEPLICE      1
# 109            SEJKORA Adam                   SC PRAHA      1
# 110            SKROVNÝ Petr              TJ LOKO PLZEN      4
# 111            SMRČEK Šimon                  USK PRAHA      5
# 112              SMÍTKA Jan                SOKOL PLZEN      1
# 113         SOKOL Vratislav             SLAVOJ Č.TĚŠÍN      5
# 114             STEHLÍK Jan              DUKLA OLOMOUC      5
# 115         STEHLÍK Vojtěch          SLAVOJ LITOMERICE      1
# 116             STEIS Matúš                   SC PRAHA      4
# 117       STIRBER Sebastián                   SC PRAHA      6
# 118           STOLAR Samuel  AKADÉMIA ŠERMU BRATISLAVA      2
# 119            STRAKA Tomáš                   SC PRAHA      3
# 120          STUDENÝ Václav                   S.BRNO I      1
# 121            SURMA Štěpán                   LAŠSSKFZ      2
# 122    SVOBODA Bohumil Jiří             TJ DUKLA PRAHA      1
# 123           SVOBODA Tomáš                  USK PRAHA      3
# 124  SVOBODA Tomáš Kristián                  USK PRAHA      4
# 125              SZALAY Jan                     BA MPC      1
# 126     SÝKORA Adam Herbert             TJ SOKOL PISEK      1
# 127         TKACHENKO Danil                    SPORŠZZ      1
# 128               TOMAN Jan             TJ DUKLA PRAHA      4
# 129            TOMAN Štěpán              SOKOL DEJVICE      1
# 130          TÁBORSKÝ Lukáš                  USK PRAHA      6
# 131              TŮMA Marek              SOKOL DEJVICE      6
# 132          VACHOVEC Matěj              TJ LOKO PLZEN      2
# 133            VALENTA Jiří                   SC PRAHA      1
# 134         VALKOVIČ Martin                   SC PRAHA      6
# 135             VASIC Filip              SILNI BEOGRAD      1
# 136          VAŠÍČEK Martin              DUKLA OLOMOUC      3
# 137             VLACH Šimon              TJ LOKO PLZEN      1
# 138            VOLÁK Samuel              DUKLA OLOMOUC      2
# 139           VONDRA Matouš             TJ DUKLA PRAHA      1
# 140          VÁVRA Miroslav                   VSK ČVUT      1
# 141           VÁVRA Vojtěch               EKONOM PRAHA      5
# 142            VÍTEK Daniel             TJ LOKO K.VARY      2
# 143             WALLER Adam                   SC PRAHA      5
# 144            WALLER Jonáš                   SC PRAHA      6
# 145            ZELENKA Jiří               VSK HUMANITA      1
# 146            ČAPEK Martin                   SC PRAHA      6
# 147             ČUPR Michal          SLAVOJ LITOMERICE      6
# 148         ŘEZANKA_ST. Ota             TJ LOKO K.VARY      2
# 149         ŠILHÁN Jindřich               ŠERM LIBEREC      1
# 150         ŠPATENKA Martin              DUKLA OLOMOUC      6
# 151          ŠTVERÁK Martin             TJ SOKOL PISEK      1
# 152            ŠVANDA Pavel                  USK PRAHA      4

# %% [markdown]
# ## Duplicity v Datumech narození - UPŘESNIT
# * i po opravě datumů v turnaji v Písku mám 163 řádků místo 153
# * předpoklad - kdo má 1.1., tak datum nejdřív nevěděli, později doplnili
# * tot aplikuji sem: BALCAR Josef, BEDNÁR Kryštof, MIČINEC Adam, STEHLÍK Jan, STOLAR Samuel, VÁVRA Vojtěch
# * DUDUC Alex Vladimir (má 3 různé - zatím volím 1.6.97)
# * GAISLER Jakub (jiný měsíc - zatím volím 29.4., byl víckrát, shodně s exportem Mužů)
# * KURÁŇ Martin (stále o den - zatím volím 24.8., shodně s exportem Mužů)
# * Stehlík Vojtěch - na webu 2001, ale v Lázenském poháru 2011

# %%
men_birthdates = df_m.groupby(['Name','Birthdate']).size().reset_index().rename(columns={0:'count'})
printbold(str(len(men_birthdates)))
men_birthdates
# Out:
# 153
#                        Name  Birthdate  count
# 0         ADDO DJAN Theodor 2006-11-06      4
# 1        AIGERMAN František 1972-08-31      1
# 2           AIGERMAN Oliver 2006-12-03      1
# 3             ALMER Vojtěch 1997-12-24      2
# 4              ANDERLE Petr 1977-07-07      4
# 5         ARTAZOV Maxmilián 2002-03-09      1
# 6              BALCAR Josef 1998-10-31      6
# 7            BEDNÁR Kryštof 1997-04-02      6
# 8                BERAN Jiří 1982-01-18      2
# 9                BERKA Adam 1982-03-11      1
# 10             BILKO Martin 1993-03-12      1
# 11     BINICHAKIS Emannouil 2001-03-20      1
# 12             BOSÁK Štěpán 1998-02-16      2
# 13              BRADÁČ Petr 1996-04-30      4
# 14              BUREŠ Lukáš 2005-05-01      1
# 15             BÉREŠ Daniel 1993-12-01      1
# 16                BÓR Karel 2007-02-16      1
# 17        BĚLOHOUBEK Matouš 2003-05-12      2
# 18              CHOUN Karím 2005-09-05      6
# 19           CIMLER Čestmír 1990-06-14      1
# 20           CIMPA Miroslav 1982-06-15      1
# 21         COUFAL František 2003-02-10      4
# 22         D'AMICO Kristian 1997-04-22      5
# 23            DOLEJŠÍ Marek 1993-12-12      6
# 24               DOŠEK Jiří 2004-06-23      2
# 25      DUDUC Alex Vladimír 1997-06-01      3
# 26            DURYCH Martin 1994-01-15      1
# 27                ERNÉE Jan 1998-09-08      2
# 28            FIEDOR Michal 2004-02-02      6
# 29             FRANK Kilián 2003-03-14      6
# 30             FÖLDES Tomáš 1986-01-01      5
# 31            GAISLER Jakub 2005-04-29      4
# 32              GENZER Jiří 1978-05-05      3
# 33              GERŽA Jakub 1992-07-06      1
# 34               GIL Matyáš 1999-09-06      1
# 35            GRUMMICH Petr 1991-11-20      5
# 36           HABARTA Ondřej 1992-03-10      3
# 37                HERDA Jan 1957-07-26      6
# 38           HEREY Anatoliy 1989-03-31      1
# 39             HLAVÁČ Jakub 1983-07-06      2
# 40          HORBACHUK Yuriy 1972-05-07      2
# 41             HOYER Martin 1967-11-25      5
# 42            HRONEK Ondřej 2007-12-16      1
# 43               HÖBAUS Max 2000-12-30      1
# 44          IVANČO Alexandr 1973-11-28      5
# 45           IVANČO Mikuláš 2001-06-08      5
# 46             IVANČO Robin 1999-10-08      5
# 47         JAMBOR Stanislav 1981-01-14      5
# 48                JANŮ Gael 2003-01-06      1
# 49    JAVAKHISHVILI Georgii 1999-05-05      1
# 50             JEŘÁBEK Petr 1984-06-10      1
# 51             JINDRA Jakub 2002-09-24      1
# 52               JINDRA Jan 1956-09-20      1
# 53                JIRAN Jan 1996-07-31      4
# 54              JURKA Jakub 1999-06-13      2
# 55              JURKA Tomáš 1997-01-01      1
# 56           JÍLEK Jaroslav 1968-07-03      4
# 57              KAIL Daniel 2003-07-20      4
# 58              KALUS Jonáš 2002-11-23      2
# 59               KAREL Petr 1974-09-22      2
# 60            KARÁSEK Libor 1984-04-12      3
# 61            KAŠPAR Daniel 1980-07-17      4
# 62             KEDER Michal 1991-12-24      3
# 63             KLAUS Robert 2003-03-03      6
# 64               KLSÁK Adam 1991-06-25      3
# 65            KNAP Ladislav 1978-10-21      3
# 66              KNOP Tadeáš 2004-03-10      2
# 67               KOTALA Jan 2004-11-08      5
# 68               KOUŘIL Jan 1988-03-25      2
# 69             KRAJSA Tomáš 1982-04-12      5
# 70          KROUŽECKÝ Tomáš 2001-08-12      5
# 71                KRÁL Jiří 2004-06-30      1
# 72             KUCHAŘ Matěj 2006-02-04      3
# 73                  KUF Jan 1991-05-11      2
# 74               KULT Pavel 1995-03-31      4
# 75             KURÁŇ Martin 2005-08-24      2
# 76                KŘÍŽ Petr 1990-04-19      2
# 77             LOKAJ Václav 1998-09-09      4
# 78            LUCOVIČ Matěj 2001-02-28      2
# 79              LUKEŠ Matěj 2002-04-12      1
# 80           LUŠTICKÝ Josef 2004-11-17      3
# 81                LÁNÍK Jan 1973-05-24      5
# 82            MALEČEK Jakub 2001-04-24      1
# 83           MATOUŠEK David 2004-09-01      5
# 84           MAŠATA Vojtěch 2002-09-07      2
# 85             MIČINEC Adam 1991-07-01      4
# 86            MOTALÍK Libor 1971-03-28      5
# 87               MRÁZ Pavel 1988-07-02      1
# 88      MÜNZBERGER Vladimír 1971-02-25      1
# 89             NECHAY Pavel 2007-04-16      1
# 90            NOVOTNÝ Šimon 2006-05-17      2
# 91             NOVÁK Martin 2004-05-04      5
# 92           OMELKA Antonín 1993-03-12      1
# 93             OMELKA Jakub 1994-07-22      1
# 94              OSIČKA Adam 2000-10-22      1
# 95            PAVLÍK Matyáš 2000-09-13      4
# 96              PITRA Pavel 1988-06-25      5
# 97           POHNAN Kryštof 2004-03-08      2
# 98          POKORNÝ Richard 1991-07-11      1
# 99         PROCHÁZKA Ondřej 2005-04-10      6
# 100           PRYL Dobromil 1975-05-06      5
# 101    PUSTĚJOVSKÝ Vladimír 2003-12-14      6
# 102            RUBEŠ Martin 1996-09-16      6
# 103         SADSKÝ Jaroslav 1982-12-03      2
# 104           SALAČ Vojtěch 1998-09-23      1
# 105             SALZER Jiří 2001-07-29      2
# 106            SALZER Matěj 2001-07-29      6
# 107          SCHÖPPEL Karel 2005-02-03      1
# 108             SEDLÁK Petr 2006-04-30      1
# 109            SEJKORA Adam 2007-08-28      1
# 110            SKROVNÝ Petr 1984-05-10      4
# 111            SMRČEK Šimon 2001-05-17      5
# 112              SMÍTKA Jan 2001-05-24      1
# 113         SOKOL Vratislav 1976-07-08      5
# 114             STEHLÍK Jan 1999-02-28      5
# 115         STEHLÍK Vojtěch 2001-11-07      1
# 116             STEIS Matúš 1993-04-03      4
# 117       STIRBER Sebastián 2004-08-12      6
# 118           STOLAR Samuel 1998-06-16      2
# 119            STRAKA Tomáš 1975-03-14      3
# 120          STUDENÝ Václav 1966-11-07      1
# 121            SURMA Štěpán 2004-12-17      2
# 122    SVOBODA Bohumil Jiří 2003-03-17      1
# 123           SVOBODA Tomáš 1998-11-29      3
# 124  SVOBODA Tomáš Kristián 1967-09-09      4
# 125              SZALAY Jan 1992-01-01      1
# 126     SÝKORA Adam Herbert 2001-09-17      1
# 127         TKACHENKO Danil 2000-10-31      1
# 128               TOMAN Jan 2002-08-16      4
# 129            TOMAN Štěpán 1978-06-10      1
# 130          TÁBORSKÝ Lukáš 2004-06-03      6
# 131              TŮMA Marek 1993-03-30      6
# 132          VACHOVEC Matěj 2005-11-30      2
# 133            VALENTA Jiří 1983-07-04      1
# 134         VALKOVIČ Martin 1962-08-27      6
# 135             VASIC Filip 1973-07-19      1
# 136          VAŠÍČEK Martin 2002-09-21      3
# 137             VLACH Šimon 2005-06-10      1
# 138            VOLÁK Samuel 2000-12-15      2
# 139           VONDRA Matouš 2003-11-23      1
# 140          VÁVRA Miroslav 1961-08-17      1
# 141           VÁVRA Vojtěch 1996-11-19      5
# 142            VÍTEK Daniel 1974-05-18      2
# 143             WALLER Adam 2007-08-27      5
# 144            WALLER Jonáš 2008-10-10      6
# 145            ZELENKA Jiří 1993-06-04      1
# 146            ČAPEK Martin 1983-09-14      6
# 147             ČUPR Michal 1991-12-23      6
# 148         ŘEZANKA_ST. Ota 1970-07-24      2
# 149         ŠILHÁN Jindřich 1996-12-20      1
# 150         ŠPATENKA Martin 1971-10-13      6
# 151          ŠTVERÁK Martin 1993-07-13      1
# 152            ŠVANDA Pavel 1975-02-02      4

# %%
## Problémisti:

df2 = df_m.groupby(['Name','Birthdate']).size().reset_index().rename(columns={0:'count'})
df2 = df2[["Name", "Birthdate"]]
#display(df2)
v = df2.Name.value_counts()   # kolikrát se jméno objevuje v našem Name-Birthdate groupáči, kde jsou unikátní dvojice
df2[df2.Name.isin(v.index[v.gt(1)])]  # nevím co je to v.gt(1), ale 1 v tuto chvíli říká 2 a více výskytů :D
# Out:
# Empty DataFrame
# Columns: [Name, Birthdate]
# Index: []

# %%
## MANUÁLNÍ OPRAVA

df_m.loc[df_m.Name == "BALCAR Josef", "Birthdate"] = "1998-10-31"
df_m.loc[df_m.Name == "BEDNÁR Kryštof", "Birthdate"] = "1997-04-02"
df_m.loc[df_m.Name == "DUDUC Alex Vladimír", "Birthdate"] = "1997-06-01"
df_m.loc[df_m.Name == "GAISLER Jakub", "Birthdate"] = "2005-04-29"
df_m.loc[df_m.Name == "KURÁŇ Martin", "Birthdate"] = "2005-08-24"
df_m.loc[df_m.Name == "MIČINEC Adam", "Birthdate"] = "1991-07-01"
df_m.loc[df_m.Name == "STEHLÍK Jan", "Birthdate"] = "1999-02-28"
df_m.loc[df_m.Name == "STOLAR Samuel", "Birthdate"] = "1998-06-16"
df_m.loc[df_m.Name == "VÁVRA Vojtěch", "Birthdate"] = "1996-11-19"

df_m.loc[df_m.Name == "STEHLÍK Vojtěch", "Birthdate"] = "2001-11-07"

# %% [markdown]
# ## Kontrola zemí
#
# #### 2 lidé mají dvě země (kluby i pohlaví i birthdate už hotovy).
# #### DUDUC Alex Vladimir & STEIS Matúš - oba víckrát SVK než CZE -> SVK

# %%
# 155 místo 153

men_countries = df_m.groupby(['Name','Club', "Country", "Sex", "Birthdate"]).size().reset_index().rename(columns={0:'count'})
printbold(str(len(men_countries)))
men_countries
# Out:
# 155
#                        Name                       Club Country Sex  Birthdate  \
# 0         ADDO DJAN Theodor              SOKOL DEJVICE     CZE   M 2006-11-06
# 1        AIGERMAN František            TJ LOKO TEPLICE     CZE   M 1972-08-31
# 2           AIGERMAN Oliver            TJ LOKO TEPLICE     CZE   M 2006-12-03
# 3             ALMER Vojtěch               EKONOM PRAHA     CZE   M 1997-12-24
# 4              ANDERLE Petr               RIEGEL PRAHA     CZE   M 1977-07-07
# 5         ARTAZOV Maxmilián          SČ USTI NAD LABEM     CZE   M 2002-03-09
# 6              BALCAR Josef            TJ LOKO TEPLICE     CZE   M 1998-10-31
# 7            BEDNÁR Kryštof              SOKOL DEJVICE     CZE   M 1997-04-02
# 8                BERAN Jiří                   SC PRAHA     CZE   M 1982-01-18
# 9                BERKA Adam             BSK MARTINENGO     CZE   M 1982-03-11
# 10             BILKO Martin             TJ DUKLA PRAHA     CZE   M 1993-03-12
# 11     BINICHAKIS Emannouil               ŠERM LIBEREC     GRE   M 2001-03-20
# 12             BOSÁK Štěpán                  USK PRAHA     CZE   M 1998-02-16
# 13              BRADÁČ Petr                  USK PRAHA     CZE   M 1996-04-30
# 14              BUREŠ Lukáš              DUKLA OLOMOUC     CZE   M 2005-05-01
# 15             BÉREŠ Daniel               EKONOM PRAHA     CZE   M 1993-12-01
# 16                BÓR Karel               ŠERM LIBEREC     CZE   M 2007-02-16
# 17        BĚLOHOUBEK Matouš               RIEGEL PRAHA     CZE   M 2003-05-12
# 18              CHOUN Karím                   SC PRAHA     CZE   M 2005-09-05
# 19           CIMLER Čestmír               RIEGEL PRAHA     CZE   M 1990-06-14
# 20           CIMPA Miroslav                 SP Š TÁBOR     CZE   M 1982-06-15
# 21         COUFAL František          1.FC BELA POD BEZ     CZE   M 2003-02-10
# 22         D'AMICO Kristian                   SC PRAHA     CZE   M 1997-04-22
# 23            DOLEJŠÍ Marek                   SC PRAHA     CZE   M 1993-12-12
# 24               DOŠEK Jiří                  USK PRAHA     CZE   M 2004-06-23
# 25      DUDUC Alex Vladimír             BSK MARTINENGO     CZE   M 1997-06-01
# 26      DUDUC Alex Vladimír             BSK MARTINENGO     SVK   M 1997-06-01
# 27            DURYCH Martin             TJ DUKLA PRAHA     CZE   M 1994-01-15
# 28                ERNÉE Jan                   SC PRAHA     CZE   M 1998-09-08
# 29            FIEDOR Michal                   SC PRAHA     CZE   M 2004-02-02
# 30             FRANK Kilián             TJ DUKLA PRAHA     CZE   M 2003-03-14
# 31             FÖLDES Tomáš              DUKLA OLOMOUC     CZE   M 1986-01-01
# 32            GAISLER Jakub            TJ LOKO TEPLICE     CZE   M 2005-04-29
# 33              GENZER Jiří               EKONOM PRAHA     CZE   M 1978-05-05
# 34              GERŽA Jakub                    SPORŠZZ     CZE   M 1992-07-06
# 35               GIL Matyáš               VSK HUMANITA     CZE   M 1999-09-06
# 36            GRUMMICH Petr          SČ USTI NAD LABEM     CZE   M 1991-11-20
# 37           HABARTA Ondřej                   SC PRAHA     CZE   M 1992-03-10
# 38                HERDA Jan                  USK PRAHA     CZE   M 1957-07-26
# 39           HEREY Anatoliy             DYNAMO UŽHOROD     UKR   M 1989-03-31
# 40             HLAVÁČ Jakub              DUKLA OLOMOUC     CZE   M 1983-07-06
# 41          HORBACHUK Yuriy               ŠERM LIBEREC     CZE   M 1972-05-07
# 42             HOYER Martin            TJ SLOVAN HORKY     CZE   M 1967-11-25
# 43            HRONEK Ondřej             TJ SOKOL PISEK     CZE   M 2007-12-16
# 44               HÖBAUS Max               VSK HUMANITA     CZE   M 2000-12-30
# 45          IVANČO Alexandr          SČ USTI NAD LABEM     CZE   M 1973-11-28
# 46           IVANČO Mikuláš          SČ USTI NAD LABEM     CZE   M 2001-06-08
# 47             IVANČO Robin          SČ USTI NAD LABEM     CZE   M 1999-10-08
# 48         JAMBOR Stanislav             TJ LOKO K.VARY     CZE   M 1981-01-14
# 49                JANŮ Gael              DUKLA OLOMOUC     CZE   M 2003-01-06
# 50    JAVAKHISHVILI Georgii                    TBILISI     GEO   M 1999-05-05
# 51             JEŘÁBEK Petr             SS UH.HRADISTE     CZE   M 1984-06-10
# 52             JINDRA Jakub              TJ LOKO PLZEN     CZE   M 2002-09-24
# 53               JINDRA Jan                   SC PRAHA     CZE   M 1956-09-20
# 54                JIRAN Jan               EKONOM PRAHA     CZE   M 1996-07-31
# 55              JURKA Jakub              DUKLA OLOMOUC     CZE   M 1999-06-13
# 56              JURKA Tomáš              DUKLA OLOMOUC     CZE   M 1997-01-01
# 57           JÍLEK Jaroslav              TJ LOKO PLZEN     CZE   M 1968-07-03
# 58              KAIL Daniel                   SC PRAHA     CZE   M 2003-07-20
# 59              KALUS Jonáš                   SC PRAHA     CZE   M 2002-11-23
# 60               KAREL Petr               ŠERM LIBEREC     CZE   M 1974-09-22
# 61            KARÁSEK Libor             SS UH.HRADISTE     CZE   M 1984-04-12
# 62            KAŠPAR Daniel             TJ DUKLA PRAHA     CZE   M 1980-07-17
# 63             KEDER Michal               EKONOM PRAHA     CZE   M 1991-12-24
# 64             KLAUS Robert                   SC PRAHA     CZE   M 2003-03-03
# 65               KLSÁK Adam             TJ LOKO K.VARY     CZE   M 1991-06-25
# 66            KNAP Ladislav               ŠERM LIBEREC     CZE   M 1978-10-21
# 67              KNOP Tadeáš               ŠERM LIBEREC     CZE   M 2004-03-10
# 68               KOTALA Jan            TJ LOKO TEPLICE     CZE   M 2004-11-08
# 69               KOUŘIL Jan             SS UH.HRADISTE     CZE   M 1988-03-25
# 70             KRAJSA Tomáš             TJ LOKO K.VARY     CZE   M 1982-04-12
# 71          KROUŽECKÝ Tomáš                  USK PRAHA     CZE   M 2001-08-12
# 72                KRÁL Jiří              DUKLA OLOMOUC     CZE   M 2004-06-30
# 73             KUCHAŘ Matěj                   SC PRAHA     CZE   M 2006-02-04
# 74                  KUF Jan             TJ DUKLA PRAHA     CZE   M 1991-05-11
# 75               KULT Pavel                   SC PRAHA     CZE   M 1995-03-31
# 76             KURÁŇ Martin              DUKLA OLOMOUC     CZE   M 2005-08-24
# 77                KŘÍŽ Petr                   S.BRNO I     CZE   M 1990-04-19
# 78             LOKAJ Václav               VSK HUMANITA     CZE   M 1998-09-09
# 79            LUCOVIČ Matěj             TJ LOKO K.VARY     CZE   M 2001-02-28
# 80              LUKEŠ Matěj             TJ DUKLA PRAHA     CZE   M 2002-04-12
# 81           LUŠTICKÝ Josef                OREL HR.KR.     CZE   M 2004-11-17
# 82                LÁNÍK Jan          SČ USTI NAD LABEM     CZE   M 1973-05-24
# 83            MALEČEK Jakub             TJ DUKLA PRAHA     CZE   M 2001-04-24
# 84           MATOUŠEK David              TJ LOKO PLZEN     CZE   M 2004-09-01
# 85           MAŠATA Vojtěch             TJ LOKO K.VARY     CZE   M 2002-09-07
# 86             MIČINEC Adam             TJ DUKLA PRAHA     CZE   M 1991-07-01
# 87            MOTALÍK Libor              DUKLA OLOMOUC     CZE   M 1971-03-28
# 88               MRÁZ Pavel              SOKOL DEJVICE     CZE   M 1988-07-02
# 89      MÜNZBERGER Vladimír             TJ DUKLA PRAHA     CZE   M 1971-02-25
# 90             NECHAY Pavel                SOKOL PLZEN     CZE   M 2007-04-16
# 91            NOVOTNÝ Šimon               ŠERM LIBEREC     CZE   M 2006-05-17
# 92             NOVÁK Martin          1.FC BELA POD BEZ     CZE   M 2004-05-04
# 93           OMELKA Antonín               VSK HUMANITA     CZE   M 1993-03-12
# 94             OMELKA Jakub                    SPORŠZZ     CZE   M 1994-07-22
# 95              OSIČKA Adam              DUKLA OLOMOUC     CZE   M 2000-10-22
# 96            PAVLÍK Matyáš                   SC PRAHA     CZE   M 2000-09-13
# 97              PITRA Pavel                   SC PRAHA     CZE   M 1988-06-25
# 98           POHNAN Kryštof                   SC PRAHA     CZE   M 2004-03-08
# 99          POKORNÝ Richard                   SC PRAHA     CZE   M 1991-07-11
# 100        PROCHÁZKA Ondřej          1.FC BELA POD BEZ     CZE   M 2005-04-10
# 101           PRYL Dobromil               RIEGEL PRAHA     CZE   M 1975-05-06
# 102    PUSTĚJOVSKÝ Vladimír                   SC PRAHA     CZE   M 2003-12-14
# 103            RUBEŠ Martin             TJ LOKO K.VARY     CZE   M 1996-09-16
# 104         SADSKÝ Jaroslav              TJ LOKO PLZEN     CZE   M 1982-12-03
# 105           SALAČ Vojtěch          SLAVOJ LITOMERICE     CZE   M 1998-09-23
# 106             SALZER Jiří                   SC PRAHA     CZE   M 2001-07-29
# 107            SALZER Matěj                   SC PRAHA     CZE   M 2001-07-29
# 108          SCHÖPPEL Karel                   VSK ČVUT     CZE   M 2005-02-03
# 109             SEDLÁK Petr            TJ LOKO TEPLICE     CZE   M 2006-04-30
# 110            SEJKORA Adam                   SC PRAHA     CZE   M 2007-08-28
# 111            SKROVNÝ Petr              TJ LOKO PLZEN     CZE   M 1984-05-10
# 112            SMRČEK Šimon                  USK PRAHA     CZE   M 2001-05-17
# 113              SMÍTKA Jan                SOKOL PLZEN     CZE   M 2001-05-24
# 114         SOKOL Vratislav             SLAVOJ Č.TĚŠÍN     CZE   M 1976-07-08
# 115             STEHLÍK Jan              DUKLA OLOMOUC     CZE   M 1999-02-28
# 116         STEHLÍK Vojtěch          SLAVOJ LITOMERICE     CZE   M 2001-11-07
# 117             STEIS Matúš                   SC PRAHA     CZE   M 1993-04-03
# 118             STEIS Matúš                   SC PRAHA     SVK   M 1993-04-03
# 119       STIRBER Sebastián                   SC PRAHA     CZE   M 2004-08-12
# 120           STOLAR Samuel  AKADÉMIA ŠERMU BRATISLAVA     SVK   M 1998-06-16
# 121            STRAKA Tomáš                   SC PRAHA     CZE   M 1975-03-14
# 122          STUDENÝ Václav                   S.BRNO I     CZE   M 1966-11-07
# 123            SURMA Štěpán                   LAŠSSKFZ     CZE   M 2004-12-17
# 124    SVOBODA Bohumil Jiří             TJ DUKLA PRAHA     CZE   M 2003-03-17
# 125           SVOBODA Tomáš                  USK PRAHA     CZE   M 1998-11-29
# 126  SVOBODA Tomáš Kristián                  USK PRAHA     CZE   M 1967-09-09
# 127              SZALAY Jan                     BA MPC     SVK   M 1992-01-01
# 128     SÝKORA Adam Herbert             TJ SOKOL PISEK     CZE   M 2001-09-17
# 129         TKACHENKO Danil                    SPORŠZZ     RUS   M 2000-10-31
# 130               TOMAN Jan             TJ DUKLA PRAHA     CZE   M 2002-08-16
# 131            TOMAN Štěpán              SOKOL DEJVICE     CZE   M 1978-06-10
# 132          TÁBORSKÝ Lukáš                  USK PRAHA     CZE   M 2004-06-03
# 133              TŮMA Marek              SOKOL DEJVICE     CZE   M 1993-03-30
# 134          VACHOVEC Matěj              TJ LOKO PLZEN     CZE   M 2005-11-30
# 135            VALENTA Jiří                   SC PRAHA     CZE   M 1983-07-04
# 136         VALKOVIČ Martin                   SC PRAHA     CZE   M 1962-08-27
# 137             VASIC Filip              SILNI BEOGRAD     CZE   M 1973-07-19
# 138          VAŠÍČEK Martin              DUKLA OLOMOUC     CZE   M 2002-09-21
# 139             VLACH Šimon              TJ LOKO PLZEN     CZE   M 2005-06-10
# 140            VOLÁK Samuel              DUKLA OLOMOUC     CZE   M 2000-12-15
# 141           VONDRA Matouš             TJ DUKLA PRAHA     CZE   M 2003-11-23
# 142          VÁVRA Miroslav                   VSK ČVUT     CZE   M 1961-08-17
# 143           VÁVRA Vojtěch               EKONOM PRAHA     CZE   M 1996-11-19
# 144            VÍTEK Daniel             TJ LOKO K.VARY     CZE   M 1974-05-18
# 145             WALLER Adam                   SC PRAHA     CZE   M 2007-08-27
# 146            WALLER Jonáš                   SC PRAHA     CZE   M 2008-10-10
# 147            ZELENKA Jiří               VSK HUMANITA     CZE   M 1993-06-04
# 148            ČAPEK Martin                   SC PRAHA     CZE   M 1983-09-14
# 149             ČUPR Michal          SLAVOJ LITOMERICE     CZE   M 1991-12-23
# 150         ŘEZANKA_ST. Ota             TJ LOKO K.VARY     CZE   M 1970-07-24
# 151         ŠILHÁN Jindřich               ŠERM LIBEREC     CZE   M 1996-12-20
# 152         ŠPATENKA Martin              DUKLA OLOMOUC     CZE   M 1971-10-13
# 153          ŠTVERÁK Martin             TJ SOKOL PISEK     CZE   M 1993-07-13
# 154            ŠVANDA Pavel                  USK PRAHA     CZE   M 1975-02-02
#
#      count
# 0        4
# 1        1
# 2        1
# 3        2
# 4        4
# 5        1
# 6        6
# 7        6
# 8        2
# 9        1
# 10       1
# 11       1
# 12       2
# 13       4
# 14       1
# 15       1
# 16       1
# 17       2
# 18       6
# 19       1
# 20       1
# 21       4
# 22       5
# 23       6
# 24       2
# 25       1
# 26       2
# 27       1
# 28       2
# 29       6
# 30       6
# 31       5
# 32       4
# 33       3
# 34       1
# 35       1
# 36       5
# 37       3
# 38       6
# 39       1
# 40       2
# 41       2
# 42       5
# 43       1
# 44       1
# 45       5
# 46       5
# 47       5
# 48       5
# 49       1
# 50       1
# 51       1
# 52       1
# 53       1
# 54       4
# 55       2
# 56       1
# 57       4
# 58       4
# 59       2
# 60       2
# 61       3
# 62       4
# 63       3
# 64       6
# 65       3
# 66       3
# 67       2
# 68       5
# 69       2
# 70       5
# 71       5
# 72       1
# 73       3
# 74       2
# 75       4
# 76       2
# 77       2
# 78       4
# 79       2
# 80       1
# 81       3
# 82       5
# 83       1
# 84       5
# 85       2
# 86       4
# 87       5
# 88       1
# 89       1
# 90       1
# 91       2
# 92       5
# 93       1
# 94       1
# 95       1
# 96       4
# 97       5
# 98       2
# 99       1
# 100      6
# 101      5
# 102      6
# 103      6
# 104      2
# 105      1
# 106      2
# 107      6
# 108      1
# 109      1
# 110      1
# 111      4
# 112      5
# 113      1
# 114      5
# 115      5
# 116      1
# 117      1
# 118      3
# 119      6
# 120      2
# 121      3
# 122      1
# 123      2
# 124      1
# 125      3
# 126      4
# 127      1
# 128      1
# 129      1
# 130      4
# 131      1
# 132      6
# 133      6
# 134      2
# 135      1
# 136      6
# 137      1
# 138      3
# 139      1
# 140      2
# 141      1
# 142      1
# 143      5
# 144      2
# 145      5
# 146      6
# 147      1
# 148      6
# 149      6
# 150      2
# 151      1
# 152      6
# 153      1
# 154      4

# %%
df_m.loc[df_m.Name == "DUDUC Alex Vladimir", "Country"] = "SVK"
df_m.loc[df_m.Name == "STEIS Matúš", "Country"] = "SVK"

# %% [markdown]
# ## Kontrola Final Ranků
# #### otázka: čím nahradit DNF? 99 ? 999? Pomlčkou, a pak vynechávat?

# %%
df_m["Final_rank"].value_counts()

df_m["Final_rank"] = df_m["Final_rank"].replace({"DNF": 99})

# %%
df_m[df_m.Name == "JURKA Jakub"]  # opravdu, má dvě čisté výhry turnajů
# Out:
#             Name           Club Country  Birthdate       Date           Event  \
# 240  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2022-05-21         MČR USK
# 318  JURKA Jakub  DUKLA OLOMOUC     CZE 1999-06-13 2022-10-22  Lázeňský pohár
#
#     Sex Rank First_rank  Final_rank     Notes
# 240   M    2          5           1  Advanced
# 318   M  1.0          1           1  Advanced

# %%
# seřazeno podle průměrného Final_ranku přes všechyn jejich závody
df_m.groupby('Name')['Final_rank'].mean().round().sort_values()
# Out:
# Name
# JURKA Jakub                1.0
# BERAN Jiří                 2.0
# HEREY Anatoliy             3.0
# RUBEŠ Martin               3.0
# ČUPR Michal                6.0
# BALCAR Josef               6.0
# KUF Jan                    6.0
# ČAPEK Martin               8.0
# COUFAL František           8.0
# DUDUC Alex Vladimír        8.0
# PAVLÍK Matyáš              8.0
# D'AMICO Kristian           9.0
# PITRA Pavel                9.0
# KLAUS Robert              10.0
# DOLEJŠÍ Marek             12.0
# ANDERLE Petr              14.0
# SALZER Matěj              14.0
# VACHOVEC Matěj            16.0
# HABARTA Ondřej            16.0
# JAVAKHISHVILI Georgii     17.0
# TOMAN Jan                 18.0
# KULT Pavel                18.0
# STEHLÍK Jan               19.0
# VOLÁK Samuel              20.0
# IVANČO Alexandr           21.0
# POKORNÝ Richard           22.0
# OSIČKA Adam               23.0
# POHNAN Kryštof            24.0
# MATOUŠEK David            24.0
# STIRBER Sebastián         25.0
# KOUŘIL Jan                25.0
# PROCHÁZKA Ondřej          25.0
# KALUS Jonáš               26.0
# FIEDOR Michal             27.0
# LOKAJ Václav              27.0
# KAŠPAR Daniel             28.0
# JANŮ Gael                 28.0
# MOTALÍK Libor             28.0
# SZALAY Jan                29.0
# JINDRA Jakub              30.0
# ŠVANDA Pavel              30.0
# BILKO Martin              30.0
# CHOUN Karím               30.0
# STRAKA Tomáš              31.0
# HORBACHUK Yuriy           31.0
# WALLER Jonáš              32.0
# BERKA Adam                32.0
# STOLAR Samuel             32.0
# HOYER Martin              32.0
# ERNÉE Jan                 32.0
# SVOBODA Bohumil Jiří      34.0
# NOVÁK Martin              35.0
# KUCHAŘ Matěj              36.0
# HLAVÁČ Jakub              36.0
# VAŠÍČEK Martin            37.0
# FRANK Kilián              37.0
# SALZER Jiří               38.0
# STEIS Matúš               38.0
# JURKA Tomáš               38.0
# VONDRA Matouš             39.0
# SOKOL Vratislav           39.0
# MAŠATA Vojtěch            39.0
# ŠPATENKA Martin           39.0
# LÁNÍK Jan                 40.0
# KOTALA Jan                40.0
# PUSTĚJOVSKÝ Vladimír      41.0
# KRAJSA Tomáš              42.0
# KŘÍŽ Petr                 42.0
# KROUŽECKÝ Tomáš           43.0
# KEDER Michal              43.0
# BRADÁČ Petr               43.0
# JAMBOR Stanislav          44.0
# MÜNZBERGER Vladimír       44.0
# IVANČO Robin              45.0
# KARÁSEK Libor             45.0
# TKACHENKO Danil           45.0
# VÁVRA Vojtěch             46.0
# BEDNÁR Kryštof            46.0
# DURYCH Martin             46.0
# PRYL Dobromil             47.0
# BUREŠ Lukáš               47.0
# VLACH Šimon               47.0
# TÁBORSKÝ Lukáš            48.0
# SMRČEK Šimon              48.0
# GAISLER Jakub             48.0
# KURÁŇ Martin              48.0
# WALLER Adam               48.0
# KLSÁK Adam                48.0
# MIČINEC Adam              49.0
# SEJKORA Adam              49.0
# IVANČO Mikuláš            49.0
# DOŠEK Jiří                50.0
# HRONEK Ondřej             50.0
# SKROVNÝ Petr              50.0
# ADDO DJAN Theodor         50.0
# FÖLDES Tomáš              51.0
# SURMA Štěpán              52.0
# NOVOTNÝ Šimon             53.0
# ŠTVERÁK Martin            53.0
# GERŽA Jakub               53.0
# MALEČEK Jakub             55.0
# HERDA Jan                 55.0
# JEŘÁBEK Petr              55.0
# JÍLEK Jaroslav            55.0
# KAIL Daniel               55.0
# TŮMA Marek                56.0
# SMÍTKA Jan                57.0
# GENZER Jiří               57.0
# BINICHAKIS Emannouil      57.0
# VALKOVIČ Martin           58.0
# SADSKÝ Jaroslav           58.0
# LUCOVIČ Matěj             58.0
# KAREL Petr                58.0
# KRÁL Jiří                 58.0
# SVOBODA Tomáš Kristián    58.0
# OMELKA Antonín            58.0
# ŠILHÁN Jindřich           60.0
# BOSÁK Štěpán              61.0
# STUDENÝ Václav            61.0
# CIMLER Čestmír            62.0
# LUŠTICKÝ Josef            62.0
# SVOBODA Tomáš             63.0
# KNAP Ladislav             63.0
# STEHLÍK Vojtěch           63.0
# OMELKA Jakub              64.0
# LUKEŠ Matěj               65.0
# ŘEZANKA_ST. Ota           66.0
# KNOP Tadeáš               66.0
# ALMER Vojtěch             66.0
# CIMPA Miroslav            67.0
# JINDRA Jan                67.0
# NECHAY Pavel              67.0
# SÝKORA Adam Herbert       68.0
# JIRAN Jan                 68.0
# AIGERMAN Oliver           69.0
# GIL Matyáš                70.0
# BÓR Karel                 70.0
# VASIC Filip               71.0
# BĚLOHOUBEK Matouš         72.0
# SALAČ Vojtěch             72.0
# VÍTEK Daniel              72.0
# GRUMMICH Petr             72.0
# BÉREŠ Daniel              72.0
# ARTAZOV Maxmilián         73.0
# VÁVRA Miroslav            74.0
# HÖBAUS Max                74.0
# ZELENKA Jiří              75.0
# TOMAN Štěpán              76.0
# SEDLÁK Petr               78.0
# AIGERMAN František        79.0
# MRÁZ Pavel                79.0
# VALENTA Jiří              80.0
# SCHÖPPEL Karel            80.0
# Name: Final_rank, dtype: float64

# %% [markdown]
# ## Vytvoření tabulky závodníků
# #### vyřešit sortování jmen dle české abecedy
# #### Případně příjmení pstá bez diakritiky...
#
# * ID / Jméno /Klub (potenciálně víc) / Stát / Pohlaví / D.narození / Ruka / Zbraň / Skore v žebříčku k poslednímu update
# * // dopočítaný počet všech turnajů, počet poolových zápasů a počet eliminačních zápasů, a jejich koeficienty Výher. / Počet vítězství? nebo to až později...

# %%
df_m["Year"]  = pd.DatetimeIndex(df_m['Birthdate']).year
printbold(str(len(df_m)))
df_m.head(2)
# Out:
# 447
#                 Name           Club Country  Birthdate       Date     Event  \
# 0  ADDO DJAN Theodor  SOKOL DEJVICE     CZE 2006-11-06 2021-12-18  Memorial
# 1       ANDERLE Petr   RIEGEL PRAHA     CZE 1977-07-07 2021-12-18  Memorial
#
#   Sex   Rank First_rank  Final_rank     Notes  Year
# 0   M  999.0         56          56  Advanced  2006
# 1   M   24.0         45          16  Advanced  1977

# %%
df_m_people = df_m.groupby(['Name','Club', "Country", "Sex", "Birthdate", "Year"]).size().reset_index().rename(columns={0:'count'})
df_m_people = df_m_people[["Name", "Club", "Country", "Sex", "Birthdate", "Year"]]

#df_m_people.to_excel("C:/Users/jzelenka/Documents/python_j/fencing/1_zavodnici.xlsx", index=False)

printbold(str(len(df_m_people)))
df_m_people.tail()
# Out:
# 154
#                 Name            Club Country Sex  Birthdate  Year
# 149  ŘEZANKA_ST. Ota  TJ LOKO K.VARY     CZE   M 1970-07-24  1970
# 150  ŠILHÁN Jindřich    ŠERM LIBEREC     CZE   M 1996-12-20  1996
# 151  ŠPATENKA Martin   DUKLA OLOMOUC     CZE   M 1971-10-13  1971
# 152   ŠTVERÁK Martin  TJ SOKOL PISEK     CZE   M 1993-07-13  1993
# 153     ŠVANDA Pavel       USK PRAHA     CZE   M 1975-02-02  1975

# %% [markdown]
# ## I.2 - STATISTIKY závodníci a kluby obecně

# %%
df = df_m_people.copy()
print(len(df))
df.head(2)
# Out:
# 154
#                  Name             Club Country Sex  Birthdate  Year
# 0   ADDO DJAN Theodor    SOKOL DEJVICE     CZE   M 2006-11-06  2006
# 1  AIGERMAN František  TJ LOKO TEPLICE     CZE   M 1972-08-31  1972

# %%
df[df.Year > 2006]  # ti nejmladší - potenciální chyba v datu narození
# Out:
#               Name            Club Country Sex  Birthdate  Year
# 16       BÓR Karel    ŠERM LIBEREC     CZE   M 2007-02-16  2007
# 43   HRONEK Ondřej  TJ SOKOL PISEK     CZE   M 2007-12-16  2007
# 90    NECHAY Pavel     SOKOL PLZEN     CZE   M 2007-04-16  2007
# 110   SEJKORA Adam        SC PRAHA     CZE   M 2007-08-28  2007
# 144    WALLER Adam        SC PRAHA     CZE   M 2007-08-27  2007
# 145   WALLER Jonáš        SC PRAHA     CZE   M 2008-10-10  2008

# %% [markdown]
# ## Počty závodníků podle roku narození

# %%
#plt.style.use('ggplot')
#plt.hist(df["Year"])

figure(figsize=(10, 4), dpi=100)

years = sorted(df["Year"].unique())
counts = df.groupby('Year')['Year'].count()
plt.xticks(years, rotation='vertical')
plt.bar(years, counts, width=0.8)  # šířka sloupečku

plt.show()

# %%
"""figure(figsize=(10, 4), dpi=100)

clubs = sorted(df["Club"].unique())  # Groupby je řazené abecedně,  takže i Clubs musím sortovat ! jedině pak Verze 2 přes dictionary
counts = df.groupby('Club')['Club'].count()
plt.xticks(rotation='vertical')    # muselo se tu jen odebrat to jméno z labelů, kůli problémům že to je kategorická proměnná
plt.bar(clubs, counts, width=0.8)  # šířka sloupečku

plt.show()"""
#
# Out:
# 'figure(figsize=(10, 4), dpi=100)\n\nclubs = sorted(df["Club"].unique())  # Groupby je řazené abecedně,  takže i Clubs musím sortovat ! jedině pak Verze 2 přes dictionary\ncounts = df.groupby(\'Club\')[\'Club\'].count()\nplt.xticks(rotation=\'vertical\')    # muselo se tu jen odebrat to jméno z labelů, kůli problémům že to je kategorická proměnná\nplt.bar(clubs, counts, width=0.8)  # šířka sloupečku\n\nplt.show()'

# %% [markdown]
# ## Počty závodníků podle klubů

# %%
# Verze 2 - přes Dictionary
# https://www.includehelp.com/python/groupby-results-to-dictionary-of-lists.aspx
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/categorical_variables.html

figure(figsize=(10, 4), dpi=100)

clubs = df.groupby(['Club'])['Club'].count().to_dict()
clubs = dict(sorted(clubs.items(), key=lambda item: item[1], reverse = True))

plt.xticks(rotation='vertical')                             # muselo se tu jen odebrat to jméno z labelů, kůli problémům že to je kategorická proměnná
plt.bar(list(clubs.keys()), list(clubs.values()), width=0.8)# šířka sloupečku

plt.show()

# %% [markdown]
# ## POKUS - věkové rozložení u 4 největších klubů
# * nutnost vyřešit překrývání sloupců

# %%
df1 = df.loc[df.Club == "SC PRAHA", ["Name", "Year"]]
df2 = df.loc[df.Club == "DUKLA OLOMOUC", ["Name", "Year"]]
df3 = df.loc[df.Club == "TJ DUKLA PRAHA", ["Name", "Year"]]
df4 = df.loc[df.Club == "USK PRAHA", ["Name", "Year"]]

print(len(df1), len(df2), len(df3), len(df4))
# Out:
# 29 14 12 10

# %%
figure(figsize=(10, 4), dpi=100)
years = sorted(df1["Year"].unique())

plt.xticks(rotation='vertical') 

years1 = sorted(df1["Year"].unique())
years2 = sorted(df2["Year"].unique())
years3 = sorted(df3["Year"].unique())
years4 = sorted(df4["Year"].unique())
plt.bar(years1, df1.groupby('Year')['Year'].count(), width=0.8)
plt.bar(years2, df2.groupby('Year')['Year'].count(), width=0.8)
plt.bar(years3, df3.groupby('Year')['Year'].count(), width=0.8)
plt.bar(years4, df4.groupby('Year')['Year'].count(), width=0.8)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Statistiky k Rankům
# * medaile podle kovu - nutnost vyřešit překrývání sloupců
# * pro složitější ploty (víc než jeden simple groupby) budou lepší dictionaries, případně listy i s nulami
# * např. pro stacked nebo sdružené sloupce

# %%
df_m.tail(2)
# Out:
#              Name          Club Country  Birthdate       Date  \
# 445  WALLER Jonáš      SC PRAHA     CZE 2008-10-10 2022-11-05
# 446  ZELENKA Jiří  VSK HUMANITA     CZE 1993-06-04 2022-11-05
#
#                       Event Sex Rank First_rank  Final_rank       Notes  Year
# 445  Zlatý kord města Písku   M   27         25          34    Advanced  2008
# 446  Zlatý kord města Písku   M  999         75          75  Eliminated  1993

# %%
# lets drop DNFs
df_m = df_m[df_m.Final_rank != "DNF"]
print(len(df_m))
# Out:
# 447

# %%
df_m.groupby(["Name", "Club", "Year"])['Final_rank'].min()
# Out:
# Name                    Club                       Year
# ADDO DJAN Theodor       SOKOL DEJVICE              2006    33
# AIGERMAN František      TJ LOKO TEPLICE            1972    79
# AIGERMAN Oliver         TJ LOKO TEPLICE            2006    69
# ALMER Vojtěch           EKONOM PRAHA               1997    65
# ANDERLE Petr            RIEGEL PRAHA               1977     5
# ARTAZOV Maxmilián       SČ USTI NAD LABEM          2002    73
# BALCAR Josef            TJ LOKO TEPLICE            1998     2
# BEDNÁR Kryštof          SOKOL DEJVICE              1997    17
# BERAN Jiří              SC PRAHA                   1982     1
# BERKA Adam              BSK MARTINENGO             1982    32
# BILKO Martin            TJ DUKLA PRAHA             1993    30
# BINICHAKIS Emannouil    ŠERM LIBEREC               2001    57
# BOSÁK Štěpán            USK PRAHA                  1998    47
# BRADÁČ Petr             USK PRAHA                  1996    37
# BUREŠ Lukáš             DUKLA OLOMOUC              2005    47
# BÉREŠ Daniel            EKONOM PRAHA               1993    72
# BÓR Karel               ŠERM LIBEREC               2007    70
# BĚLOHOUBEK Matouš       RIEGEL PRAHA               2003    70
# CHOUN Karím             SC PRAHA                   2005    13
# CIMLER Čestmír          RIEGEL PRAHA               1990    62
# CIMPA Miroslav          SP Š TÁBOR                 1982    67
# COUFAL František        1.FC BELA POD BEZ          2003     2
# D'AMICO Kristian        SC PRAHA                   1997     2
# DOLEJŠÍ Marek           SC PRAHA                   1993     3
# DOŠEK Jiří              USK PRAHA                  2004    31
# DUDUC Alex Vladimír     BSK MARTINENGO             1997     6
# DURYCH Martin           TJ DUKLA PRAHA             1994    46
# ERNÉE Jan               SC PRAHA                   1998    26
# FIEDOR Michal           SC PRAHA                   2004     7
# FRANK Kilián            TJ DUKLA PRAHA             2003    25
# FÖLDES Tomáš            DUKLA OLOMOUC              1986    33
# GAISLER Jakub           TJ LOKO TEPLICE            2005    40
# GENZER Jiří             EKONOM PRAHA               1978    34
# GERŽA Jakub             SPORŠZZ                    1992    53
# GIL Matyáš              VSK HUMANITA               1999    70
# GRUMMICH Petr           SČ USTI NAD LABEM          1991    59
# HABARTA Ondřej          SC PRAHA                   1992     3
# HERDA Jan               USK PRAHA                  1957    40
# HEREY Anatoliy          DYNAMO UŽHOROD             1989     3
# HLAVÁČ Jakub            DUKLA OLOMOUC              1983    22
# HORBACHUK Yuriy         ŠERM LIBEREC               1972    20
# HOYER Martin            TJ SLOVAN HORKY            1967    22
# HRONEK Ondřej           TJ SOKOL PISEK             2007    50
# HÖBAUS Max              VSK HUMANITA               2000    74
# IVANČO Alexandr         SČ USTI NAD LABEM          1973    11
# IVANČO Mikuláš          SČ USTI NAD LABEM          2001    32
# IVANČO Robin            SČ USTI NAD LABEM          1999    25
# JAMBOR Stanislav        TJ LOKO K.VARY             1981    36
# JANŮ Gael               DUKLA OLOMOUC              2003    28
# JAVAKHISHVILI Georgii   TBILISI                    1999    17
# JEŘÁBEK Petr            SS UH.HRADISTE             1984    55
# JINDRA Jakub            TJ LOKO PLZEN              2002    30
# JINDRA Jan              SC PRAHA                   1956    67
# JIRAN Jan               EKONOM PRAHA               1996    57
# JURKA Jakub             DUKLA OLOMOUC              1999     1
# JURKA Tomáš             DUKLA OLOMOUC              1997    38
# JÍLEK Jaroslav          TJ LOKO PLZEN              1968    49
# KAIL Daniel             SC PRAHA                   2003    38
# KALUS Jonáš             SC PRAHA                   2002    22
# KAREL Petr              ŠERM LIBEREC               1974    58
# KARÁSEK Libor           SS UH.HRADISTE             1984    37
# KAŠPAR Daniel           TJ DUKLA PRAHA             1980     7
# KEDER Michal            EKONOM PRAHA               1991    33
# KLAUS Robert            SC PRAHA                   2003     3
# KLSÁK Adam              TJ LOKO K.VARY             1991    24
# KNAP Ladislav           ŠERM LIBEREC               1978    56
# KNOP Tadeáš             ŠERM LIBEREC               2004    66
# KOTALA Jan              TJ LOKO TEPLICE            2004    15
# KOUŘIL Jan              SS UH.HRADISTE             1988    23
# KRAJSA Tomáš            TJ LOKO K.VARY             1982    21
# KROUŽECKÝ Tomáš         USK PRAHA                  2001    23
# KRÁL Jiří               DUKLA OLOMOUC              2004    58
# KUCHAŘ Matěj            SC PRAHA                   2006    28
# KUF Jan                 TJ DUKLA PRAHA             1991     5
# KULT Pavel              SC PRAHA                   1995     7
# KURÁŇ Martin            DUKLA OLOMOUC              2005    41
# KŘÍŽ Petr               S.BRNO I                   1990    34
# LOKAJ Václav            VSK HUMANITA               1998    18
# LUCOVIČ Matěj           TJ LOKO K.VARY             2001    54
# LUKEŠ Matěj             TJ DUKLA PRAHA             2002    65
# LUŠTICKÝ Josef          OREL HR.KR.                2004    51
# LÁNÍK Jan               SČ USTI NAD LABEM          1973    15
# MALEČEK Jakub           TJ DUKLA PRAHA             2001    55
# MATOUŠEK David          TJ LOKO PLZEN              2004    11
# MAŠATA Vojtěch          TJ LOKO K.VARY             2002    16
# MIČINEC Adam            TJ DUKLA PRAHA             1991    41
# MOTALÍK Libor           DUKLA OLOMOUC              1971    13
# MRÁZ Pavel              SOKOL DEJVICE              1988    79
# MÜNZBERGER Vladimír     TJ DUKLA PRAHA             1971    44
# NECHAY Pavel            SOKOL PLZEN                2007    67
# NOVOTNÝ Šimon           ŠERM LIBEREC               2006    47
# NOVÁK Martin            1.FC BELA POD BEZ          2004    15
# OMELKA Antonín          VSK HUMANITA               1993    58
# OMELKA Jakub            SPORŠZZ                    1994    64
# OSIČKA Adam             DUKLA OLOMOUC              2000    23
# PAVLÍK Matyáš           SC PRAHA                   2000     1
# PITRA Pavel             SC PRAHA                   1988     2
# POHNAN Kryštof          SC PRAHA                   2004    12
# POKORNÝ Richard         SC PRAHA                   1991    22
# PROCHÁZKA Ondřej        1.FC BELA POD BEZ          2005    11
# PRYL Dobromil           RIEGEL PRAHA               1975    26
# PUSTĚJOVSKÝ Vladimír    SC PRAHA                   2003    22
# RUBEŠ Martin            TJ LOKO K.VARY             1996     1
# SADSKÝ Jaroslav         TJ LOKO PLZEN              1982    57
# SALAČ Vojtěch           SLAVOJ LITOMERICE          1998    72
# SALZER Jiří             SC PRAHA                   2001    23
# SALZER Matěj            SC PRAHA                   2001     9
# SCHÖPPEL Karel          VSK ČVUT                   2005    80
# SEDLÁK Petr             TJ LOKO TEPLICE            2006    78
# SEJKORA Adam            SC PRAHA                   2007    49
# SKROVNÝ Petr            TJ LOKO PLZEN              1984    19
# SMRČEK Šimon            USK PRAHA                  2001    31
# SMÍTKA Jan              SOKOL PLZEN                2001    57
# SOKOL Vratislav         SLAVOJ Č.TĚŠÍN             1976    25
# STEHLÍK Jan             DUKLA OLOMOUC              1999     7
# STEHLÍK Vojtěch         SLAVOJ LITOMERICE          2001    63
# STEIS Matúš             SC PRAHA                   1993    20
# STIRBER Sebastián       SC PRAHA                   2004    13
# STOLAR Samuel           AKADÉMIA ŠERMU BRATISLAVA  1998    28
# STRAKA Tomáš            SC PRAHA                   1975    12
# STUDENÝ Václav          S.BRNO I                   1966    61
# SURMA Štěpán            LAŠSSKFZ                   2004    48
# SVOBODA Bohumil Jiří    TJ DUKLA PRAHA             2003    34
# SVOBODA Tomáš           USK PRAHA                  1998    43
# SVOBODA Tomáš Kristián  USK PRAHA                  1967    37
# SZALAY Jan              BA MPC                     1992    29
# SÝKORA Adam Herbert     TJ SOKOL PISEK             2001    68
# TKACHENKO Danil         SPORŠZZ                    2000    45
# TOMAN Jan               TJ DUKLA PRAHA             2002     9
# TOMAN Štěpán            SOKOL DEJVICE              1978    76
# TÁBORSKÝ Lukáš          USK PRAHA                  2004    24
# TŮMA Marek              SOKOL DEJVICE              1993    48
# VACHOVEC Matěj          TJ LOKO PLZEN              2005    14
# VALENTA Jiří            SC PRAHA                   1983    80
# VALKOVIČ Martin         SC PRAHA                   1962    44
# VASIC Filip             SILNI BEOGRAD              1973    71
# VAŠÍČEK Martin          DUKLA OLOMOUC              2002    20
# VLACH Šimon             TJ LOKO PLZEN              2005    47
# VOLÁK Samuel            DUKLA OLOMOUC              2000    19
# VONDRA Matouš           TJ DUKLA PRAHA             2003    39
# VÁVRA Miroslav          VSK ČVUT                   1961    74
# VÁVRA Vojtěch           EKONOM PRAHA               1996    36
# VÍTEK Daniel            TJ LOKO K.VARY             1974    69
# WALLER Adam             SC PRAHA                   2007    32
# WALLER Jonáš            SC PRAHA                   2008    11
# ZELENKA Jiří            VSK HUMANITA               1993    75
# ČAPEK Martin            SC PRAHA                   1983     1
# ČUPR Michal             SLAVOJ LITOMERICE          1991     3
# ŘEZANKA_ST. Ota         TJ LOKO K.VARY             1970    34
# ŠILHÁN Jindřich         ŠERM LIBEREC               1996    60
# ŠPATENKA Martin         DUKLA OLOMOUC              1971    20
# ŠTVERÁK Martin          TJ SOKOL PISEK             1993    53
# ŠVANDA Pavel            USK PRAHA                  1975    20
# Name: Final_rank, dtype: int64

# %% [markdown]
# ## Medaile souhrnně per rok narození

# %%
medals = df_m.loc[df_m.Final_rank.isin([1,2,3]), :]

# %%
figure(figsize=(6, 5), dpi=80)

years = sorted(medals["Year"].unique())
counts = medals.groupby('Year')['Year'].count()
plt.xticks(years, rotation='vertical')
plt.bar(years, counts, width=0.8)  # šířka sloupečku

plt.show()

# %% [markdown]
# ### Rozdělení na jednotlivé kovy
# * medaile podle kovu - nutnost vyřešit překrývání sloupců !

# %%
# nutnost mít list se všemi (nenulovými) roky

years_all = sorted(df_m.Year.unique())  # 1956-2008
print(len(years_all))
golds, silvers, bronzes = [0 for i in years_all],[0 for i in years_all],[0 for i in years_all]
print(len(golds))
# Out:
# 43
# 43

# %%
# jeden list pro každou medaili
# nustnost změnit na numpy array, protože jinak nefungovalo dvojité stackování, ale jen jednoduché 
# (silver: bottom = gold, ale bronze = gold + silver, tak to už ne)

for i in range(len(years_all)):
    df = df_m.loc[df_m.Year == years_all[i]].copy()
    df_g = df.loc[df.Final_rank == 1]
    df_s = df.loc[df.Final_rank == 2]
    df_b = df.loc[df.Final_rank == 3]
    
    golds[i], silvers[i], bronzes[i] = len(df_g), len(df_s), len(df_b) 

golds = np.array(golds)
silvers = np.array(silvers)
bronzes = np.array(bronzes)

# %%
figure(figsize=(12, 8), dpi=80)

plt.xticks(years_all ,rotation='vertical') 
plt.bar(years_all, golds,                          color = "gold",         label = "Gold")
plt.bar(years_all, silvers, bottom = golds,        color = "silver",     label = "Silver")
plt.bar(years_all, bronzes, bottom = golds+silvers, color = "goldenrod",  label = "Bronze")

plt.legend(loc = "upper left")
plt.show()

# %% [markdown]
# ## Medaile souhrn per klub

# %%
figure(figsize=(6, 5), dpi=80)

clubs = medals.groupby(['Club'])['Club'].count().to_dict()
clubs = dict(sorted(clubs.items(), key=lambda item: item[1], reverse = True))

plt.xticks(rotation='vertical')                             
plt.bar(list(clubs.keys()), list(clubs.values()), width=0.8)

plt.show()

# %% [markdown]
# # DODĚLAT !!!!!!!

# %%
years_all = sorted(df_m.Year.unique())  # 1956-2008
print(len(years_all))
golds, silvers, bronzes = [0 for i in years_all],[0 for i in years_all],[0 for i in years_all]
print(len(golds))

# %%
# jeden list pro každou medaili
# nustnost změnit na numpy array, protože jinak nefungovalo dvojité stackování, ale jen jednoduché 
# (silver: bottom = gold, ale bronze = gold + silver, tak to už ne)

for i in range(len(years_all)):
    df = df_m.loc[df_m.Year == years_all[i]].copy()
    df_g = df.loc[df.Final_rank == 1]
    df_s = df.loc[df.Final_rank == 2]
    df_b = df.loc[df.Final_rank == 3]
    
    golds[i], silvers[i], bronzes[i] = len(df_g), len(df_s), len(df_b) 

golds = np.array(golds)
silvers = np.array(silvers)
bronzes = np.array(bronzes)

# %% [markdown]
# # II. ZÁPASY
# ## II.1 - PŘÍPRAVA A ČIŠTĚNÍ DAT

# %%
def merge_all_matches(list_of_events, sex):
    df_tot = pd.DataFrame(columns = ["Date", "Event", "Name", "Uni", "Sex", "Fight_lvl",
                                     "Enemy", "Enemy_uni", "Result", "Scored", "Received"])
    if sex == "M":
        s = "men"
    else:
        s = "women"
    for event in list_of_events:
        e = pd.ExcelFile(f"C:/Users/jzelenka/Documents/python_j/fencing/data/{s}/" + event)
        df0 = pd.read_excel(e, 'pools')
        df1 = pd.read_excel(e, 'eliminations')
        
        print(f"Event {event} has {len(df0)} pool fights, {len(df1)} elimination fights and {len(df0['Name'].unique())} unique Names")

        df_tot = df_tot.append(pd.concat([df0, df1]))
        print(f"now total is: {len(df_tot)}")
        printbold("####################################")
        
    df_tot.reset_index(inplace=True, drop = True)
    df_tot = df_tot.rename(columns={"Uni":'Club', "Enemy_uni": "Enemy_Club" })
    
    return df_tot

# %%
df_m_matches = merge_all_matches(men, "M")
print(len(df_m_matches))
display(df_m_matches.head(2))
display(df_m_matches.tail(2))

# %%
df_m_matches.describe()

# %%
df_m_matches["Name"] = df_m_matches["Name"].replace(to_replace_man)     
df_m_matches["Club"] = df_m_matches["Club"].replace(to_replace_club)  
df_m_matches["Enemy_Club"] = df_m_matches["Enemy_Club"].replace(to_replace_club)  
df_m_matches['Name'].str.strip()

# %%
df_m_matches.describe()

# %%
# ANDERLE petr,
# CHOUN Karim
# D'AMICO Kristian
# DOŠEK Jirí
# HORBACHUCK Yuiriy
# JAVAKHISHVILI Georgii '
# KALUS Jonáš '
# LOKAJ Václav ',
# LUCOVIC Matej
# MAŠATA Vojtech  10/19
# POKORNÝ Richard '
# PROCHÁZKA Ondrej
# SALZER Jirí
# SALZER Matej
# SURMA Štepán
# VAŠÍCEK Martin

# %%
sorted(df_m_matches["Name"].unique())

# %% [markdown]
# ## až opravím jména (hromadně, nebo už v excelech?)
# ## tak můžu přikročit ke kontrole V vs D, a k součtům Dal - dostal atd
# # kontrola jestli někdo nemá V a víc zásahů než bodů, a naopak.
